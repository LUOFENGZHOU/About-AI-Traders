# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import matplotlib.pylab as plt
from scipy.stats import pearsonr

from hyperopt import fmin, tpe, hp, partial


def find_time_ind(df):
    day_ind = [0]
    day_temp = df["TradingDay"][0]
    for i in range(1, len(df)):
        if df["TradingDay"][i] != day_temp:
            day_ind.append(i)
            day_temp = df["TradingDay"][i]
    return day_ind

# %%
# input cell
# train = pd.read_csv('0805rolling5.csv')
train = pd.read_csv('08053before_rolling.csv')
# train = pd.read_csv('08052acou_and_factors.csv')
# x_column = ["factor"+str(i)+'_'+str(j) for i in range(0,17) for j in range(5)]
x_column = ["factor"+str(i) for i in range(0,17)]
# for i in range(12):
#     for j in range(5):
#         x_column.append("10M" + str(i) +'_'+str(j))
for i in range(12):
    x_column.append("10M" + str(i))

train = train.sort_values(by = ["TradingDay", "SecuCode"], ascending = [True, True])
train.reset_index(drop=True, inplace=True)
X = train[x_column]
target = ['NextReturnCate']
y = train[target]
y += 1
yp = train["NextReturn"]
time_ind = find_time_ind(train)

# %%
# initializing
train_days = 775
delta_days = -776
X_train = X[time_ind[0]:time_ind[train_days]]
X_test = X[time_ind[train_days]:time_ind[train_days+delta_days]]
y_train = y[time_ind[0]:time_ind[train_days]]
y_test = y[time_ind[train_days]:time_ind[train_days+delta_days]]
yp_train = yp[time_ind[0]:time_ind[train_days]]
yp_test = yp[time_ind[train_days]:time_ind[train_days+delta_days]]
dtrain = xgb.DMatrix(data=X_train, label=y_train)
dtest = xgb.DMatrix(data=X_test)
ddev = xgb.DMatrix(data=X_test, label=y_test)

evallist = [(ddev, 'eval'), (dtrain, 'train')]

# %%
# 自定义hyperopt的参数空间
space = {"max_depth": hp.randint("max_depth", 25),
         "n_estimators": hp.randint("n_estimators", 30),
         'learning_rate': hp.uniform('learning_rate', 1e-3, 5e-1),
         "subsample": hp.randint("subsample", 5),
         "min_child_weight": hp.randint("min_child_weight", 6),
         "alpha": hp.uniform("alpha", 0, 1),
         "lambda": hp.uniform("lambda", 0, 1)
         }

def argsDict_tranform(argsDict, isPrint=False):
    argsDict["max_depth"] = argsDict["max_depth"] + 5    # from 5 to 30
    argsDict['n_estimators'] = argsDict['n_estimators'] + 10  # from 10 to 40
    argsDict["learning_rate"] = argsDict["learning_rate"] * 0.02 + 0.001   # from 0.001 to 0.01
    argsDict["subsample"] = argsDict["subsample"] * 0.1 + 0.5  # from 0.5 to 1
    argsDict["min_child_weight"] = argsDict["min_child_weight"] + 1 # from 1 to 6
    argsDict["alpha"] = argsDict["alpha"] * 20
    argsDict["lambda"] = argsDict["lambda"] * 50
    if isPrint:
        print(argsDict)
    else:
        pass

    return argsDict

# %%
from sklearn.metrics import mean_squared_error, zero_one_loss

def xgboost_factory(argsDict):
    argsDict = argsDict_tranform(argsDict)
    
    params = {'nthread': -1,  # 进程数
              'max_depth': argsDict['max_depth'],  # 最大深度
              'n_estimators': argsDict['n_estimators'],  # 树的数量
              'eta': argsDict['learning_rate'],  # 学习率
              'subsample': argsDict['subsample'],  # 采样数
              'min_child_weight': argsDict['min_child_weight'],  # 终点节点最小样本占比的和
              'objective': 'reg:squarederror',
              'silent': 0,  # 是否显示
              'gamma': 0,  # 是否后剪枝
              'colsample_bytree': 0.7,  # 样本列采样
              'alpha': argsDict['alpha'],  # L1 正则化
              'lambda': argsDict['lambda'],  # L2 正则化
              'scale_pos_weight': 0,  # 取值>0时,在数据不平衡时有助于收敛
              'seed': 100,  # 随机种子
              'tree_method':'exact'
              }

    xrf = xgb.train(params, dtrain, params['n_estimators'], evallist,early_stopping_rounds=100)

    return get_tranformer_score(xrf)


def get_tranformer_score(tranformer):
    
    xrf = tranformer
    pred = xrf.predict(ddev, ntree_limit=xrf.best_ntree_limit)
  
    return -pearsonr(np.array(yp_test), pred)[0]

# %%
# 开始使用hyperopt进行自动调参
algo = partial(tpe.suggest, n_startup_jobs=1)
best = fmin(xgboost_factory, space, algo=algo, max_evals=100, pass_expr_memo_ctrl=None)
store = best
print("the best parameter before transformation is:" + best)
print("the best parameter after transformation is:" + argsDict_tranform(best))
# Out:
# [0]	eval-rmse:0.956279	train-rmse:0.932308
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.956145	train-rmse:0.932158
#
# [2]	eval-rmse:0.955883	train-rmse:0.931955
#
# [3]	eval-rmse:0.955631	train-rmse:0.931761
#
# [4]	eval-rmse:0.955124	train-rmse:0.931316
#
# [5]	eval-rmse:0.95475	train-rmse:0.930898
#
# [6]	eval-rmse:0.954449	train-rmse:0.930655
#
# [7]	eval-rmse:0.954199	train-rmse:0.930452
#
# [8]	eval-rmse:0.954004	train-rmse:0.930189
#
# [9]	eval-rmse:0.953845	train-rmse:0.929862
#
# [10]	eval-rmse:0.953717	train-rmse:0.929499
#
# [11]	eval-rmse:0.953532	train-rmse:0.929097
#
# [12]	eval-rmse:0.953265	train-rmse:0.928752
#
# [13]	eval-rmse:0.953028	train-rmse:0.928432
#
# [14]	eval-rmse:0.952717	train-rmse:0.928113
#
# [15]	eval-rmse:0.952477	train-rmse:0.927825
#
# [16]	eval-rmse:0.952247	train-rmse:0.927551
#
# [17]	eval-rmse:0.952023	train-rmse:0.927296
#
# [18]	eval-rmse:0.951803	train-rmse:0.927072
#
# [19]	eval-rmse:0.951575	train-rmse:0.926865
#
# [20]	eval-rmse:0.951347	train-rmse:0.926652
#
# [21]	eval-rmse:0.951132	train-rmse:0.926427
#
# [22]	eval-rmse:0.950893	train-rmse:0.926191
#
# [23]	eval-rmse:0.950643	train-rmse:0.925961
#
# [0]	eval-rmse:0.956247	train-rmse:0.932277
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.956002	train-rmse:0.93203
#
# [2]	eval-rmse:0.955696	train-rmse:0.931798
#
# [3]	eval-rmse:0.955045	train-rmse:0.931299
#
# [4]	eval-rmse:0.954602	train-rmse:0.930798
#
# [5]	eval-rmse:0.954282	train-rmse:0.930545
#
# [6]	eval-rmse:0.954049	train-rmse:0.930237
#
# [7]	eval-rmse:0.953841	train-rmse:0.92982
#
# [8]	eval-rmse:0.953647	train-rmse:0.92933
#
# [9]	eval-rmse:0.953335	train-rmse:0.92889
#
# [10]	eval-rmse:0.953041	train-rmse:0.928479
#
# [11]	eval-rmse:0.95268	train-rmse:0.928095
#
# [12]	eval-rmse:0.952359	train-rmse:0.927733
#
# [13]	eval-rmse:0.952088	train-rmse:0.927398
#
# [14]	eval-rmse:0.951788	train-rmse:0.927087
#
# [15]	eval-rmse:0.951473	train-rmse:0.926821
#
# [16]	eval-rmse:0.951201	train-rmse:0.926573
#
# [17]	eval-rmse:0.950925	train-rmse:0.926279
#
# [18]	eval-rmse:0.950631	train-rmse:0.925988
#
# [19]	eval-rmse:0.950328	train-rmse:0.925707
#
# [20]	eval-rmse:0.950019	train-rmse:0.925405
#
# [21]	eval-rmse:0.949724	train-rmse:0.925082
#
# [22]	eval-rmse:0.949404	train-rmse:0.924727
#
# [23]	eval-rmse:0.949119	train-rmse:0.924344
#
# [0]	eval-rmse:0.954004	train-rmse:0.930436
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.952331	train-rmse:0.927944
#
# [2]	eval-rmse:0.950414	train-rmse:0.926015
#
# [3]	eval-rmse:0.948358	train-rmse:0.923822
#
# [4]	eval-rmse:0.946578	train-rmse:0.921716
#
# [5]	eval-rmse:0.944668	train-rmse:0.919717
#
# [6]	eval-rmse:0.942662	train-rmse:0.917703
#
# [7]	eval-rmse:0.940981	train-rmse:0.915732
#
# [8]	eval-rmse:0.939296	train-rmse:0.913877
#
# [9]	eval-rmse:0.93748	train-rmse:0.912116
#
# [10]	eval-rmse:0.935877	train-rmse:0.910282
#
# [11]	eval-rmse:0.934135	train-rmse:0.908424
#
# [12]	eval-rmse:0.932528	train-rmse:0.906621
#
# [13]	eval-rmse:0.930858	train-rmse:0.9048
#
# [14]	eval-rmse:0.929172	train-rmse:0.902902
#
# [15]	eval-rmse:0.927449	train-rmse:0.901139
#
# [16]	eval-rmse:0.926042	train-rmse:0.899503
#
# [17]	eval-rmse:0.924515	train-rmse:0.897823
#
# [18]	eval-rmse:0.923012	train-rmse:0.896129
#
# [19]	eval-rmse:0.92148	train-rmse:0.894563
#
# [20]	eval-rmse:0.919955	train-rmse:0.893023
#
# [21]	eval-rmse:0.918552	train-rmse:0.891419
#
# [22]	eval-rmse:0.916988	train-rmse:0.889763
#
# [23]	eval-rmse:0.915529	train-rmse:0.888208
#
# [24]	eval-rmse:0.914168	train-rmse:0.886662
#
# [25]	eval-rmse:0.912754	train-rmse:0.885167
#
# [0]	eval-rmse:0.953691	train-rmse:0.929645
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.951137	train-rmse:0.926718
#
# [2]	eval-rmse:0.948601	train-rmse:0.924024
#
# [3]	eval-rmse:0.946044	train-rmse:0.921282
#
# [4]	eval-rmse:0.943542	train-rmse:0.918726
#
# [5]	eval-rmse:0.941301	train-rmse:0.916034
#
# [6]	eval-rmse:0.938971	train-rmse:0.913548
#
# [7]	eval-rmse:0.936572	train-rmse:0.911145
#
# [8]	eval-rmse:0.934348	train-rmse:0.908831
#
# [9]	eval-rmse:0.932371	train-rmse:0.906489
#
# [10]	eval-rmse:0.93017	train-rmse:0.904118
#
# [11]	eval-rmse:0.928143	train-rmse:0.901739
#
# [12]	eval-rmse:0.926094	train-rmse:0.899469
#
# [13]	eval-rmse:0.924171	train-rmse:0.897183
#
# [14]	eval-rmse:0.922022	train-rmse:0.895078
#
# [15]	eval-rmse:0.920055	train-rmse:0.893065
#
# [16]	eval-rmse:0.918307	train-rmse:0.890991
#
# [17]	eval-rmse:0.916282	train-rmse:0.888897
#
# [18]	eval-rmse:0.914457	train-rmse:0.886869
#
# [19]	eval-rmse:0.912653	train-rmse:0.884887
#
# [20]	eval-rmse:0.910864	train-rmse:0.88297
#
# [21]	eval-rmse:0.909152	train-rmse:0.881081
# [22]	eval-rmse:0.90745	train-rmse:0.879195
#
# [23]	eval-rmse:0.905828	train-rmse:0.877319
#
# [24]	eval-rmse:0.904193	train-rmse:0.875472
#
# [25]	eval-rmse:0.902475	train-rmse:0.873735
#
# [26]	eval-rmse:0.900919	train-rmse:0.871972
#
# [27]	eval-rmse:0.899502	train-rmse:0.870267
#
# [28]	eval-rmse:0.897922	train-rmse:0.868582
#
# [29]	eval-rmse:0.896487	train-rmse:0.866952
#
# [0]	eval-rmse:0.953651	train-rmse:0.929681
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.95095	train-rmse:0.926546
#
# [2]	eval-rmse:0.948318	train-rmse:0.92387
#
# [3]	eval-rmse:0.945635	train-rmse:0.920992
#
# [4]	eval-rmse:0.943196	train-rmse:0.918372
#
# [5]	eval-rmse:0.940782	train-rmse:0.915601
#
# [6]	eval-rmse:0.938373	train-rmse:0.913042
#
# [7]	eval-rmse:0.935888	train-rmse:0.910551
#
# [8]	eval-rmse:0.933762	train-rmse:0.908123
#
# [9]	eval-rmse:0.931607	train-rmse:0.905711
#
# [10]	eval-rmse:0.929435	train-rmse:0.903267
#
# [11]	eval-rmse:0.927355	train-rmse:0.900877
#
# [12]	eval-rmse:0.925356	train-rmse:0.898491
#
# [13]	eval-rmse:0.923215	train-rmse:0.896183
#
# [14]	eval-rmse:0.921189	train-rmse:0.894015
#
# [15]	eval-rmse:0.919115	train-rmse:0.891896
#
# [16]	eval-rmse:0.917154	train-rmse:0.889796
#
# [17]	eval-rmse:0.915354	train-rmse:0.887644
#
# [18]	eval-rmse:0.913441	train-rmse:0.885559
#
# [19]	eval-rmse:0.911598	train-rmse:0.883545
#
# [20]	eval-rmse:0.909854	train-rmse:0.881596
#
# [21]	eval-rmse:0.907959	train-rmse:0.879626
#
# [22]	eval-rmse:0.906295	train-rmse:0.877701
#
# [23]	eval-rmse:0.904667	train-rmse:0.875816
#
# [24]	eval-rmse:0.903016	train-rmse:0.873925
#
# [25]	eval-rmse:0.901311	train-rmse:0.872127
#
# [26]	eval-rmse:0.899731	train-rmse:0.870336
#
# [27]	eval-rmse:0.898238	train-rmse:0.868608
#
# [28]	eval-rmse:0.896639	train-rmse:0.866861
#
# [29]	eval-rmse:0.89526	train-rmse:0.865168
#
# [0]	eval-rmse:0.954997	train-rmse:0.931083
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.95416	train-rmse:0.929526
#
# [2]	eval-rmse:0.952919	train-rmse:0.927789
#
# [3]	eval-rmse:0.951841	train-rmse:0.926487
#
# [4]	eval-rmse:0.950796	train-rmse:0.925087
#
# [5]	eval-rmse:0.949806	train-rmse:0.923506
#
# [6]	eval-rmse:0.948704	train-rmse:0.921971
#
# [7]	eval-rmse:0.94771	train-rmse:0.920551
#
# [8]	eval-rmse:0.946633	train-rmse:0.919191
#
# [9]	eval-rmse:0.94546	train-rmse:0.917763
#
# [10]	eval-rmse:0.944467	train-rmse:0.91635
#
# [11]	eval-rmse:0.943371	train-rmse:0.915019
#
# [12]	eval-rmse:0.942399	train-rmse:0.913678
#
# [13]	eval-rmse:0.941382	train-rmse:0.912366
#
# [14]	eval-rmse:0.940303	train-rmse:0.911046
#
# [15]	eval-rmse:0.939279	train-rmse:0.909721
#
# [16]	eval-rmse:0.938315	train-rmse:0.90842
#
# [17]	eval-rmse:0.937242	train-rmse:0.907108
#
# [18]	eval-rmse:0.936344	train-rmse:0.905788
#
# [19]	eval-rmse:0.935298	train-rmse:0.904458
#
# [20]	eval-rmse:0.934319	train-rmse:0.903182
#
# [21]	eval-rmse:0.933345	train-rmse:0.901876
#
# [22]	eval-rmse:0.932443	train-rmse:0.900568
#
# [23]	eval-rmse:0.931513	train-rmse:0.899279
#
# [24]	eval-rmse:0.930652	train-rmse:0.897974
#
# [25]	eval-rmse:0.929732	train-rmse:0.896698
#
# [26]	eval-rmse:0.928831	train-rmse:0.895423
#
# [27]	eval-rmse:0.92799	train-rmse:0.894197
#
# [28]	eval-rmse:0.927026	train-rmse:0.892939
#
# [29]	eval-rmse:0.926168	train-rmse:0.891723
#
# [30]	eval-rmse:0.925232	train-rmse:0.890472
#
# [31]	eval-rmse:0.924357	train-rmse:0.889237
#
# [32]	eval-rmse:0.923495	train-rmse:0.888022
#
# [33]	eval-rmse:0.922647	train-rmse:0.886819
#
# [34]	eval-rmse:0.921816	train-rmse:0.88561
#
# [35]	eval-rmse:0.920987	train-rmse:0.884414
#
# [36]	eval-rmse:0.920067	train-rmse:0.883244
#
# [37]	eval-rmse:0.919273	train-rmse:0.882071
#
# [38]	eval-rmse:0.918382	train-rmse:0.880933
#
# [0]	eval-rmse:0.954124	train-rmse:0.929128
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.951882	train-rmse:0.926118
#
# [2]	eval-rmse:0.949689	train-rmse:0.922876
#
# [3]	eval-rmse:0.947327	train-rmse:0.919881
#
# [4]	eval-rmse:0.94528	train-rmse:0.916857
#
# [5]	eval-rmse:0.943217	train-rmse:0.913902
#
# [6]	eval-rmse:0.941173	train-rmse:0.911007
#
# [7]	eval-rmse:0.939127	train-rmse:0.908164
#
# [8]	eval-rmse:0.937152	train-rmse:0.905379
#
# [9]	eval-rmse:0.935284	train-rmse:0.902597
#
# [10]	eval-rmse:0.933506	train-rmse:0.899912
#
# [11]	eval-rmse:0.931201	train-rmse:0.897188
#
# [12]	eval-rmse:0.929348	train-rmse:0.894533
#
# [13]	eval-rmse:0.927516	train-rmse:0.891886
# [14]	eval-rmse:0.925634	train-rmse:0.889295
#
# [15]	eval-rmse:0.92379	train-rmse:0.886836
#
# [16]	eval-rmse:0.921939	train-rmse:0.884399
#
# [17]	eval-rmse:0.920237	train-rmse:0.881871
#
# [18]	eval-rmse:0.918652	train-rmse:0.879373
#
# [19]	eval-rmse:0.916798	train-rmse:0.876919
#
# [20]	eval-rmse:0.915151	train-rmse:0.874572
#
# [21]	eval-rmse:0.913539	train-rmse:0.872188
#
# [22]	eval-rmse:0.912014	train-rmse:0.869761
#
# [23]	eval-rmse:0.910413	train-rmse:0.867382
#
# [24]	eval-rmse:0.908889	train-rmse:0.865071
#
# [25]	eval-rmse:0.907259	train-rmse:0.862838
#
# [26]	eval-rmse:0.90591	train-rmse:0.860585
#
# [27]	eval-rmse:0.904619	train-rmse:0.858398
#
# [28]	eval-rmse:0.90313	train-rmse:0.85613
#
# [29]	eval-rmse:0.901914	train-rmse:0.853966
#
# [0]	eval-rmse:0.954746	train-rmse:0.931027
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.953718	train-rmse:0.929252
#
# [2]	eval-rmse:0.952256	train-rmse:0.927532
#
# [3]	eval-rmse:0.950973	train-rmse:0.926109
#
# [4]	eval-rmse:0.94973	train-rmse:0.92459
#
# [5]	eval-rmse:0.948391	train-rmse:0.922912
#
# [6]	eval-rmse:0.947126	train-rmse:0.921361
#
# [7]	eval-rmse:0.945847	train-rmse:0.919935
#
# [8]	eval-rmse:0.94456	train-rmse:0.918477
#
# [9]	eval-rmse:0.943272	train-rmse:0.916966
#
# [10]	eval-rmse:0.942034	train-rmse:0.915527
#
# [11]	eval-rmse:0.940803	train-rmse:0.914159
#
# [12]	eval-rmse:0.939594	train-rmse:0.912772
#
# [13]	eval-rmse:0.938395	train-rmse:0.911379
#
# [14]	eval-rmse:0.937202	train-rmse:0.91
#
# [15]	eval-rmse:0.935971	train-rmse:0.908651
#
# [16]	eval-rmse:0.934794	train-rmse:0.90733
#
# [17]	eval-rmse:0.933735	train-rmse:0.905956
#
# [18]	eval-rmse:0.932639	train-rmse:0.904539
#
# [19]	eval-rmse:0.931401	train-rmse:0.903185
#
# [20]	eval-rmse:0.930259	train-rmse:0.901841
#
# [21]	eval-rmse:0.929152	train-rmse:0.900486
#
# [22]	eval-rmse:0.928034	train-rmse:0.899164
#
# [23]	eval-rmse:0.926921	train-rmse:0.897845
#
# [24]	eval-rmse:0.92591	train-rmse:0.896566
#
# [25]	eval-rmse:0.924827	train-rmse:0.895335
#
# [26]	eval-rmse:0.92377	train-rmse:0.894088
#
# [27]	eval-rmse:0.922781	train-rmse:0.892849
#
# [28]	eval-rmse:0.921784	train-rmse:0.891591
#
# [29]	eval-rmse:0.920854	train-rmse:0.89038
#
# [30]	eval-rmse:0.919809	train-rmse:0.889116
#
# [31]	eval-rmse:0.918782	train-rmse:0.887902
#
# [32]	eval-rmse:0.917834	train-rmse:0.886714
#
# [0]	eval-rmse:0.955799	train-rmse:0.931855
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.954382	train-rmse:0.930545
#
# [2]	eval-rmse:0.953671	train-rmse:0.929237
#
# [3]	eval-rmse:0.952658	train-rmse:0.928062
#
# [4]	eval-rmse:0.951815	train-rmse:0.927072
#
# [5]	eval-rmse:0.950909	train-rmse:0.926183
#
# [6]	eval-rmse:0.950082	train-rmse:0.92522
#
# [7]	eval-rmse:0.949176	train-rmse:0.9242
#
# [8]	eval-rmse:0.948339	train-rmse:0.923089
#
# [9]	eval-rmse:0.94741	train-rmse:0.922079
#
# [10]	eval-rmse:0.946556	train-rmse:0.921115
#
# [11]	eval-rmse:0.945669	train-rmse:0.920202
#
# [12]	eval-rmse:0.944843	train-rmse:0.919217
#
# [13]	eval-rmse:0.944013	train-rmse:0.918244
#
# [14]	eval-rmse:0.943161	train-rmse:0.917233
#
# [15]	eval-rmse:0.942322	train-rmse:0.916239
#
# [16]	eval-rmse:0.94146	train-rmse:0.915325
#
# [17]	eval-rmse:0.940676	train-rmse:0.9144
#
# [18]	eval-rmse:0.939914	train-rmse:0.913485
#
# [19]	eval-rmse:0.9391	train-rmse:0.912609
#
# [20]	eval-rmse:0.93831	train-rmse:0.911727
#
# [21]	eval-rmse:0.93745	train-rmse:0.910817
#
# [22]	eval-rmse:0.936626	train-rmse:0.909909
#
# [23]	eval-rmse:0.935834	train-rmse:0.909014
#
# [24]	eval-rmse:0.935063	train-rmse:0.908131
#
# [25]	eval-rmse:0.934296	train-rmse:0.907254
#
# [26]	eval-rmse:0.933532	train-rmse:0.906359
#
# [27]	eval-rmse:0.932822	train-rmse:0.905466
#
# [28]	eval-rmse:0.932064	train-rmse:0.904525
#
# [29]	eval-rmse:0.931298	train-rmse:0.903647
#
# [30]	eval-rmse:0.930529	train-rmse:0.902737
#
# [31]	eval-rmse:0.929743	train-rmse:0.901862
#
# [32]	eval-rmse:0.929062	train-rmse:0.900991
#
# [0]	eval-rmse:0.954374	train-rmse:0.930197
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.952535	train-rmse:0.927412
#
# [2]	eval-rmse:0.950723	train-rmse:0.925178
#
# [3]	eval-rmse:0.948935	train-rmse:0.922654
#
# [4]	eval-rmse:0.947248	train-rmse:0.920316
#
# [5]	eval-rmse:0.945585	train-rmse:0.917975
#
# [6]	eval-rmse:0.943791	train-rmse:0.915616
#
# [7]	eval-rmse:0.942186	train-rmse:0.913353
# [8]	eval-rmse:0.940482	train-rmse:0.911229
#
# [9]	eval-rmse:0.938684	train-rmse:0.909012
#
# [10]	eval-rmse:0.937166	train-rmse:0.9069
#
# [11]	eval-rmse:0.935419	train-rmse:0.904802
#
# [12]	eval-rmse:0.93396	train-rmse:0.902653
#
# [13]	eval-rmse:0.932458	train-rmse:0.900492
#
# [14]	eval-rmse:0.930935	train-rmse:0.898421
#
# [15]	eval-rmse:0.929358	train-rmse:0.896411
#
# [16]	eval-rmse:0.927872	train-rmse:0.894456
#
# [17]	eval-rmse:0.926322	train-rmse:0.892466
#
# [18]	eval-rmse:0.924872	train-rmse:0.890429
#
# [19]	eval-rmse:0.923149	train-rmse:0.888404
#
# [20]	eval-rmse:0.921709	train-rmse:0.886501
#
# [21]	eval-rmse:0.920323	train-rmse:0.884569
#
# [22]	eval-rmse:0.918899	train-rmse:0.88259
#
# [23]	eval-rmse:0.917529	train-rmse:0.880713
#
# [24]	eval-rmse:0.916276	train-rmse:0.878804
#
# [25]	eval-rmse:0.914874	train-rmse:0.876972
#
# [26]	eval-rmse:0.913621	train-rmse:0.875098
#
# [27]	eval-rmse:0.912365	train-rmse:0.873298
#
# [28]	eval-rmse:0.911126	train-rmse:0.871404
#
# [29]	eval-rmse:0.90992	train-rmse:0.869627
#
# [30]	eval-rmse:0.90871	train-rmse:0.86779
#
# [31]	eval-rmse:0.907427	train-rmse:0.866011
#
# [32]	eval-rmse:0.90622	train-rmse:0.864294
#
# [0]	eval-rmse:0.955812	train-rmse:0.931977
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.954841	train-rmse:0.931015
#
# [2]	eval-rmse:0.954154	train-rmse:0.930294
#
# [3]	eval-rmse:0.95363	train-rmse:0.929196
#
# [4]	eval-rmse:0.952954	train-rmse:0.928321
#
# [5]	eval-rmse:0.952235	train-rmse:0.927484
#
# [6]	eval-rmse:0.951621	train-rmse:0.926852
#
# [7]	eval-rmse:0.950933	train-rmse:0.926188
#
# [8]	eval-rmse:0.95032	train-rmse:0.925507
#
# [9]	eval-rmse:0.949635	train-rmse:0.924719
#
# [10]	eval-rmse:0.948987	train-rmse:0.923914
#
# [11]	eval-rmse:0.948329	train-rmse:0.923113
#
# [12]	eval-rmse:0.947727	train-rmse:0.922282
#
# [13]	eval-rmse:0.947122	train-rmse:0.921546
#
# [14]	eval-rmse:0.946426	train-rmse:0.920835
#
# [15]	eval-rmse:0.94584	train-rmse:0.920119
#
# [16]	eval-rmse:0.945187	train-rmse:0.919396
#
# [17]	eval-rmse:0.944556	train-rmse:0.918645
#
# [18]	eval-rmse:0.943955	train-rmse:0.917887
#
# [19]	eval-rmse:0.943319	train-rmse:0.917138
#
# [20]	eval-rmse:0.942703	train-rmse:0.916392
#
# [21]	eval-rmse:0.942044	train-rmse:0.915677
#
# [22]	eval-rmse:0.941408	train-rmse:0.914983
#
# [23]	eval-rmse:0.940795	train-rmse:0.914296
#
# [24]	eval-rmse:0.940191	train-rmse:0.913611
#
# [25]	eval-rmse:0.939623	train-rmse:0.912945
#
# [26]	eval-rmse:0.939008	train-rmse:0.912272
#
# [27]	eval-rmse:0.938385	train-rmse:0.911601
#
# [28]	eval-rmse:0.937796	train-rmse:0.91092
#
# [29]	eval-rmse:0.937214	train-rmse:0.910247
#
# [30]	eval-rmse:0.936617	train-rmse:0.909562
#
# [31]	eval-rmse:0.936037	train-rmse:0.908907
#
# [32]	eval-rmse:0.935474	train-rmse:0.908228
#
# [33]	eval-rmse:0.934843	train-rmse:0.907545
#
# [34]	eval-rmse:0.934306	train-rmse:0.906895
#
# [35]	eval-rmse:0.933735	train-rmse:0.906227
#
# [0]	eval-rmse:0.95436	train-rmse:0.930494
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.952851	train-rmse:0.928128
#
# [2]	eval-rmse:0.951108	train-rmse:0.926087
#
# [3]	eval-rmse:0.949435	train-rmse:0.923967
#
# [4]	eval-rmse:0.947887	train-rmse:0.921909
#
# [5]	eval-rmse:0.946187	train-rmse:0.919908
#
# [6]	eval-rmse:0.944558	train-rmse:0.917869
#
# [7]	eval-rmse:0.942818	train-rmse:0.915918
#
# [8]	eval-rmse:0.941246	train-rmse:0.914036
#
# [9]	eval-rmse:0.939592	train-rmse:0.912135
#
# [10]	eval-rmse:0.938098	train-rmse:0.91033
#
# [11]	eval-rmse:0.936537	train-rmse:0.908559
#
# [12]	eval-rmse:0.935051	train-rmse:0.906697
#
# [13]	eval-rmse:0.933598	train-rmse:0.904828
#
# [14]	eval-rmse:0.932137	train-rmse:0.902992
#
# [15]	eval-rmse:0.930614	train-rmse:0.901217
#
# [16]	eval-rmse:0.929105	train-rmse:0.899491
#
# [17]	eval-rmse:0.927795	train-rmse:0.897687
#
# [18]	eval-rmse:0.926446	train-rmse:0.895951
#
# [19]	eval-rmse:0.92496	train-rmse:0.894246
#
# [20]	eval-rmse:0.92364	train-rmse:0.892604
#
# [21]	eval-rmse:0.922288	train-rmse:0.890915
#
# [22]	eval-rmse:0.920814	train-rmse:0.889232
#
# [23]	eval-rmse:0.919537	train-rmse:0.887542
#
# [24]	eval-rmse:0.918267	train-rmse:0.885916
#
# [25]	eval-rmse:0.916987	train-rmse:0.884325
#
# [26]	eval-rmse:0.915754	train-rmse:0.882712
#
# [27]	eval-rmse:0.914642	train-rmse:0.881147
#
# [28]	eval-rmse:0.913385	train-rmse:0.87958
#
# [29]	eval-rmse:0.912226	train-rmse:0.878079
# [30]	eval-rmse:0.91086	train-rmse:0.876513
#
# [31]	eval-rmse:0.909636	train-rmse:0.875004
#
# [32]	eval-rmse:0.90856	train-rmse:0.87353
#
# [33]	eval-rmse:0.907414	train-rmse:0.872087
#
# [0]	eval-rmse:0.954117	train-rmse:0.930414
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.952296	train-rmse:0.927796
#
# [2]	eval-rmse:0.950253	train-rmse:0.925694
#
# [3]	eval-rmse:0.948292	train-rmse:0.923453
#
# [4]	eval-rmse:0.946414	train-rmse:0.921269
#
# [5]	eval-rmse:0.944635	train-rmse:0.919208
#
# [6]	eval-rmse:0.942762	train-rmse:0.91705
#
# [7]	eval-rmse:0.940912	train-rmse:0.914921
#
# [8]	eval-rmse:0.939253	train-rmse:0.912994
#
# [9]	eval-rmse:0.937498	train-rmse:0.911035
#
# [10]	eval-rmse:0.935714	train-rmse:0.909131
#
# [11]	eval-rmse:0.93392	train-rmse:0.90724
#
# [12]	eval-rmse:0.93236	train-rmse:0.905291
#
# [13]	eval-rmse:0.930553	train-rmse:0.903355
#
# [14]	eval-rmse:0.928889	train-rmse:0.901448
#
# [15]	eval-rmse:0.927284	train-rmse:0.899607
#
# [16]	eval-rmse:0.925815	train-rmse:0.897838
#
# [17]	eval-rmse:0.924212	train-rmse:0.896036
#
# [18]	eval-rmse:0.922663	train-rmse:0.894251
#
# [19]	eval-rmse:0.921101	train-rmse:0.892511
#
# [20]	eval-rmse:0.919571	train-rmse:0.890855
#
# [21]	eval-rmse:0.918025	train-rmse:0.889163
#
# [22]	eval-rmse:0.9165	train-rmse:0.887471
#
# [23]	eval-rmse:0.91502	train-rmse:0.885824
#
# [24]	eval-rmse:0.913704	train-rmse:0.88416
#
# [25]	eval-rmse:0.912352	train-rmse:0.88256
#
# [26]	eval-rmse:0.910972	train-rmse:0.880944
#
# [27]	eval-rmse:0.909562	train-rmse:0.879349
#
# [28]	eval-rmse:0.908332	train-rmse:0.877782
#
# [29]	eval-rmse:0.906999	train-rmse:0.876245
#
# [30]	eval-rmse:0.905637	train-rmse:0.874721
#
# [31]	eval-rmse:0.904327	train-rmse:0.873257
#
# [32]	eval-rmse:0.903014	train-rmse:0.871793
#
# [33]	eval-rmse:0.901785	train-rmse:0.87038
#
# [0]	eval-rmse:0.954444	train-rmse:0.930741
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.952915	train-rmse:0.928503
#
# [2]	eval-rmse:0.951272	train-rmse:0.926613
#
# [3]	eval-rmse:0.949643	train-rmse:0.924987
#
# [4]	eval-rmse:0.947996	train-rmse:0.922914
#
# [5]	eval-rmse:0.946455	train-rmse:0.921163
#
# [6]	eval-rmse:0.944894	train-rmse:0.919442
#
# [7]	eval-rmse:0.943239	train-rmse:0.917574
#
# [8]	eval-rmse:0.941713	train-rmse:0.915857
#
# [9]	eval-rmse:0.940126	train-rmse:0.914196
#
# [10]	eval-rmse:0.938776	train-rmse:0.912629
#
# [11]	eval-rmse:0.937245	train-rmse:0.910965
#
# [12]	eval-rmse:0.935741	train-rmse:0.909357
#
# [13]	eval-rmse:0.934269	train-rmse:0.907724
#
# [14]	eval-rmse:0.932916	train-rmse:0.906135
#
# [15]	eval-rmse:0.931472	train-rmse:0.904503
#
# [16]	eval-rmse:0.930168	train-rmse:0.902888
#
# [0]	eval-rmse:0.953881	train-rmse:0.930027
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.951676	train-rmse:0.927102
#
# [2]	eval-rmse:0.949352	train-rmse:0.924671
#
# [3]	eval-rmse:0.947138	train-rmse:0.921988
#
# [4]	eval-rmse:0.944952	train-rmse:0.919592
#
# [5]	eval-rmse:0.942843	train-rmse:0.917143
#
# [6]	eval-rmse:0.940773	train-rmse:0.914676
#
# [7]	eval-rmse:0.938739	train-rmse:0.912377
#
# [8]	eval-rmse:0.93695	train-rmse:0.910162
#
# [9]	eval-rmse:0.934713	train-rmse:0.907932
#
# [10]	eval-rmse:0.932846	train-rmse:0.905701
#
# [11]	eval-rmse:0.930781	train-rmse:0.903517
#
# [12]	eval-rmse:0.928882	train-rmse:0.901307
#
# [13]	eval-rmse:0.927001	train-rmse:0.89913
#
# [0]	eval-rmse:0.955538	train-rmse:0.931743
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.953898	train-rmse:0.930388
#
# [2]	eval-rmse:0.953273	train-rmse:0.928947
#
# [3]	eval-rmse:0.952062	train-rmse:0.927662
#
# [4]	eval-rmse:0.951109	train-rmse:0.926817
#
# [5]	eval-rmse:0.950055	train-rmse:0.925838
#
# [6]	eval-rmse:0.948907	train-rmse:0.92482
#
# [7]	eval-rmse:0.948056	train-rmse:0.923542
#
# [8]	eval-rmse:0.947102	train-rmse:0.922351
#
# [9]	eval-rmse:0.946099	train-rmse:0.921391
#
# [10]	eval-rmse:0.945175	train-rmse:0.920391
#
# [11]	eval-rmse:0.944229	train-rmse:0.919434
#
# [12]	eval-rmse:0.943169	train-rmse:0.918413
#
# [0]	eval-rmse:0.955997	train-rmse:0.932042
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.955371	train-rmse:0.9314
#
# [2]	eval-rmse:0.954728	train-rmse:0.930636
# [3]	eval-rmse:0.954316	train-rmse:0.929923
#
# [4]	eval-rmse:0.953886	train-rmse:0.929045
#
# [5]	eval-rmse:0.953361	train-rmse:0.928228
#
# [6]	eval-rmse:0.952882	train-rmse:0.927472
#
# [7]	eval-rmse:0.952413	train-rmse:0.926843
#
# [8]	eval-rmse:0.951968	train-rmse:0.926272
#
# [9]	eval-rmse:0.951439	train-rmse:0.925694
#
# [10]	eval-rmse:0.950993	train-rmse:0.925085
#
# [11]	eval-rmse:0.950505	train-rmse:0.924428
#
# [12]	eval-rmse:0.950009	train-rmse:0.923717
#
# [13]	eval-rmse:0.949584	train-rmse:0.922993
#
# [14]	eval-rmse:0.949095	train-rmse:0.922274
#
# [15]	eval-rmse:0.948612	train-rmse:0.921606
#
# [16]	eval-rmse:0.948134	train-rmse:0.920982
#
# [17]	eval-rmse:0.947636	train-rmse:0.920346
#
# [18]	eval-rmse:0.947158	train-rmse:0.919716
#
# [19]	eval-rmse:0.946632	train-rmse:0.919094
#
# [20]	eval-rmse:0.94614	train-rmse:0.91848
#
# [21]	eval-rmse:0.94569	train-rmse:0.917829
#
# [22]	eval-rmse:0.945212	train-rmse:0.917164
#
# [23]	eval-rmse:0.944729	train-rmse:0.916504
#
# [24]	eval-rmse:0.944282	train-rmse:0.91586
#
# [25]	eval-rmse:0.943784	train-rmse:0.915231
#
# [26]	eval-rmse:0.943348	train-rmse:0.9146
#
# [27]	eval-rmse:0.94287	train-rmse:0.913978
#
# [28]	eval-rmse:0.942432	train-rmse:0.91334
#
# [29]	eval-rmse:0.942	train-rmse:0.91274
#
# [30]	eval-rmse:0.941566	train-rmse:0.912113
#
# [31]	eval-rmse:0.94112	train-rmse:0.911512
#
# [32]	eval-rmse:0.940635	train-rmse:0.910898
#
# [33]	eval-rmse:0.94018	train-rmse:0.910287
#
# [34]	eval-rmse:0.939726	train-rmse:0.909681
#
# [35]	eval-rmse:0.939293	train-rmse:0.90906
#
# [36]	eval-rmse:0.938823	train-rmse:0.908457
#
# [0]	eval-rmse:0.954394	train-rmse:0.930711
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.953003	train-rmse:0.928549
#
# [2]	eval-rmse:0.951227	train-rmse:0.926764
#
# [3]	eval-rmse:0.949575	train-rmse:0.925053
#
# [4]	eval-rmse:0.947883	train-rmse:0.9231
#
# [5]	eval-rmse:0.946259	train-rmse:0.921306
#
# [6]	eval-rmse:0.94464	train-rmse:0.919597
#
# [7]	eval-rmse:0.942969	train-rmse:0.917844
#
# [8]	eval-rmse:0.941473	train-rmse:0.916102
#
# [9]	eval-rmse:0.939939	train-rmse:0.914449
#
# [10]	eval-rmse:0.938418	train-rmse:0.912849
#
# [11]	eval-rmse:0.936878	train-rmse:0.91129
#
# [12]	eval-rmse:0.935416	train-rmse:0.909653
#
# [13]	eval-rmse:0.934003	train-rmse:0.908065
#
# [14]	eval-rmse:0.93248	train-rmse:0.906482
#
# [15]	eval-rmse:0.93101	train-rmse:0.904898
#
# [16]	eval-rmse:0.929602	train-rmse:0.903356
#
# [17]	eval-rmse:0.928233	train-rmse:0.901727
#
# [18]	eval-rmse:0.926778	train-rmse:0.9002
#
# [19]	eval-rmse:0.925374	train-rmse:0.898695
#
# [20]	eval-rmse:0.923988	train-rmse:0.897229
#
# [21]	eval-rmse:0.922657	train-rmse:0.895785
#
# [22]	eval-rmse:0.921341	train-rmse:0.894341
#
# [23]	eval-rmse:0.919943	train-rmse:0.892909
#
# [24]	eval-rmse:0.91867	train-rmse:0.891484
#
# [25]	eval-rmse:0.917513	train-rmse:0.890121
#
# [26]	eval-rmse:0.916255	train-rmse:0.888697
#
# [27]	eval-rmse:0.91504	train-rmse:0.887336
#
# [28]	eval-rmse:0.913769	train-rmse:0.885982
#
# [29]	eval-rmse:0.91254	train-rmse:0.88464
#
# [30]	eval-rmse:0.911308	train-rmse:0.883316
#
# [31]	eval-rmse:0.91014	train-rmse:0.882021
#
# [32]	eval-rmse:0.909019	train-rmse:0.880739
#
# [33]	eval-rmse:0.907831	train-rmse:0.879473
#
# [0]	eval-rmse:0.954636	train-rmse:0.930204
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.95307	train-rmse:0.927446
#
# [2]	eval-rmse:0.95154	train-rmse:0.924974
#
# [3]	eval-rmse:0.950057	train-rmse:0.922437
#
# [4]	eval-rmse:0.948614	train-rmse:0.920018
#
# [5]	eval-rmse:0.947226	train-rmse:0.917593
#
# [6]	eval-rmse:0.945759	train-rmse:0.915209
#
# [7]	eval-rmse:0.944317	train-rmse:0.912836
#
# [8]	eval-rmse:0.94291	train-rmse:0.910565
#
# [9]	eval-rmse:0.94127	train-rmse:0.908189
#
# [10]	eval-rmse:0.93996	train-rmse:0.905933
#
# [11]	eval-rmse:0.938383	train-rmse:0.903753
#
# [12]	eval-rmse:0.937082	train-rmse:0.901488
#
# [13]	eval-rmse:0.935836	train-rmse:0.899211
#
# ...
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.952893	train-rmse:0.928146
#
# [2]	eval-rmse:0.951165	train-rmse:0.926039
#
# [3]	eval-rmse:0.949492	train-rmse:0.923994
#
# [4]	eval-rmse:0.947868	train-rmse:0.921831
#
# [5]	eval-rmse:0.946269	train-rmse:0.919812
#
# [6]	eval-rmse:0.944694	train-rmse:0.91781
#
# [7]	eval-rmse:0.943036	train-rmse:0.915763
#
# [8]	eval-rmse:0.941493	train-rmse:0.913841
#
# [9]	eval-rmse:0.939905	train-rmse:0.911914
#
# [10]	eval-rmse:0.938401	train-rmse:0.910043
#
# [11]	eval-rmse:0.936844	train-rmse:0.908236
#
# [12]	eval-rmse:0.935382	train-rmse:0.906393
#
# [13]	eval-rmse:0.933927	train-rmse:0.904537
#
# [14]	eval-rmse:0.932434	train-rmse:0.902685
#
# [15]	eval-rmse:0.931098	train-rmse:0.900916
#
# [16]	eval-rmse:0.929602	train-rmse:0.89913
#
# [17]	eval-rmse:0.928291	train-rmse:0.897337
#
# [18]	eval-rmse:0.926952	train-rmse:0.895522
#
# [19]	eval-rmse:0.925501	train-rmse:0.893751
#
# [20]	eval-rmse:0.924099	train-rmse:0.892092
#
# [21]	eval-rmse:0.922729	train-rmse:0.890387
#
# [22]	eval-rmse:0.921451	train-rmse:0.88868
#
# [23]	eval-rmse:0.920079	train-rmse:0.886982
#
# [24]	eval-rmse:0.918864	train-rmse:0.885311
#
# [25]	eval-rmse:0.917497	train-rmse:0.883676
#
# [26]	eval-rmse:0.916295	train-rmse:0.882022
#
# [0]	eval-rmse:0.954422	train-rmse:0.930666
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.953015	train-rmse:0.928363
#
# [2]	eval-rmse:0.951386	train-rmse:0.926505
#
# [3]	eval-rmse:0.94981	train-rmse:0.924684
#
# [4]	eval-rmse:0.94824	train-rmse:0.922627
#
# [5]	eval-rmse:0.946714	train-rmse:0.920751
#
# [6]	eval-rmse:0.945121	train-rmse:0.918972
# [7]	eval-rmse:0.943533	train-rmse:0.917033
#
# [8]	eval-rmse:0.942054	train-rmse:0.915268
#
# [9]	eval-rmse:0.940511	train-rmse:0.913507
#
# [10]	eval-rmse:0.939107	train-rmse:0.911863
#
# [11]	eval-rmse:0.937559	train-rmse:0.910164
#
# [12]	eval-rmse:0.936152	train-rmse:0.908496
#
# [13]	eval-rmse:0.93457	train-rmse:0.906837
#
# [14]	eval-rmse:0.933142	train-rmse:0.905154
#
# [15]	eval-rmse:0.931717	train-rmse:0.903478
#
# [16]	eval-rmse:0.930327	train-rmse:0.901864
#
# [17]	eval-rmse:0.928905	train-rmse:0.900232
#
# [18]	eval-rmse:0.927604	train-rmse:0.898553
#
# [19]	eval-rmse:0.92617	train-rmse:0.896922
#
# [20]	eval-rmse:0.924769	train-rmse:0.895393
#
# [21]	eval-rmse:0.923441	train-rmse:0.893881
#
# [22]	eval-rmse:0.922176	train-rmse:0.89233
#
# [23]	eval-rmse:0.920878	train-rmse:0.890798
#
# [24]	eval-rmse:0.919648	train-rmse:0.889284
#
# [25]	eval-rmse:0.918381	train-rmse:0.887816
#
# [26]	eval-rmse:0.917193	train-rmse:0.886342
#
# [0]	eval-rmse:0.954042	train-rmse:0.930104
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.951963	train-rmse:0.927356
#
# [2]	eval-rmse:0.949769	train-rmse:0.925057
#
# [3]	eval-rmse:0.947527	train-rmse:0.922384
#
# [4]	eval-rmse:0.945503	train-rmse:0.920189
#
# [5]	eval-rmse:0.94344	train-rmse:0.917761
#
# [6]	eval-rmse:0.941488	train-rmse:0.915466
#
# [7]	eval-rmse:0.939453	train-rmse:0.913282
#
# [8]	eval-rmse:0.937528	train-rmse:0.911221
#
# [9]	eval-rmse:0.935445	train-rmse:0.909049
#
# [10]	eval-rmse:0.933779	train-rmse:0.906951
#
# [11]	eval-rmse:0.931913	train-rmse:0.904799
#
# [12]	eval-rmse:0.930106	train-rmse:0.902642
#
# [13]	eval-rmse:0.928278	train-rmse:0.900536
#
# [14]	eval-rmse:0.926489	train-rmse:0.89852
#
# [15]	eval-rmse:0.924664	train-rmse:0.89652
#
# [0]	eval-rmse:0.954022	train-rmse:0.930079
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.952115	train-rmse:0.927328
#
# [2]	eval-rmse:0.950029	train-rmse:0.924862
#
# [3]	eval-rmse:0.948032	train-rmse:0.922323
#
# [4]	eval-rmse:0.946122	train-rmse:0.919954
#
# [5]	eval-rmse:0.944213	train-rmse:0.917599
#
# [6]	eval-rmse:0.942544	train-rmse:0.915215
#
# [7]	eval-rmse:0.940645	train-rmse:0.912902
#
# [8]	eval-rmse:0.938807	train-rmse:0.910682
#
# [9]	eval-rmse:0.936807	train-rmse:0.908458
#
# [10]	eval-rmse:0.935045	train-rmse:0.906289
#
# [11]	eval-rmse:0.933319	train-rmse:0.904207
#
# [12]	eval-rmse:0.931511	train-rmse:0.902005
#
# [13]	eval-rmse:0.929888	train-rmse:0.899813
#
# [14]	eval-rmse:0.928142	train-rmse:0.897677
#
# [15]	eval-rmse:0.926409	train-rmse:0.895667
#
# [16]	eval-rmse:0.924754	train-rmse:0.893716
#
# [17]	eval-rmse:0.923046	train-rmse:0.89168
#
# [18]	eval-rmse:0.921556	train-rmse:0.889637
#
# [19]	eval-rmse:0.919918	train-rmse:0.887637
#
# [20]	eval-rmse:0.918383	train-rmse:0.885722
#
# [21]	eval-rmse:0.916973	train-rmse:0.883762
#
# [22]	eval-rmse:0.91559	train-rmse:0.881822
#
# [23]	eval-rmse:0.914106	train-rmse:0.879929
#
# [24]	eval-rmse:0.912696	train-rmse:0.878055
#
# [25]	eval-rmse:0.911227	train-rmse:0.876224
#
# [26]	eval-rmse:0.909854	train-rmse:0.874363
#
# [0]	eval-rmse:0.955161	train-rmse:0.931393
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.953776	train-rmse:0.930037
#
# [2]	eval-rmse:0.9526	train-rmse:0.928249
#
# [3]	eval-rmse:0.951393	train-rmse:0.926973
#
# [4]	eval-rmse:0.95034	train-rmse:0.925864
#
# [5]	eval-rmse:0.949044	train-rmse:0.924624
#
# [6]	eval-rmse:0.947716	train-rmse:0.923142
#
# [7]	eval-rmse:0.946533	train-rmse:0.92186
#
# [8]	eval-rmse:0.945379	train-rmse:0.920685
#
# [9]	eval-rmse:0.944216	train-rmse:0.91948
#
# [10]	eval-rmse:0.943021	train-rmse:0.918271
#
# [11]	eval-rmse:0.94181	train-rmse:0.917047
#
# [12]	eval-rmse:0.940766	train-rmse:0.915786
#
# [13]	eval-rmse:0.939796	train-rmse:0.91463
#
# [14]	eval-rmse:0.938766	train-rmse:0.913464
#
# [15]	eval-rmse:0.937353	train-rmse:0.912365
#
# [16]	eval-rmse:0.936237	train-rmse:0.911258
#
# [17]	eval-rmse:0.935088	train-rmse:0.910095
#
# [18]	eval-rmse:0.934131	train-rmse:0.908997
#
# [19]	eval-rmse:0.933208	train-rmse:0.90789
#
# [20]	eval-rmse:0.932168	train-rmse:0.906795
#
# [21]	eval-rmse:0.931047	train-rmse:0.905677
#
# [22]	eval-rmse:0.92983	train-rmse:0.904489
#
# [23]	eval-rmse:0.928888	train-rmse:0.903335
#
# [24]	eval-rmse:0.927907	train-rmse:0.902203
#
# [25]	eval-rmse:0.926921	train-rmse:0.901149
# [26]	eval-rmse:0.925951	train-rmse:0.900084
#
# [0]	eval-rmse:0.955869	train-rmse:0.931897
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.954793	train-rmse:0.930813
#
# [2]	eval-rmse:0.954159	train-rmse:0.929913
#
# [3]	eval-rmse:0.953488	train-rmse:0.928748
#
# [4]	eval-rmse:0.952799	train-rmse:0.927763
#
# [5]	eval-rmse:0.952143	train-rmse:0.926911
#
# [6]	eval-rmse:0.951466	train-rmse:0.926124
#
# [7]	eval-rmse:0.950763	train-rmse:0.925314
#
# [8]	eval-rmse:0.950101	train-rmse:0.924448
#
# [9]	eval-rmse:0.949408	train-rmse:0.923522
#
# [10]	eval-rmse:0.948775	train-rmse:0.922562
#
# [11]	eval-rmse:0.948074	train-rmse:0.921673
#
# [12]	eval-rmse:0.947419	train-rmse:0.920839
#
# [13]	eval-rmse:0.946691	train-rmse:0.920016
#
# [14]	eval-rmse:0.94602	train-rmse:0.919186
#
# [15]	eval-rmse:0.945335	train-rmse:0.918358
#
# [16]	eval-rmse:0.94472	train-rmse:0.917536
#
# [17]	eval-rmse:0.944052	train-rmse:0.916639
#
# [18]	eval-rmse:0.943437	train-rmse:0.915787
#
# [19]	eval-rmse:0.942777	train-rmse:0.914991
#
# [20]	eval-rmse:0.942067	train-rmse:0.914199
#
# [21]	eval-rmse:0.941421	train-rmse:0.913391
#
# [22]	eval-rmse:0.940764	train-rmse:0.912581
#
# [23]	eval-rmse:0.940137	train-rmse:0.911775
#
# [24]	eval-rmse:0.939512	train-rmse:0.910969
#
# [25]	eval-rmse:0.938868	train-rmse:0.910188
#
# [26]	eval-rmse:0.938287	train-rmse:0.909391
#
# [27]	eval-rmse:0.937685	train-rmse:0.908587
#
# [28]	eval-rmse:0.937034	train-rmse:0.907789
#
# [0]	eval-rmse:0.955368	train-rmse:0.93136
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.954508	train-rmse:0.929923
#
# [2]	eval-rmse:0.953477	train-rmse:0.92828
#
# [3]	eval-rmse:0.95248	train-rmse:0.926967
#
# [4]	eval-rmse:0.951659	train-rmse:0.925736
#
# [5]	eval-rmse:0.950798	train-rmse:0.924407
#
# [6]	eval-rmse:0.94989	train-rmse:0.92301
#
# [7]	eval-rmse:0.948995	train-rmse:0.921632
#
# [8]	eval-rmse:0.948104	train-rmse:0.920354
#
# [9]	eval-rmse:0.947158	train-rmse:0.919065
#
# [10]	eval-rmse:0.94628	train-rmse:0.917794
#
# [11]	eval-rmse:0.945328	train-rmse:0.916542
#
# [12]	eval-rmse:0.944488	train-rmse:0.915279
#
# [13]	eval-rmse:0.94369	train-rmse:0.914048
#
# [14]	eval-rmse:0.942847	train-rmse:0.91283
#
# 100%|██████████| 100/100 [3:32:26<00:00, 122.63s/it, best loss: -0.08622752632234527]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-0c2c656d9fd7> in <module>()
#       3 best = fmin(xgboost_factory, space, algo=algo, max_evals=100, pass_expr_memo_ctrl=None)
#       4 store = best
# ----> 5 print("the best parameter before transformation is:" + best)
#       6 print("the best parameter after transformation is:" + argsDict_tranform(best))
#
# TypeError: must be str, not dict

# %%
best
# Out:
# {'alpha': 0.024323280644326623,
#  'lambda': 0.0686095965507202,
#  'learning_rate': 0.12013231877185954,
#  'max_depth': 6,
#  'min_child_weight': 2,
#  'n_estimators': 25,
#  'subsample': 2}

# %%
argsDict_tranform(best)
# Out:
# {'alpha': 0.48646561288653245,
#  'lambda': 3.43047982753601,
#  'learning_rate': 0.003402646375437191,
#  'max_depth': 11,
#  'min_child_weight': 3,
#  'n_estimators': 35,
#  'subsample': 0.7}

# %%
best
# Out:
# {'learning_rate': 0.415602004895926,
#  'max_depth': 2,
#  'min_child_weight': 5,
#  'n_estimators': 14,
#  'subsample': 2}

# %%
 xgboost_factory(argsDict_tranform(best))
# Out:
# [0]	eval-rmse:0.887142	train-rmse:0.91346
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
# Will train until train-rmse hasn't improved in 100 rounds.
# [1]	eval-rmse:0.876897	train-rmse:0.894919
# [2]	eval-rmse:0.868053	train-rmse:0.878668
# [3]	eval-rmse:0.859192	train-rmse:0.86251
# [4]	eval-rmse:0.851483	train-rmse:0.848265
# [5]	eval-rmse:0.844992	train-rmse:0.833192
# [6]	eval-rmse:0.838924	train-rmse:0.820392
# [7]	eval-rmse:0.833219	train-rmse:0.807377
# [8]	eval-rmse:0.828818	train-rmse:0.794724
# [9]	eval-rmse:0.824214	train-rmse:0.783454
# [10]	eval-rmse:0.820525	train-rmse:0.772966
# [11]	eval-rmse:0.817106	train-rmse:0.762479
# [12]	eval-rmse:0.814711	train-rmse:0.752645
# [13]	eval-rmse:0.812286	train-rmse:0.743479
# [14]	eval-rmse:0.810634	train-rmse:0.734102
# [15]	eval-rmse:0.808537	train-rmse:0.72533
# [16]	eval-rmse:0.807054	train-rmse:0.716354
# [17]	eval-rmse:0.805628	train-rmse:0.707871
# [18]	eval-rmse:0.804132	train-rmse:0.699963
# [19]	eval-rmse:0.803122	train-rmse:0.692472
# [20]	eval-rmse:0.802222	train-rmse:0.686265
# [21]	eval-rmse:0.801558	train-rmse:0.678802
# [22]	eval-rmse:0.800949	train-rmse:0.672142
# [23]	eval-rmse:0.800676	train-rmse:0.665405
# [24]	eval-rmse:0.800251	train-rmse:0.659376
# [25]	eval-rmse:0.799761	train-rmse:0.653864
# [26]	eval-rmse:0.799646	train-rmse:0.647186
# [27]	eval-rmse:0.799241	train-rmse:0.640191
# [28]	eval-rmse:0.799364	train-rmse:0.635241
# -0.06243747878596423

# %%
bst=xgb.train(params,dtrain=dtrain,num_boost_round=1,early_stopping_rounds=None,evals=[(dtrain,'train'),(ddev,'test')],verbose_eval=3)
# Out:
# [0]	train-rmse:0.926187	test-rmse:0.896756

# %%
xrf = xgb.train(params, dtrain,num_boost_round=1,early_stopping_rounds=None)

# %%
# first time training

bst=xgb.train(params=xgb_param,dtrain=dtrain,num_boost_round=1,early_stopping_rounds=None,evals=[(dtrain,'train'),(ddev,'test')],verbose_eval=3)
pred = bst.predict(dtest)
predtrain = bst.predict(dtrain)
print(pearsonr(np.array(yp_train), predtrain))
print(pearsonr(np.array(yp_test), pred))


# first time training - continued
for kk in range(29):
    bst=xgb.train(params=xgb_param,dtrain=dtrain,num_boost_round=1,early_stopping_rounds=None,evals=[(dtrain,'train'),(ddev,'test')],verbose_eval=3, xgb_model = bst)
    pred = bst.predict(dtest)
    predtrain = bst.predict(dtrain)
print(pearsonr(np.array(yp_train), predtrain))
# print(pearsonr(np.array(y_train.T)[0], predtrain))
print(pearsonr(np.array(yp_test), pred))
# print(pearsonr(np.array(y_test.T)[0], pred))

# concatenate predictions

g =  train[["TradingDay", "SecuCode"]][time_ind[train_days]:time_ind[train_days+delta_days]]
g["NextCatPred"] = pred
k = g.pivot_table(columns='SecuCode', index='TradingDay', values='NextCatPred').reset_index().sort_values("TradingDay")

# %%
# second traininng and so on

# change dataset
drift = 1
while drift * delta_days + train_days + delta_days < len(time_ind):
    X_train = X[time_ind[drift * delta_days]:time_ind[train_days + drift * delta_days]]
    X_test = X[time_ind[train_days + drift * delta_days]:time_ind[train_days+delta_days + drift * delta_days]]
    y_train = y[time_ind[drift * delta_days]:time_ind[train_days + drift * delta_days]]
    y_test = y[time_ind[train_days + drift * delta_days]:time_ind[train_days+delta_days + drift * delta_days]]
    yp_train = yp[time_ind[drift * delta_days]:time_ind[train_days + drift * delta_days]]
    yp_test = yp[time_ind[train_days + drift * delta_days]:time_ind[train_days+delta_days + drift * delta_days]]
    dtrain = xgb.DMatrix(data=X_train, label=y_train)
    dtest = xgb.DMatrix(data=X_test)
    ddev = xgb.DMatrix(data=X_test, label=y_test)
    bst=xgb.train(params=xgb_param,dtrain=dtrain,num_boost_round=1,early_stopping_rounds=None,evals=[(dtrain,'train'),(ddev,'test')],verbose_eval=3)

    for kk in range(29):
        bst=xgb.train(params=xgb_param,dtrain=dtrain,num_boost_round=1,early_stopping_rounds=None,evals=[(dtrain,'train'),(ddev,'test')],verbose_eval=3, xgb_model = bst)
#         bst=xgb.train(params=xgb_param,dtrain=dtrain,num_boost_round=1,early_stopping_rounds=None,evals=[(dtrain,'train'),(ddev,'test')],verbose_eval=3)
        pred = bst.predict(dtest)
        predtrain = bst.predict(dtrain)
    print(pearsonr(np.array(yp_train), predtrain))
    # print(pearsonr(np.array(y_train.T)[0], predtrain))
    print(pearsonr(np.array(yp_test), pred))
    # print(pearsonr(np.array(y_test.T)[0], pred))
    gt =  train[["TradingDay", "SecuCode"]][time_ind[train_days + drift * delta_days]:time_ind[train_days+delta_days + drift * delta_days]]
    gt["NextCatPred"] = pred
    kt = gt.pivot_table(columns='SecuCode', index='TradingDay', values='NextCatPred').reset_index().sort_values("TradingDay")
    k = pd.concat([k, kt],ignore_index=True)
    drift += 1

# the last dataset
if drift * delta_days + train_days + delta_days > len(time_ind):
    X_train = X[time_ind[drift * delta_days]:time_ind[train_days + drift * delta_days]]
    X_test = X[time_ind[train_days + drift * delta_days]:]
    y_train = y[time_ind[drift * delta_days]:time_ind[train_days + drift * delta_days]]
    y_test = y[time_ind[train_days + drift * delta_days]:]
    yp_train = yp[time_ind[drift * delta_days]:time_ind[train_days + drift * delta_days]]
    yp_test = yp[time_ind[train_days + drift * delta_days]:]
    dtrain = xgb.DMatrix(data=X_train, label=y_train)
    dtest = xgb.DMatrix(data=X_test)
    ddev = xgb.DMatrix(data=X_test, label=y_test)
    bst=xgb.train(params=xgb_param,dtrain=dtrain,num_boost_round=1,early_stopping_rounds=None,evals=[(dtrain,'train'),(ddev,'test')],verbose_eval=3)

    for kk in range(29):
        bst=xgb.train(params=xgb_param,dtrain=dtrain,num_boost_round=1,early_stopping_rounds=None,evals=[(dtrain,'train'),(ddev,'test')],verbose_eval=3, xgb_model = bst)
        pred = bst.predict(dtest)
        predtrain = bst.predict(dtrain)
    print(pearsonr(np.array(yp_train), predtrain))
    # print(pearsonr(np.array(y_train.T)[0], predtrain))
    print(pearsonr(np.array(yp_test), pred))
    # print(pearsonr(np.array(y_test.T)[0], pred))
    gt =  train[["TradingDay", "SecuCode"]][time_ind[train_days + drift * delta_days]:]
    gt["NextCatPred"] = pred
    kt = gt.pivot_table(columns='SecuCode', index='TradingDay', values='NextCatPred').reset_index().sort_values("TradingDay")
    k = pd.concat([k, kt],ignore_index=True)

k.set_index("TradingDay").to_csv("0805back_input_30_30.csv")
