# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import matplotlib.pylab as plt
from scipy.stats import pearsonr

from hyperopt import fmin, tpe, hp, partial


def find_time_ind(df):
    day_ind = [0]
    day_temp = df["TradingDay"][0]
    for i in range(1, len(df)):
        if df["TradingDay"][i] != day_temp:
            day_ind.append(i)
            day_temp = df["TradingDay"][i]
    return day_ind

# %%
# input cell
# train = pd.read_csv('0805rolling5.csv')
train = pd.read_csv('08053before_rolling.csv')
# train = pd.read_csv('08052acou_and_factors.csv')
# x_column = ["factor"+str(i)+'_'+str(j) for i in range(0,17) for j in range(5)]
x_column = ["factor"+str(i) for i in range(0,17)]
# for i in range(12):
#     for j in range(5):
#         x_column.append("10M" + str(i) +'_'+str(j))
# for i in range(12):
#     x_column.append("10M" + str(i))

train = train.sort_values(by = ["TradingDay", "SecuCode"], ascending = [True, True])
train.reset_index(drop=True, inplace=True)
X = train[x_column]
target = ['NextReturnCate']
y = train[target]
y += 1
yp = train["NextReturn"]
time_ind = find_time_ind(train)

# %%
# initializing
train_days = 775
delta_days = -776
X_train = X[time_ind[0]:time_ind[train_days]]
X_test = X[time_ind[train_days]:time_ind[train_days+delta_days]]
y_train = y[time_ind[0]:time_ind[train_days]]
y_test = y[time_ind[train_days]:time_ind[train_days+delta_days]]
yp_train = yp[time_ind[0]:time_ind[train_days]]
yp_test = yp[time_ind[train_days]:time_ind[train_days+delta_days]]
dtrain = xgb.DMatrix(data=X_train, label=y_train)
dtest = xgb.DMatrix(data=X_test)
ddev = xgb.DMatrix(data=X_test, label=y_test)

evallist = [(ddev, 'eval'), (dtrain, 'train')]

# %%
# 自定义hyperopt的参数空间
space = {"max_depth": hp.randint("max_depth", 25),
         "n_estimators": hp.randint("n_estimators", 30),
         'learning_rate': hp.uniform('learning_rate', 1e-3, 5e-1),
         "subsample": hp.randint("subsample", 5),
         "min_child_weight": hp.randint("min_child_weight", 6),
         "alpha": hp.uniform("alpha", 0, 1),
         "lambda": hp.uniform("lambda", 0, 1)
         }

def argsDict_tranform(argsDict, isPrint=False):
    argsDict["max_depth"] = argsDict["max_depth"] + 5    # from 5 to 30
    argsDict['n_estimators'] = argsDict['n_estimators'] + 10  # from 10 to 40
    argsDict["learning_rate"] = argsDict["learning_rate"] * 0.02 + 0.001   # from 0.001 to 0.01
    argsDict["subsample"] = argsDict["subsample"] * 0.1 + 0.5  # from 0.5 to 1
    argsDict["min_child_weight"] = argsDict["min_child_weight"] + 1 # from 1 to 6
    argsDict["alpha"] = argsDict["alpha"] * 20
    argsDict["lambda"] = argsDict["lambda"] * 50
    if isPrint:
        print(argsDict)
    else:
        pass

    return argsDict

# %%
from sklearn.metrics import mean_squared_error, zero_one_loss

def xgboost_factory(argsDict):
    argsDict = argsDict_tranform(argsDict)
    
    params = {'nthread': -1,  # 进程数
              'max_depth': argsDict['max_depth'],  # 最大深度
              'n_estimators': argsDict['n_estimators'],  # 树的数量
              'eta': argsDict['learning_rate'],  # 学习率
              'subsample': argsDict['subsample'],  # 采样数
              'min_child_weight': argsDict['min_child_weight'],  # 终点节点最小样本占比的和
              'objective': 'reg:squarederror',
              'silent': 0,  # 是否显示
              'gamma': 0,  # 是否后剪枝
              'colsample_bytree': 0.7,  # 样本列采样
              'alpha': argsDict['alpha'],  # L1 正则化
              'lambda': argsDict['lambda'],  # L2 正则化
              'scale_pos_weight': 0,  # 取值>0时,在数据不平衡时有助于收敛
              'seed': 100,  # 随机种子
              'tree_method':'exact'
              }

    xrf = xgb.train(params, dtrain, params['n_estimators'], evallist,early_stopping_rounds=100)

    return get_tranformer_score(xrf)


def get_tranformer_score(tranformer):
    
    xrf = tranformer
    pred = xrf.predict(ddev, ntree_limit=xrf.best_ntree_limit)
  
    return -pearsonr(np.array(yp_test), pred)[0]

# %%
# 开始使用hyperopt进行自动调参
algo = partial(tpe.suggest, n_startup_jobs=1)
best = fmin(xgboost_factory, space, algo=algo, max_evals=100, pass_expr_memo_ctrl=None)
store = best
print("the best parameter before transformation is:" + best)
print("the best parameter after transformation is:" + argsDict_tranform(best))
# Out:
# [0]	eval-rmse:0.954875	train-rmse:0.93093
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.953518	train-rmse:0.929155
#
# [2]	eval-rmse:0.95216	train-rmse:0.927418
#
# [3]	eval-rmse:0.950901	train-rmse:0.926101
#
# [4]	eval-rmse:0.94945	train-rmse:0.924519
#
# [5]	eval-rmse:0.948124	train-rmse:0.922813
#
# [6]	eval-rmse:0.946781	train-rmse:0.921258
#
# [7]	eval-rmse:0.945502	train-rmse:0.91983
#
# [8]	eval-rmse:0.944165	train-rmse:0.918299
#
# [9]	eval-rmse:0.942875	train-rmse:0.916808
#
# [10]	eval-rmse:0.941597	train-rmse:0.915348
#
# [11]	eval-rmse:0.940298	train-rmse:0.913958
#
# [12]	eval-rmse:0.939008	train-rmse:0.912558
#
# [13]	eval-rmse:0.937879	train-rmse:0.911165
#
# [14]	eval-rmse:0.936715	train-rmse:0.909794
#
# [15]	eval-rmse:0.935441	train-rmse:0.908351
#
# [16]	eval-rmse:0.934307	train-rmse:0.906991
#
# [17]	eval-rmse:0.933117	train-rmse:0.905627
#
# [18]	eval-rmse:0.931938	train-rmse:0.904305
#
# [19]	eval-rmse:0.930717	train-rmse:0.902902
#
# [0]	eval-rmse:0.954869	train-rmse:0.930927
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.953532	train-rmse:0.929165
#
# [2]	eval-rmse:0.952164	train-rmse:0.927419
#
# [3]	eval-rmse:0.950914	train-rmse:0.926101
#
# [4]	eval-rmse:0.949471	train-rmse:0.924516
#
# [5]	eval-rmse:0.94816	train-rmse:0.922785
#
# [6]	eval-rmse:0.946826	train-rmse:0.92124
#
# [7]	eval-rmse:0.945545	train-rmse:0.919784
#
# [8]	eval-rmse:0.944206	train-rmse:0.918276
#
# [9]	eval-rmse:0.94292	train-rmse:0.91679
#
# [10]	eval-rmse:0.941681	train-rmse:0.915315
#
# [11]	eval-rmse:0.940343	train-rmse:0.913907
#
# [12]	eval-rmse:0.939082	train-rmse:0.912508
#
# [13]	eval-rmse:0.937929	train-rmse:0.911098
#
# [14]	eval-rmse:0.936766	train-rmse:0.90972
#
# [15]	eval-rmse:0.935525	train-rmse:0.908285
#
# [16]	eval-rmse:0.934357	train-rmse:0.906907
#
# [17]	eval-rmse:0.933177	train-rmse:0.905539
#
# [18]	eval-rmse:0.931959	train-rmse:0.90421
#
# [19]	eval-rmse:0.930782	train-rmse:0.902822
#
# [0]	eval-rmse:0.956182	train-rmse:0.932196
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.955726	train-rmse:0.931872
#
# [2]	eval-rmse:0.955094	train-rmse:0.931347
#
# [3]	eval-rmse:0.954292	train-rmse:0.930641
#
# [4]	eval-rmse:0.953913	train-rmse:0.930298
#
# [5]	eval-rmse:0.953638	train-rmse:0.929771
#
# [6]	eval-rmse:0.953286	train-rmse:0.929017
#
# [7]	eval-rmse:0.952852	train-rmse:0.928508
#
# [8]	eval-rmse:0.95237	train-rmse:0.927994
#
# [9]	eval-rmse:0.951878	train-rmse:0.927422
#
# [10]	eval-rmse:0.951465	train-rmse:0.926954
#
# [11]	eval-rmse:0.951052	train-rmse:0.926637
#
# [12]	eval-rmse:0.950669	train-rmse:0.926305
#
# [13]	eval-rmse:0.950264	train-rmse:0.92592
#
# [14]	eval-rmse:0.949835	train-rmse:0.925505
#
# [15]	eval-rmse:0.949312	train-rmse:0.925023
#
# [16]	eval-rmse:0.948874	train-rmse:0.924531
#
# [17]	eval-rmse:0.948422	train-rmse:0.924032
#
# [18]	eval-rmse:0.94802	train-rmse:0.923544
#
# [19]	eval-rmse:0.947598	train-rmse:0.923029
#
# [20]	eval-rmse:0.947164	train-rmse:0.922454
#
# [21]	eval-rmse:0.946723	train-rmse:0.921936
#
# [22]	eval-rmse:0.946307	train-rmse:0.921497
#
# [23]	eval-rmse:0.945881	train-rmse:0.921049
#
# [24]	eval-rmse:0.945454	train-rmse:0.920649
#
# [0]	eval-rmse:0.956274	train-rmse:0.932302
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.956086	train-rmse:0.93213
#
# [2]	eval-rmse:0.955815	train-rmse:0.931932
#
# [3]	eval-rmse:0.955487	train-rmse:0.931705
#
# [4]	eval-rmse:0.95482	train-rmse:0.931153
#
# [5]	eval-rmse:0.954411	train-rmse:0.930745
#
# [6]	eval-rmse:0.954103	train-rmse:0.930534
#
# [7]	eval-rmse:0.95389	train-rmse:0.930321
#
# [8]	eval-rmse:0.953745	train-rmse:0.930024
#
# [9]	eval-rmse:0.953577	train-rmse:0.929617
#
# [10]	eval-rmse:0.953333	train-rmse:0.929124
#
# [11]	eval-rmse:0.953031	train-rmse:0.928771
#
# [12]	eval-rmse:0.952699	train-rmse:0.928449
#
# [13]	eval-rmse:0.95242	train-rmse:0.928107
#
# [14]	eval-rmse:0.952164	train-rmse:0.927771
#
# [15]	eval-rmse:0.95189	train-rmse:0.927415
#
# [16]	eval-rmse:0.951624	train-rmse:0.927127
#
# [17]	eval-rmse:0.951366	train-rmse:0.926939
#
# [18]	eval-rmse:0.951086	train-rmse:0.926753
#
# [19]	eval-rmse:0.950838	train-rmse:0.926571
#
# [20]	eval-rmse:0.950588	train-rmse:0.926368
#
# [21]	eval-rmse:0.95034	train-rmse:0.926131
#
# [22]	eval-rmse:0.950068	train-rmse:0.925857
#
# [23]	eval-rmse:0.94979	train-rmse:0.92557
#
# [24]	eval-rmse:0.949503	train-rmse:0.925286
#
# [0]	eval-rmse:0.956273	train-rmse:0.932296
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.95609	train-rmse:0.93211
#
# [2]	eval-rmse:0.955785	train-rmse:0.931913
#
# [3]	eval-rmse:0.955455	train-rmse:0.931667
# [4]	eval-rmse:0.954744	train-rmse:0.931056
#
# [5]	eval-rmse:0.954369	train-rmse:0.930703
#
# [6]	eval-rmse:0.954084	train-rmse:0.93049
#
# [7]	eval-rmse:0.953874	train-rmse:0.930251
#
# [8]	eval-rmse:0.953717	train-rmse:0.929924
#
# [9]	eval-rmse:0.953516	train-rmse:0.929459
#
# [10]	eval-rmse:0.95328	train-rmse:0.928993
#
# [11]	eval-rmse:0.952967	train-rmse:0.928663
#
# [12]	eval-rmse:0.952644	train-rmse:0.92834
#
# [13]	eval-rmse:0.952335	train-rmse:0.927971
#
# [14]	eval-rmse:0.952069	train-rmse:0.927637
#
# [15]	eval-rmse:0.951762	train-rmse:0.927268
#
# [16]	eval-rmse:0.951539	train-rmse:0.927027
#
# [17]	eval-rmse:0.95125	train-rmse:0.926823
#
# [18]	eval-rmse:0.950994	train-rmse:0.92664
#
# [19]	eval-rmse:0.950753	train-rmse:0.926439
#
# [20]	eval-rmse:0.950497	train-rmse:0.926198
#
# [21]	eval-rmse:0.950227	train-rmse:0.925939
#
# [22]	eval-rmse:0.949948	train-rmse:0.925653
#
# [23]	eval-rmse:0.949652	train-rmse:0.92537
#
# [24]	eval-rmse:0.949355	train-rmse:0.925065
#
# [25]	eval-rmse:0.949024	train-rmse:0.924738
#
# [26]	eval-rmse:0.948751	train-rmse:0.924404
#
# [0]	eval-rmse:0.953834	train-rmse:0.929852
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.951556	train-rmse:0.927022
#
# [2]	eval-rmse:0.94928	train-rmse:0.924521
#
# [3]	eval-rmse:0.946985	train-rmse:0.921804
#
# [4]	eval-rmse:0.944642	train-rmse:0.919441
#
# [5]	eval-rmse:0.942311	train-rmse:0.916869
#
# [6]	eval-rmse:0.940169	train-rmse:0.914526
#
# [7]	eval-rmse:0.938099	train-rmse:0.912202
#
# [8]	eval-rmse:0.935917	train-rmse:0.909961
#
# [9]	eval-rmse:0.933777	train-rmse:0.90765
#
# [10]	eval-rmse:0.931736	train-rmse:0.905385
#
# [11]	eval-rmse:0.929661	train-rmse:0.903074
#
# [12]	eval-rmse:0.927569	train-rmse:0.900853
#
# [13]	eval-rmse:0.925651	train-rmse:0.898679
#
# [14]	eval-rmse:0.923909	train-rmse:0.896719
#
# [15]	eval-rmse:0.921953	train-rmse:0.8947
#
# [16]	eval-rmse:0.920142	train-rmse:0.892776
#
# [0]	eval-rmse:0.955857	train-rmse:0.931952
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.954745	train-rmse:0.930928
#
# [2]	eval-rmse:0.954038	train-rmse:0.930211
#
# [3]	eval-rmse:0.953447	train-rmse:0.929183
#
# [4]	eval-rmse:0.952678	train-rmse:0.928228
#
# [5]	eval-rmse:0.951951	train-rmse:0.927333
#
# [6]	eval-rmse:0.951286	train-rmse:0.926711
#
# [7]	eval-rmse:0.950637	train-rmse:0.926059
#
# [8]	eval-rmse:0.949928	train-rmse:0.925343
#
# [9]	eval-rmse:0.949192	train-rmse:0.924503
#
# [10]	eval-rmse:0.948511	train-rmse:0.923647
#
# [11]	eval-rmse:0.947825	train-rmse:0.922768
#
# [12]	eval-rmse:0.947121	train-rmse:0.921932
#
# [13]	eval-rmse:0.946441	train-rmse:0.921176
#
# [14]	eval-rmse:0.945821	train-rmse:0.920471
#
# [15]	eval-rmse:0.945159	train-rmse:0.919745
#
# [16]	eval-rmse:0.944511	train-rmse:0.919026
#
# [17]	eval-rmse:0.943837	train-rmse:0.918266
#
# [18]	eval-rmse:0.943102	train-rmse:0.917495
#
# [19]	eval-rmse:0.94242	train-rmse:0.916727
#
# [20]	eval-rmse:0.941805	train-rmse:0.91597
#
# [21]	eval-rmse:0.941143	train-rmse:0.915237
#
# [22]	eval-rmse:0.94045	train-rmse:0.914522
#
# [23]	eval-rmse:0.939791	train-rmse:0.913813
#
# [24]	eval-rmse:0.939157	train-rmse:0.913136
#
# [0]	eval-rmse:0.953804	train-rmse:0.929897
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.951597	train-rmse:0.927084
#
# [2]	eval-rmse:0.949448	train-rmse:0.924876
#
# [3]	eval-rmse:0.947145	train-rmse:0.922123
#
# [4]	eval-rmse:0.944963	train-rmse:0.919928
#
# [5]	eval-rmse:0.942561	train-rmse:0.91741
#
# [6]	eval-rmse:0.940387	train-rmse:0.915078
#
# [7]	eval-rmse:0.938352	train-rmse:0.912939
#
# [8]	eval-rmse:0.93633	train-rmse:0.910744
#
# [9]	eval-rmse:0.934156	train-rmse:0.9085
#
# [10]	eval-rmse:0.932123	train-rmse:0.906325
#
# [11]	eval-rmse:0.93021	train-rmse:0.904096
#
# [12]	eval-rmse:0.928217	train-rmse:0.901961
#
# [13]	eval-rmse:0.926392	train-rmse:0.899815
#
# [0]	eval-rmse:0.955672	train-rmse:0.93182
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.954408	train-rmse:0.930656
#
# [2]	eval-rmse:0.953744	train-rmse:0.929622
#
# [3]	eval-rmse:0.95294	train-rmse:0.92846
#
# [4]	eval-rmse:0.951968	train-rmse:0.927344
#
# [5]	eval-rmse:0.951197	train-rmse:0.926603
#
# [6]	eval-rmse:0.950415	train-rmse:0.9258
#
# [7]	eval-rmse:0.949552	train-rmse:0.924827
#
# [8]	eval-rmse:0.9487	train-rmse:0.923823
#
# [9]	eval-rmse:0.947913	train-rmse:0.922767
# [10]	eval-rmse:0.947122	train-rmse:0.921781
#
# [11]	eval-rmse:0.946257	train-rmse:0.920886
#
# [12]	eval-rmse:0.945461	train-rmse:0.920035
#
# [13]	eval-rmse:0.94471	train-rmse:0.919154
#
# [14]	eval-rmse:0.943928	train-rmse:0.918261
#
# [15]	eval-rmse:0.943116	train-rmse:0.917325
#
# [16]	eval-rmse:0.942337	train-rmse:0.916406
#
# [17]	eval-rmse:0.941602	train-rmse:0.915516
#
# [18]	eval-rmse:0.940768	train-rmse:0.914679
#
# [0]	eval-rmse:0.954251	train-rmse:0.930368
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.952593	train-rmse:0.927914
#
# [2]	eval-rmse:0.950814	train-rmse:0.926013
#
# [3]	eval-rmse:0.948898	train-rmse:0.923832
#
# [4]	eval-rmse:0.947045	train-rmse:0.921596
#
# [5]	eval-rmse:0.945274	train-rmse:0.919682
#
# [6]	eval-rmse:0.943398	train-rmse:0.917604
#
# [7]	eval-rmse:0.941697	train-rmse:0.915569
#
# [8]	eval-rmse:0.939968	train-rmse:0.913748
#
# [9]	eval-rmse:0.938297	train-rmse:0.911911
#
# [10]	eval-rmse:0.936604	train-rmse:0.90999
#
# [11]	eval-rmse:0.934807	train-rmse:0.908063
#
# [12]	eval-rmse:0.933102	train-rmse:0.906214
#
# [13]	eval-rmse:0.931637	train-rmse:0.904317
#
# [14]	eval-rmse:0.930223	train-rmse:0.902518
#
# [15]	eval-rmse:0.928628	train-rmse:0.900705
#
# [16]	eval-rmse:0.927132	train-rmse:0.89892
#
# [17]	eval-rmse:0.925624	train-rmse:0.897149
#
# [18]	eval-rmse:0.924118	train-rmse:0.89547
#
# [19]	eval-rmse:0.922618	train-rmse:0.893847
#
# [20]	eval-rmse:0.921188	train-rmse:0.892215
#
# [21]	eval-rmse:0.919758	train-rmse:0.890556
#
# [22]	eval-rmse:0.918339	train-rmse:0.88886
#
# [23]	eval-rmse:0.916923	train-rmse:0.887187
#
# [24]	eval-rmse:0.915512	train-rmse:0.885575
#
# [25]	eval-rmse:0.914105	train-rmse:0.884051
#
# [26]	eval-rmse:0.912872	train-rmse:0.882423
#
# [27]	eval-rmse:0.911564	train-rmse:0.880874
#
# [28]	eval-rmse:0.910343	train-rmse:0.879353
#
# [29]	eval-rmse:0.909077	train-rmse:0.877911
#
# [30]	eval-rmse:0.907968	train-rmse:0.876385
#
# [31]	eval-rmse:0.906781	train-rmse:0.874918
#
# [32]	eval-rmse:0.905653	train-rmse:0.873484
#
# [0]	eval-rmse:0.955595	train-rmse:0.931554
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.954688	train-rmse:0.930368
#
# [2]	eval-rmse:0.953889	train-rmse:0.929028
#
# [3]	eval-rmse:0.953159	train-rmse:0.927816
#
# [4]	eval-rmse:0.952276	train-rmse:0.92676
#
# [5]	eval-rmse:0.951502	train-rmse:0.925749
#
# [6]	eval-rmse:0.950721	train-rmse:0.924654
#
# [7]	eval-rmse:0.949918	train-rmse:0.92349
#
# [8]	eval-rmse:0.949093	train-rmse:0.922337
#
# [9]	eval-rmse:0.94836	train-rmse:0.921233
#
# [10]	eval-rmse:0.947598	train-rmse:0.920169
#
# [11]	eval-rmse:0.946809	train-rmse:0.919125
#
# [12]	eval-rmse:0.945975	train-rmse:0.918053
#
# [13]	eval-rmse:0.945192	train-rmse:0.917048
#
# [14]	eval-rmse:0.944474	train-rmse:0.916024
#
# [15]	eval-rmse:0.943698	train-rmse:0.914998
#
# [16]	eval-rmse:0.942986	train-rmse:0.914007
#
# [17]	eval-rmse:0.942246	train-rmse:0.912996
#
# [18]	eval-rmse:0.941479	train-rmse:0.91202
#
# [19]	eval-rmse:0.940738	train-rmse:0.91103
#
# [20]	eval-rmse:0.940025	train-rmse:0.910018
#
# [21]	eval-rmse:0.9393	train-rmse:0.909022
#
# [22]	eval-rmse:0.938551	train-rmse:0.907977
#
# [23]	eval-rmse:0.937851	train-rmse:0.906912
#
# [24]	eval-rmse:0.937105	train-rmse:0.905919
#
# [25]	eval-rmse:0.93635	train-rmse:0.90495
#
# [26]	eval-rmse:0.935611	train-rmse:0.903927
#
# [27]	eval-rmse:0.934978	train-rmse:0.902922
#
# [28]	eval-rmse:0.934308	train-rmse:0.901918
#
# [29]	eval-rmse:0.933613	train-rmse:0.900914
#
# [30]	eval-rmse:0.932942	train-rmse:0.899872
#
# [0]	eval-rmse:0.954288	train-rmse:0.930537
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.952578	train-rmse:0.928275
#
# [2]	eval-rmse:0.950715	train-rmse:0.926373
#
# [3]	eval-rmse:0.948722	train-rmse:0.924428
#
# [4]	eval-rmse:0.946848	train-rmse:0.922156
#
# [5]	eval-rmse:0.945104	train-rmse:0.920357
#
# [6]	eval-rmse:0.943126	train-rmse:0.918328
#
# [7]	eval-rmse:0.94138	train-rmse:0.916381
#
# [8]	eval-rmse:0.939592	train-rmse:0.914641
#
# [9]	eval-rmse:0.937855	train-rmse:0.912907
#
# [10]	eval-rmse:0.936247	train-rmse:0.911138
#
# [11]	eval-rmse:0.934289	train-rmse:0.909204
#
# [12]	eval-rmse:0.932629	train-rmse:0.907499
#
# [13]	eval-rmse:0.931151	train-rmse:0.905792
#
# [14]	eval-rmse:0.929675	train-rmse:0.90396
#
# [15]	eval-rmse:0.928083	train-rmse:0.902317
#
# [16]	eval-rmse:0.926427	train-rmse:0.900563
# [17]	eval-rmse:0.924885	train-rmse:0.898777
#
# [18]	eval-rmse:0.923373	train-rmse:0.89726
#
# [19]	eval-rmse:0.92191	train-rmse:0.895783
#
# [20]	eval-rmse:0.920445	train-rmse:0.894279
#
# [21]	eval-rmse:0.918909	train-rmse:0.892736
#
# [22]	eval-rmse:0.91742	train-rmse:0.8912
#
# [0]	eval-rmse:0.956121	train-rmse:0.932138
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.955544	train-rmse:0.931684
#
# [2]	eval-rmse:0.95463	train-rmse:0.930853
#
# [3]	eval-rmse:0.954117	train-rmse:0.930394
#
# [4]	eval-rmse:0.953723	train-rmse:0.929666
#
# [5]	eval-rmse:0.953254	train-rmse:0.928962
#
# [6]	eval-rmse:0.952668	train-rmse:0.928276
#
# [7]	eval-rmse:0.952133	train-rmse:0.927576
#
# [8]	eval-rmse:0.951667	train-rmse:0.927113
#
# [9]	eval-rmse:0.951195	train-rmse:0.92672
#
# [10]	eval-rmse:0.950718	train-rmse:0.926295
#
# [11]	eval-rmse:0.9502	train-rmse:0.925766
#
# [12]	eval-rmse:0.949649	train-rmse:0.925189
#
# [0]	eval-rmse:0.95544	train-rmse:0.931673
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.953795	train-rmse:0.930207
#
# [2]	eval-rmse:0.952905	train-rmse:0.928574
#
# [3]	eval-rmse:0.951458	train-rmse:0.927114
#
# [4]	eval-rmse:0.950457	train-rmse:0.926349
#
# [5]	eval-rmse:0.94914	train-rmse:0.924998
#
# [6]	eval-rmse:0.948093	train-rmse:0.923881
#
# [7]	eval-rmse:0.946883	train-rmse:0.922219
#
# [8]	eval-rmse:0.945782	train-rmse:0.921181
#
# [9]	eval-rmse:0.944777	train-rmse:0.920231
#
# [10]	eval-rmse:0.943518	train-rmse:0.918932
#
# [11]	eval-rmse:0.94233	train-rmse:0.917666
#
# [12]	eval-rmse:0.941253	train-rmse:0.916522
#
# [13]	eval-rmse:0.940131	train-rmse:0.915355
#
# [14]	eval-rmse:0.939143	train-rmse:0.914362
#
# [15]	eval-rmse:0.938045	train-rmse:0.913281
#
# [16]	eval-rmse:0.937042	train-rmse:0.912248
#
# [17]	eval-rmse:0.936138	train-rmse:0.911187
#
# [18]	eval-rmse:0.934983	train-rmse:0.909986
#
# [19]	eval-rmse:0.933756	train-rmse:0.90886
#
# [20]	eval-rmse:0.93277	train-rmse:0.907844
#
# [21]	eval-rmse:0.931701	train-rmse:0.906807
#
# [22]	eval-rmse:0.930794	train-rmse:0.905733
#
# [23]	eval-rmse:0.929751	train-rmse:0.904473
#
# [24]	eval-rmse:0.928873	train-rmse:0.903486
#
# [25]	eval-rmse:0.927957	train-rmse:0.902534
#
# [26]	eval-rmse:0.926794	train-rmse:0.901414
#
# [27]	eval-rmse:0.925859	train-rmse:0.900234
#
# [28]	eval-rmse:0.92496	train-rmse:0.899205
#
# [29]	eval-rmse:0.923892	train-rmse:0.898266
#
# [0]	eval-rmse:0.95432	train-rmse:0.9305
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.952748	train-rmse:0.92816
#
# [2]	eval-rmse:0.951088	train-rmse:0.926359
#
# [3]	eval-rmse:0.949297	train-rmse:0.924343
#
# [4]	eval-rmse:0.947519	train-rmse:0.922191
#
# [5]	eval-rmse:0.945824	train-rmse:0.92033
#
# [6]	eval-rmse:0.944094	train-rmse:0.918415
#
# [7]	eval-rmse:0.942456	train-rmse:0.916418
#
# [8]	eval-rmse:0.940821	train-rmse:0.914607
#
# [9]	eval-rmse:0.939219	train-rmse:0.912872
#
# [10]	eval-rmse:0.937715	train-rmse:0.911088
#
# [11]	eval-rmse:0.9361	train-rmse:0.909297
#
# [12]	eval-rmse:0.934424	train-rmse:0.907473
#
# [13]	eval-rmse:0.932964	train-rmse:0.905721
#
# [14]	eval-rmse:0.93161	train-rmse:0.904023
#
# [15]	eval-rmse:0.930135	train-rmse:0.902261
#
# [16]	eval-rmse:0.928686	train-rmse:0.900543
#
# [17]	eval-rmse:0.927303	train-rmse:0.898818
#
# [18]	eval-rmse:0.925858	train-rmse:0.897204
#
# [19]	eval-rmse:0.92441	train-rmse:0.895578
#
# [20]	eval-rmse:0.92307	train-rmse:0.894027
#
# [21]	eval-rmse:0.921689	train-rmse:0.892455
#
# [22]	eval-rmse:0.920354	train-rmse:0.890878
#
# [23]	eval-rmse:0.919031	train-rmse:0.889235
#
# [24]	eval-rmse:0.917681	train-rmse:0.887699
#
# [25]	eval-rmse:0.916348	train-rmse:0.886215
#
# [26]	eval-rmse:0.915125	train-rmse:0.884646
#
# [27]	eval-rmse:0.91396	train-rmse:0.883132
#
# [28]	eval-rmse:0.912788	train-rmse:0.881615
#
# [29]	eval-rmse:0.911602	train-rmse:0.880193
#
# [30]	eval-rmse:0.910529	train-rmse:0.878724
#
# [31]	eval-rmse:0.909343	train-rmse:0.877325
#
# [32]	eval-rmse:0.908315	train-rmse:0.875924
#
# [33]	eval-rmse:0.90714	train-rmse:0.874573
#
# [34]	eval-rmse:0.906048	train-rmse:0.873244
#
# [35]	eval-rmse:0.90495	train-rmse:0.87191
#
# [36]	eval-rmse:0.90395	train-rmse:0.870504
#
# [37]	eval-rmse:0.902784	train-rmse:0.869199
#
# [38]	eval-rmse:0.901739	train-rmse:0.867902
#
# [0]	eval-rmse:0.955292	train-rmse:0.931385
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.954005	train-rmse:0.929965
#
# [2]	eval-rmse:0.953011	train-rmse:0.928372
#
# [3]	eval-rmse:0.95188	train-rmse:0.92705
#
# [4]	eval-rmse:0.950778	train-rmse:0.925963
#
# [5]	eval-rmse:0.949669	train-rmse:0.924682
#
# [6]	eval-rmse:0.948595	train-rmse:0.923293
#
# [7]	eval-rmse:0.947489	train-rmse:0.921914
#
# [8]	eval-rmse:0.946469	train-rmse:0.920731
#
# [9]	eval-rmse:0.945376	train-rmse:0.919571
#
# [10]	eval-rmse:0.944342	train-rmse:0.918309
#
# [11]	eval-rmse:0.94325	train-rmse:0.917057
#
# [12]	eval-rmse:0.942189	train-rmse:0.915822
#
# [13]	eval-rmse:0.941227	train-rmse:0.914642
#
# [14]	eval-rmse:0.940297	train-rmse:0.913544
#
# [15]	eval-rmse:0.939243	train-rmse:0.912398
#
# [16]	eval-rmse:0.938332	train-rmse:0.911275
#
# [17]	eval-rmse:0.937326	train-rmse:0.910123
#
# [18]	eval-rmse:0.936376	train-rmse:0.908997
#
# [19]	eval-rmse:0.935329	train-rmse:0.907838
#
# [20]	eval-rmse:0.934331	train-rmse:0.90668
#
# [21]	eval-rmse:0.933417	train-rmse:0.905553
#
# [22]	eval-rmse:0.932462	train-rmse:0.904395
#
# [23]	eval-rmse:0.931473	train-rmse:0.903241
#
# [24]	eval-rmse:0.93048	train-rmse:0.902128
#
# [25]	eval-rmse:0.929512	train-rmse:0.901043
#
# [26]	eval-rmse:0.92862	train-rmse:0.899885
#
# [27]	eval-rmse:0.927763	train-rmse:0.898804
#
# [0]	eval-rmse:0.956076	train-rmse:0.932106
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.955521	train-rmse:0.931707
#
# [2]	eval-rmse:0.954459	train-rmse:0.93079
#
# [3]	eval-rmse:0.954	train-rmse:0.930377
#
# [4]	eval-rmse:0.953649	train-rmse:0.929676
#
# [5]	eval-rmse:0.953163	train-rmse:0.928882
#
# [6]	eval-rmse:0.952584	train-rmse:0.928243
#
# [7]	eval-rmse:0.951968	train-rmse:0.927511
#
# [8]	eval-rmse:0.95152	train-rmse:0.927069
#
# [9]	eval-rmse:0.951024	train-rmse:0.926725
#
# [10]	eval-rmse:0.950526	train-rmse:0.926303
#
# [11]	eval-rmse:0.949994	train-rmse:0.925771
#
# [12]	eval-rmse:0.949446	train-rmse:0.925204
#
# [13]	eval-rmse:0.948871	train-rmse:0.924568
#
# [14]	eval-rmse:0.948406	train-rmse:0.923977
#
# [15]	eval-rmse:0.947944	train-rmse:0.923387
#
# [16]	eval-rmse:0.947459	train-rmse:0.922651
#
# [17]	eval-rmse:0.946949	train-rmse:0.922078
#
# [0]	eval-rmse:0.955443	train-rmse:0.931683
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.95383	train-rmse:0.930273
#
# [2]	eval-rmse:0.952932	train-rmse:0.928631
#
# [3]	eval-rmse:0.95155	train-rmse:0.927177
#
# [4]	eval-rmse:0.950562	train-rmse:0.926433
#
# [5]	eval-rmse:0.949319	train-rmse:0.925214
#
# [6]	eval-rmse:0.948187	train-rmse:0.923915
#
# [7]	eval-rmse:0.947054	train-rmse:0.922396
#
# [8]	eval-rmse:0.945922	train-rmse:0.921315
#
# [9]	eval-rmse:0.944999	train-rmse:0.920426
#
# [10]	eval-rmse:0.943854	train-rmse:0.919295
#
# [11]	eval-rmse:0.942562	train-rmse:0.917928
#
# [12]	eval-rmse:0.941471	train-rmse:0.916755
#
# [13]	eval-rmse:0.940399	train-rmse:0.915591
#
# [14]	eval-rmse:0.939385	train-rmse:0.914604
#
# [15]	eval-rmse:0.938386	train-rmse:0.91363
#
# [16]	eval-rmse:0.937355	train-rmse:0.912569
#
# [17]	eval-rmse:0.936363	train-rmse:0.911438
#
# [18]	eval-rmse:0.935327	train-rmse:0.910422
#
# [19]	eval-rmse:0.934094	train-rmse:0.909185
#
# [20]	eval-rmse:0.933145	train-rmse:0.908218
#
# [21]	eval-rmse:0.932102	train-rmse:0.907222
#
# [22]	eval-rmse:0.931139	train-rmse:0.906169
#
# [23]	eval-rmse:0.93022	train-rmse:0.904998
#
# [24]	eval-rmse:0.929189	train-rmse:0.903846
#
# [25]	eval-rmse:0.928397	train-rmse:0.902994
#
# [26]	eval-rmse:0.927315	train-rmse:0.901958
#
# [27]	eval-rmse:0.926399	train-rmse:0.900856
#
# [28]	eval-rmse:0.925389	train-rmse:0.899683
#
# [29]	eval-rmse:0.924414	train-rmse:0.898766
#
# [0]	eval-rmse:0.955268	train-rmse:0.930497
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.954295	train-rmse:0.928348
#
# [2]	eval-rmse:0.953335	train-rmse:0.926451
#
# [3]	eval-rmse:0.952339	train-rmse:0.924359
#
# [4]	eval-rmse:0.951296	train-rmse:0.922325
#
# [5]	eval-rmse:0.950296	train-rmse:0.920304
#
# [6]	eval-rmse:0.949323	train-rmse:0.918254
#
# [7]	eval-rmse:0.948333	train-rmse:0.916193
#
# [8]	eval-rmse:0.947321	train-rmse:0.914194
#
# [9]	eval-rmse:0.946331	train-rmse:0.912256
#
# [10]	eval-rmse:0.945403	train-rmse:0.910326
#
# [11]	eval-rmse:0.944471	train-rmse:0.908443
#
# [12]	eval-rmse:0.943494	train-rmse:0.906505
#
# [13]	eval-rmse:0.942597	train-rmse:0.904619
# [14]	eval-rmse:0.941724	train-rmse:0.902751
#
# [15]	eval-rmse:0.940783	train-rmse:0.900827
#
# [16]	eval-rmse:0.939839	train-rmse:0.898976
#
# [17]	eval-rmse:0.93897	train-rmse:0.897106
#
# [18]	eval-rmse:0.938082	train-rmse:0.895219
#
# [19]	eval-rmse:0.937195	train-rmse:0.893319
#
# [20]	eval-rmse:0.936324	train-rmse:0.891462
#
# [21]	eval-rmse:0.935448	train-rmse:0.889593
#
# [22]	eval-rmse:0.934581	train-rmse:0.88768
#
# [23]	eval-rmse:0.933683	train-rmse:0.885746
#
# [24]	eval-rmse:0.93278	train-rmse:0.883961
#
# [25]	eval-rmse:0.931922	train-rmse:0.882229
#
# [26]	eval-rmse:0.931088	train-rmse:0.880329
#
# [27]	eval-rmse:0.930293	train-rmse:0.878534
#
# [28]	eval-rmse:0.9295	train-rmse:0.876688
#
# [29]	eval-rmse:0.928669	train-rmse:0.874833
#
# [30]	eval-rmse:0.927898	train-rmse:0.872939
#
# [31]	eval-rmse:0.927109	train-rmse:0.871128
#
# [32]	eval-rmse:0.926349	train-rmse:0.869342
#
# [33]	eval-rmse:0.925556	train-rmse:0.867598
#
# [34]	eval-rmse:0.924825	train-rmse:0.865812
#
# [35]	eval-rmse:0.924087	train-rmse:0.864059
#
# [36]	eval-rmse:0.923325	train-rmse:0.862197
#
# [0]	eval-rmse:0.95611	train-rmse:0.932116
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.95548	train-rmse:0.931637
#
# [2]	eval-rmse:0.954506	train-rmse:0.930733
#
# [3]	eval-rmse:0.953997	train-rmse:0.930231
#
# [4]	eval-rmse:0.953577	train-rmse:0.929489
#
# [5]	eval-rmse:0.953109	train-rmse:0.928713
#
# [6]	eval-rmse:0.952565	train-rmse:0.928049
#
# [7]	eval-rmse:0.951988	train-rmse:0.927366
#
# [8]	eval-rmse:0.951448	train-rmse:0.926805
#
# [9]	eval-rmse:0.950962	train-rmse:0.926371
#
# [10]	eval-rmse:0.950481	train-rmse:0.925879
#
# [11]	eval-rmse:0.949947	train-rmse:0.925343
#
# [12]	eval-rmse:0.949388	train-rmse:0.924738
#
# [13]	eval-rmse:0.948862	train-rmse:0.92411
#
# [14]	eval-rmse:0.948358	train-rmse:0.923479
#
# [15]	eval-rmse:0.947862	train-rmse:0.922846
#
# [16]	eval-rmse:0.947355	train-rmse:0.922179
#
# [17]	eval-rmse:0.946814	train-rmse:0.921552
#
# [18]	eval-rmse:0.946298	train-rmse:0.920982
#
# [19]	eval-rmse:0.945791	train-rmse:0.920441
#
# [20]	eval-rmse:0.945296	train-rmse:0.919936
#
# [21]	eval-rmse:0.944803	train-rmse:0.919423
#
# [22]	eval-rmse:0.94429	train-rmse:0.918894
#
# [23]	eval-rmse:0.943812	train-rmse:0.918346
#
# [24]	eval-rmse:0.943285	train-rmse:0.917782
#
# [25]	eval-rmse:0.942768	train-rmse:0.91719
#
# [26]	eval-rmse:0.942276	train-rmse:0.916568
#
# [27]	eval-rmse:0.941777	train-rmse:0.915976
#
# [28]	eval-rmse:0.941278	train-rmse:0.915416
#
# [29]	eval-rmse:0.940778	train-rmse:0.914875
#
# [0]	eval-rmse:0.954476	train-rmse:0.930655
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.953011	train-rmse:0.92852
#
# [2]	eval-rmse:0.951354	train-rmse:0.926618
#
# [3]	eval-rmse:0.949709	train-rmse:0.925013
#
# [4]	eval-rmse:0.948038	train-rmse:0.922998
#
# [5]	eval-rmse:0.946388	train-rmse:0.921089
#
# [6]	eval-rmse:0.944885	train-rmse:0.919498
#
# [7]	eval-rmse:0.943273	train-rmse:0.917711
#
# [8]	eval-rmse:0.94167	train-rmse:0.915864
#
# [9]	eval-rmse:0.940084	train-rmse:0.914221
#
# [10]	eval-rmse:0.938631	train-rmse:0.912618
#
# [11]	eval-rmse:0.937107	train-rmse:0.910999
#
# [12]	eval-rmse:0.935611	train-rmse:0.909328
#
# [13]	eval-rmse:0.934106	train-rmse:0.907691
#
# [14]	eval-rmse:0.932685	train-rmse:0.906076
#
# [15]	eval-rmse:0.931325	train-rmse:0.904502
#
# [16]	eval-rmse:0.929978	train-rmse:0.902881
#
# [17]	eval-rmse:0.928587	train-rmse:0.901271
#
# [18]	eval-rmse:0.927108	train-rmse:0.899731
#
# [19]	eval-rmse:0.925703	train-rmse:0.898157
#
# [20]	eval-rmse:0.924316	train-rmse:0.896589
#
# [21]	eval-rmse:0.922992	train-rmse:0.895072
#
# [22]	eval-rmse:0.921727	train-rmse:0.893637
#
# [23]	eval-rmse:0.920401	train-rmse:0.892215
#
# [24]	eval-rmse:0.919044	train-rmse:0.890799
#
# [25]	eval-rmse:0.917749	train-rmse:0.88942
#
# [26]	eval-rmse:0.916539	train-rmse:0.887976
#
# [27]	eval-rmse:0.915365	train-rmse:0.886556
#
# [28]	eval-rmse:0.914193	train-rmse:0.885119
#
# ...
#
# [27]	eval-rmse:0.935986	train-rmse:0.910375
#
# [28]	eval-rmse:0.935247	train-rmse:0.909612
#
# [29]	eval-rmse:0.934589	train-rmse:0.908896
#
# [30]	eval-rmse:0.933936	train-rmse:0.908163
#
# [31]	eval-rmse:0.933272	train-rmse:0.907458
#
# [32]	eval-rmse:0.932667	train-rmse:0.906771
#
# [33]	eval-rmse:0.932065	train-rmse:0.906085
#
# [34]	eval-rmse:0.931436	train-rmse:0.905365
#
# [35]	eval-rmse:0.930828	train-rmse:0.9046
#
# [36]	eval-rmse:0.93022	train-rmse:0.903854
#
# [0]	eval-rmse:0.955011	train-rmse:0.931212
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.953628	train-rmse:0.929576
# [2]	eval-rmse:0.952331	train-rmse:0.927888
#
# [3]	eval-rmse:0.951077	train-rmse:0.926673
#
# [4]	eval-rmse:0.949646	train-rmse:0.925319
#
# [5]	eval-rmse:0.948373	train-rmse:0.923737
#
# [6]	eval-rmse:0.947093	train-rmse:0.922168
#
# [7]	eval-rmse:0.945893	train-rmse:0.920859
#
# [8]	eval-rmse:0.944606	train-rmse:0.919525
#
# [9]	eval-rmse:0.94325	train-rmse:0.918087
#
# [10]	eval-rmse:0.942026	train-rmse:0.916734
#
# [11]	eval-rmse:0.94074	train-rmse:0.915402
#
# [12]	eval-rmse:0.939487	train-rmse:0.91414
#
# [13]	eval-rmse:0.938369	train-rmse:0.912893
#
# [14]	eval-rmse:0.937267	train-rmse:0.911653
#
# [15]	eval-rmse:0.936075	train-rmse:0.910402
#
# [16]	eval-rmse:0.93482	train-rmse:0.909095
#
# [17]	eval-rmse:0.933641	train-rmse:0.907798
#
# [18]	eval-rmse:0.932547	train-rmse:0.906594
#
# [19]	eval-rmse:0.931419	train-rmse:0.905348
#
# [20]	eval-rmse:0.930271	train-rmse:0.904031
#
# [21]	eval-rmse:0.929167	train-rmse:0.902794
#
# [22]	eval-rmse:0.928021	train-rmse:0.901584
#
# [23]	eval-rmse:0.92697	train-rmse:0.900313
#
# [24]	eval-rmse:0.92581	train-rmse:0.89908
#
# [25]	eval-rmse:0.924711	train-rmse:0.897929
#
# [26]	eval-rmse:0.923711	train-rmse:0.89677
#
# [27]	eval-rmse:0.922712	train-rmse:0.895669
#
# [28]	eval-rmse:0.921711	train-rmse:0.894565
#
# [29]	eval-rmse:0.920746	train-rmse:0.893521
#
# [30]	eval-rmse:0.919718	train-rmse:0.892419
#
# [31]	eval-rmse:0.918685	train-rmse:0.891292
#
# [32]	eval-rmse:0.917749	train-rmse:0.890171
#
# [33]	eval-rmse:0.916792	train-rmse:0.889076
#
# [34]	eval-rmse:0.915825	train-rmse:0.888013
#
# [0]	eval-rmse:0.955359	train-rmse:0.931607
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.95367	train-rmse:0.929871
#
# [2]	eval-rmse:0.952812	train-rmse:0.92842
#
# [3]	eval-rmse:0.951203	train-rmse:0.926891
#
# [4]	eval-rmse:0.949939	train-rmse:0.92583
#
# [5]	eval-rmse:0.948572	train-rmse:0.924427
#
# [6]	eval-rmse:0.947381	train-rmse:0.92277
#
# [7]	eval-rmse:0.946016	train-rmse:0.921444
#
# [8]	eval-rmse:0.945045	train-rmse:0.92049
#
# [9]	eval-rmse:0.943634	train-rmse:0.919111
#
# [10]	eval-rmse:0.942399	train-rmse:0.917732
#
# [11]	eval-rmse:0.941262	train-rmse:0.916475
#
# [12]	eval-rmse:0.939979	train-rmse:0.915246
#
# [13]	eval-rmse:0.938959	train-rmse:0.914153
#
# [14]	eval-rmse:0.937797	train-rmse:0.912979
#
# [0]	eval-rmse:0.955302	train-rmse:0.931298
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.954238	train-rmse:0.929904
#
# [2]	eval-rmse:0.953222	train-rmse:0.928345
#
# [3]	eval-rmse:0.952151	train-rmse:0.9271
#
# [4]	eval-rmse:0.951019	train-rmse:0.925905
#
# [5]	eval-rmse:0.949946	train-rmse:0.924575
#
# [6]	eval-rmse:0.948925	train-rmse:0.923138
#
# [7]	eval-rmse:0.947902	train-rmse:0.921829
#
# [8]	eval-rmse:0.94686	train-rmse:0.920625
#
# [9]	eval-rmse:0.945798	train-rmse:0.919374
#
# [10]	eval-rmse:0.944754	train-rmse:0.918111
#
# [11]	eval-rmse:0.943693	train-rmse:0.916863
#
# [12]	eval-rmse:0.942656	train-rmse:0.91565
#
# [13]	eval-rmse:0.941773	train-rmse:0.914459
#
# [14]	eval-rmse:0.940847	train-rmse:0.913309
#
# [15]	eval-rmse:0.939895	train-rmse:0.912119
#
# [16]	eval-rmse:0.938945	train-rmse:0.910932
#
# [17]	eval-rmse:0.937997	train-rmse:0.909737
#
# [18]	eval-rmse:0.937006	train-rmse:0.908591
#
# [19]	eval-rmse:0.936069	train-rmse:0.907434
#
# [20]	eval-rmse:0.935088	train-rmse:0.906264
#
# [21]	eval-rmse:0.934181	train-rmse:0.905056
#
# [22]	eval-rmse:0.933263	train-rmse:0.903858
#
# [23]	eval-rmse:0.932384	train-rmse:0.902687
#
# [24]	eval-rmse:0.931434	train-rmse:0.901545
#
# [25]	eval-rmse:0.930491	train-rmse:0.90045
#
# [26]	eval-rmse:0.929615	train-rmse:0.899275
#
# [27]	eval-rmse:0.928798	train-rmse:0.898144
#
# [0]	eval-rmse:0.955674	train-rmse:0.931815
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.954288	train-rmse:0.930597
#
# [2]	eval-rmse:0.953566	train-rmse:0.929414
#
# [3]	eval-rmse:0.952662	train-rmse:0.928313
#
# [4]	eval-rmse:0.951664	train-rmse:0.927134
#
# [5]	eval-rmse:0.950829	train-rmse:0.926486
#
# [6]	eval-rmse:0.949917	train-rmse:0.925649
#
# [7]	eval-rmse:0.94895	train-rmse:0.924564
#
# [8]	eval-rmse:0.948067	train-rmse:0.92356
#
# [9]	eval-rmse:0.947185	train-rmse:0.922347
#
# [10]	eval-rmse:0.946277	train-rmse:0.921403
#
# [11]	eval-rmse:0.945429	train-rmse:0.920574
#
# [12]	eval-rmse:0.944547	train-rmse:0.919705
#
# [13]	eval-rmse:0.943712	train-rmse:0.91881
# [14]	eval-rmse:0.94279	train-rmse:0.917774
#
# [15]	eval-rmse:0.94194	train-rmse:0.916784
#
# [16]	eval-rmse:0.94119	train-rmse:0.915878
#
# [17]	eval-rmse:0.94027	train-rmse:0.914974
#
# [18]	eval-rmse:0.939398	train-rmse:0.914149
#
# [19]	eval-rmse:0.938591	train-rmse:0.913356
#
# [20]	eval-rmse:0.937778	train-rmse:0.912498
#
# [0]	eval-rmse:0.955884	train-rmse:0.931975
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.954812	train-rmse:0.931008
#
# [2]	eval-rmse:0.954096	train-rmse:0.930336
#
# [3]	eval-rmse:0.953591	train-rmse:0.929358
#
# [4]	eval-rmse:0.952828	train-rmse:0.928485
#
# [5]	eval-rmse:0.952053	train-rmse:0.927522
#
# [6]	eval-rmse:0.95143	train-rmse:0.926923
#
# [7]	eval-rmse:0.950797	train-rmse:0.926397
#
# [8]	eval-rmse:0.950115	train-rmse:0.925749
#
# [9]	eval-rmse:0.949392	train-rmse:0.924936
#
# [10]	eval-rmse:0.948675	train-rmse:0.924105
#
# [0]	eval-rmse:0.955411	train-rmse:0.931462
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.954338	train-rmse:0.930224
#
# [2]	eval-rmse:0.953436	train-rmse:0.928807
#
# [3]	eval-rmse:0.952401	train-rmse:0.927519
#
# [4]	eval-rmse:0.951383	train-rmse:0.926523
#
# [5]	eval-rmse:0.950448	train-rmse:0.925406
#
# [6]	eval-rmse:0.949454	train-rmse:0.924175
#
# [7]	eval-rmse:0.948524	train-rmse:0.922913
#
# [8]	eval-rmse:0.947555	train-rmse:0.921766
#
# [9]	eval-rmse:0.946626	train-rmse:0.920669
#
# [10]	eval-rmse:0.945626	train-rmse:0.91957
#
# [11]	eval-rmse:0.944607	train-rmse:0.918435
#
# [12]	eval-rmse:0.943639	train-rmse:0.917295
#
# [13]	eval-rmse:0.942766	train-rmse:0.916178
#
# [14]	eval-rmse:0.94192	train-rmse:0.91514
#
# [15]	eval-rmse:0.941003	train-rmse:0.914095
#
# [16]	eval-rmse:0.940106	train-rmse:0.913043
#
# [17]	eval-rmse:0.939278	train-rmse:0.911983
#
# [18]	eval-rmse:0.938376	train-rmse:0.910974
#
# [19]	eval-rmse:0.937447	train-rmse:0.909929
#
# [20]	eval-rmse:0.936533	train-rmse:0.908858
#
# [21]	eval-rmse:0.935675	train-rmse:0.907805
#
# [22]	eval-rmse:0.934849	train-rmse:0.906745
#
# [23]	eval-rmse:0.933989	train-rmse:0.905678
#
# [24]	eval-rmse:0.933104	train-rmse:0.904634
#
# [25]	eval-rmse:0.9322	train-rmse:0.903635
#
# [26]	eval-rmse:0.931361	train-rmse:0.902577
#
# [27]	eval-rmse:0.930556	train-rmse:0.901573
#
# [28]	eval-rmse:0.929773	train-rmse:0.900527
#
# [29]	eval-rmse:0.928996	train-rmse:0.899533
#
# [30]	eval-rmse:0.928198	train-rmse:0.898508
#
# [31]	eval-rmse:0.927412	train-rmse:0.897501
#
# [32]	eval-rmse:0.926686	train-rmse:0.896523
#
# [33]	eval-rmse:0.925896	train-rmse:0.895571
#
# [34]	eval-rmse:0.925159	train-rmse:0.894645
#
# [35]	eval-rmse:0.924351	train-rmse:0.893692
#
# [36]	eval-rmse:0.923674	train-rmse:0.89273
#
# [37]	eval-rmse:0.922877	train-rmse:0.891803
#
# [0]	eval-rmse:0.956284	train-rmse:0.932309
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.95614	train-rmse:0.93216
#
# [2]	eval-rmse:0.955937	train-rmse:0.931988
#
# [3]	eval-rmse:0.955727	train-rmse:0.931816
#
# [4]	eval-rmse:0.955282	train-rmse:0.931453
#
# [5]	eval-rmse:0.954811	train-rmse:0.93097
#
# [6]	eval-rmse:0.954465	train-rmse:0.930706
#
# [7]	eval-rmse:0.954238	train-rmse:0.930513
#
# [8]	eval-rmse:0.954045	train-rmse:0.930293
#
# [9]	eval-rmse:0.953897	train-rmse:0.93002
#
# 100%|██████████| 100/100 [1:32:43<00:00, 62.96s/it, best loss: -0.08851941895281504]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-0c2c656d9fd7> in <module>()
#       3 best = fmin(xgboost_factory, space, algo=algo, max_evals=100, pass_expr_memo_ctrl=None)
#       4 store = best
# ----> 5 print("the best parameter before transformation is:" + best)
#       6 print("the best parameter after transformation is:" + argsDict_tranform(best))
#
# TypeError: must be str, not dict

# %%
best
# Out:
# {'alpha': 0.5044419515831545,
#  'lambda': 0.023551513057876713,
#  'learning_rate': 0.049121011680094875,
#  'max_depth': 2,
#  'min_child_weight': 0,
#  'n_estimators': 11,
#  'subsample': 0}

# %%
argsDict_tranform(best)
# Out:
# {'alpha': 10.08883903166309,
#  'lambda': 1.1775756528938357,
#  'learning_rate': 0.0019824202336018977,
#  'max_depth': 7,
#  'min_child_weight': 1,
#  'n_estimators': 21,
#  'subsample': 0.5}

# %%
best
# Out:
# {'alpha': 1216.9753467453504,
#  'lambda': 1078.9878530966914,
#  'learning_rate': 0.0010237485529570754,
#  'max_depth': 17,
#  'min_child_weight': 7,
#  'n_estimators': 49,
#  'subsample': 0.558}

# %%
def xgboost_factory_notrans(argsDict):
    
    params = {'nthread': -1,  # 进程数
              'max_depth': argsDict['max_depth'],  # 最大深度
              'n_estimators': argsDict['n_estimators'],  # 树的数量
              'eta': argsDict['learning_rate'],  # 学习率
              'subsample': argsDict['subsample'],  # 采样数
              'min_child_weight': argsDict['min_child_weight'],  # 终点节点最小样本占比的和
              'objective': 'reg:squarederror',
              'silent': 0,  # 是否显示
              'gamma': 0,  # 是否后剪枝
              'colsample_bytree': 0.7,  # 样本列采样
              'alpha': argsDict['alpha'],  # L1 正则化
              'lambda': argsDict['lambda'],  # L2 正则化
              'scale_pos_weight': 0,  # 取值>0时,在数据不平衡时有助于收敛
              'seed': 100,  # 随机种子
              'tree_method':'exact'
              }

    xrf = xgb.train(params, dtrain, params['n_estimators'], evallist,early_stopping_rounds=100)

    return get_tranformer_score(xrf)

xgboost_factory_notrans(best)
# Out:
# [0]	eval-rmse:0.956294	train-rmse:0.932323
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
# Will train until train-rmse hasn't improved in 100 rounds.
# [1]	eval-rmse:0.956204	train-rmse:0.932242
# [2]	eval-rmse:0.955814	train-rmse:0.931945
# [3]	eval-rmse:0.955778	train-rmse:0.931912
# [4]	eval-rmse:0.955707	train-rmse:0.931841
# [5]	eval-rmse:0.954407	train-rmse:0.930852
# [6]	eval-rmse:0.954307	train-rmse:0.930755
# [7]	eval-rmse:0.954263	train-rmse:0.930723
# [8]	eval-rmse:0.953948	train-rmse:0.93052
# [9]	eval-rmse:0.953839	train-rmse:0.930419
# [10]	eval-rmse:0.953808	train-rmse:0.930382
# [11]	eval-rmse:0.953647	train-rmse:0.929275
# [12]	eval-rmse:0.953591	train-rmse:0.929216
# [13]	eval-rmse:0.953194	train-rmse:0.928925
# [14]	eval-rmse:0.95316	train-rmse:0.92889
# [15]	eval-rmse:0.953073	train-rmse:0.928812
# [16]	eval-rmse:0.951963	train-rmse:0.927507
# [17]	eval-rmse:0.951928	train-rmse:0.927474
# [18]	eval-rmse:0.951848	train-rmse:0.927389
# [19]	eval-rmse:0.951454	train-rmse:0.927098
# [20]	eval-rmse:0.951544	train-rmse:0.927128
# [21]	eval-rmse:0.95135	train-rmse:0.926998
# [22]	eval-rmse:0.951355	train-rmse:0.926989
# [23]	eval-rmse:0.951221	train-rmse:0.926886
# [24]	eval-rmse:0.951337	train-rmse:0.9271
# [25]	eval-rmse:0.950872	train-rmse:0.926654
# [26]	eval-rmse:0.950791	train-rmse:0.926564
# [27]	eval-rmse:0.950728	train-rmse:0.926513
# [28]	eval-rmse:0.949402	train-rmse:0.925485
# [29]	eval-rmse:0.949343	train-rmse:0.925424
# [30]	eval-rmse:0.949311	train-rmse:0.925394
# [31]	eval-rmse:0.948935	train-rmse:0.925101
# [32]	eval-rmse:0.948825	train-rmse:0.92501
# [33]	eval-rmse:0.948964	train-rmse:0.925194
# [34]	eval-rmse:0.948713	train-rmse:0.92356
# [35]	eval-rmse:0.948643	train-rmse:0.923478
# [36]	eval-rmse:0.948224	train-rmse:0.923167
# [37]	eval-rmse:0.948314	train-rmse:0.923192
# [38]	eval-rmse:0.948134	train-rmse:0.923079
# [39]	eval-rmse:0.946836	train-rmse:0.922062
# [40]	eval-rmse:0.946793	train-rmse:0.922034
# [41]	eval-rmse:0.946818	train-rmse:0.922177
# [42]	eval-rmse:0.946445	train-rmse:0.921897
# [43]	eval-rmse:0.946334	train-rmse:0.921707
# [44]	eval-rmse:0.946226	train-rmse:0.921613
# [45]	eval-rmse:0.946313	train-rmse:0.921645
# [46]	eval-rmse:0.946273	train-rmse:0.921616
# [47]	eval-rmse:0.946102	train-rmse:0.921492
# [48]	eval-rmse:0.945715	train-rmse:0.921198
# -0.03290653323531516

# %%
bst=xgb.train(params,dtrain=dtrain,num_boost_round=1,early_stopping_rounds=None,evals=[(dtrain,'train'),(ddev,'test')],verbose_eval=3)
# Out:
# [0]	train-rmse:0.926187	test-rmse:0.896756

# %%
xrf = xgb.train(params, dtrain,num_boost_round=1,early_stopping_rounds=None)

# %%
# first time training

bst=xgb.train(params=xgb_param,dtrain=dtrain,num_boost_round=1,early_stopping_rounds=None,evals=[(dtrain,'train'),(ddev,'test')],verbose_eval=3)
pred = bst.predict(dtest)
predtrain = bst.predict(dtrain)
print(pearsonr(np.array(yp_train), predtrain))
print(pearsonr(np.array(yp_test), pred))


# first time training - continued
for kk in range(29):
    bst=xgb.train(params=xgb_param,dtrain=dtrain,num_boost_round=1,early_stopping_rounds=None,evals=[(dtrain,'train'),(ddev,'test')],verbose_eval=3, xgb_model = bst)
    pred = bst.predict(dtest)
    predtrain = bst.predict(dtrain)
print(pearsonr(np.array(yp_train), predtrain))
# print(pearsonr(np.array(y_train.T)[0], predtrain))
print(pearsonr(np.array(yp_test), pred))
# print(pearsonr(np.array(y_test.T)[0], pred))

# concatenate predictions

g =  train[["TradingDay", "SecuCode"]][time_ind[train_days]:time_ind[train_days+delta_days]]
g["NextCatPred"] = pred
k = g.pivot_table(columns='SecuCode', index='TradingDay', values='NextCatPred').reset_index().sort_values("TradingDay")

# %%
# second traininng and so on

# change dataset
drift = 1
while drift * delta_days + train_days + delta_days < len(time_ind):
    X_train = X[time_ind[drift * delta_days]:time_ind[train_days + drift * delta_days]]
    X_test = X[time_ind[train_days + drift * delta_days]:time_ind[train_days+delta_days + drift * delta_days]]
    y_train = y[time_ind[drift * delta_days]:time_ind[train_days + drift * delta_days]]
    y_test = y[time_ind[train_days + drift * delta_days]:time_ind[train_days+delta_days + drift * delta_days]]
    yp_train = yp[time_ind[drift * delta_days]:time_ind[train_days + drift * delta_days]]
    yp_test = yp[time_ind[train_days + drift * delta_days]:time_ind[train_days+delta_days + drift * delta_days]]
    dtrain = xgb.DMatrix(data=X_train, label=y_train)
    dtest = xgb.DMatrix(data=X_test)
    ddev = xgb.DMatrix(data=X_test, label=y_test)
    bst=xgb.train(params=xgb_param,dtrain=dtrain,num_boost_round=1,early_stopping_rounds=None,evals=[(dtrain,'train'),(ddev,'test')],verbose_eval=3)

    for kk in range(29):
        bst=xgb.train(params=xgb_param,dtrain=dtrain,num_boost_round=1,early_stopping_rounds=None,evals=[(dtrain,'train'),(ddev,'test')],verbose_eval=3, xgb_model = bst)
#         bst=xgb.train(params=xgb_param,dtrain=dtrain,num_boost_round=1,early_stopping_rounds=None,evals=[(dtrain,'train'),(ddev,'test')],verbose_eval=3)
        pred = bst.predict(dtest)
        predtrain = bst.predict(dtrain)
    print(pearsonr(np.array(yp_train), predtrain))
    # print(pearsonr(np.array(y_train.T)[0], predtrain))
    print(pearsonr(np.array(yp_test), pred))
    # print(pearsonr(np.array(y_test.T)[0], pred))
    gt =  train[["TradingDay", "SecuCode"]][time_ind[train_days + drift * delta_days]:time_ind[train_days+delta_days + drift * delta_days]]
    gt["NextCatPred"] = pred
    kt = gt.pivot_table(columns='SecuCode', index='TradingDay', values='NextCatPred').reset_index().sort_values("TradingDay")
    k = pd.concat([k, kt],ignore_index=True)
    drift += 1

# the last dataset
if drift * delta_days + train_days + delta_days > len(time_ind):
    X_train = X[time_ind[drift * delta_days]:time_ind[train_days + drift * delta_days]]
    X_test = X[time_ind[train_days + drift * delta_days]:]
    y_train = y[time_ind[drift * delta_days]:time_ind[train_days + drift * delta_days]]
    y_test = y[time_ind[train_days + drift * delta_days]:]
    yp_train = yp[time_ind[drift * delta_days]:time_ind[train_days + drift * delta_days]]
    yp_test = yp[time_ind[train_days + drift * delta_days]:]
    dtrain = xgb.DMatrix(data=X_train, label=y_train)
    dtest = xgb.DMatrix(data=X_test)
    ddev = xgb.DMatrix(data=X_test, label=y_test)
    bst=xgb.train(params=xgb_param,dtrain=dtrain,num_boost_round=1,early_stopping_rounds=None,evals=[(dtrain,'train'),(ddev,'test')],verbose_eval=3)

    for kk in range(29):
        bst=xgb.train(params=xgb_param,dtrain=dtrain,num_boost_round=1,early_stopping_rounds=None,evals=[(dtrain,'train'),(ddev,'test')],verbose_eval=3, xgb_model = bst)
        pred = bst.predict(dtest)
        predtrain = bst.predict(dtrain)
    print(pearsonr(np.array(yp_train), predtrain))
    # print(pearsonr(np.array(y_train.T)[0], predtrain))
    print(pearsonr(np.array(yp_test), pred))
    # print(pearsonr(np.array(y_test.T)[0], pred))
    gt =  train[["TradingDay", "SecuCode"]][time_ind[train_days + drift * delta_days]:]
    gt["NextCatPred"] = pred
    kt = gt.pivot_table(columns='SecuCode', index='TradingDay', values='NextCatPred').reset_index().sort_values("TradingDay")
    k = pd.concat([k, kt],ignore_index=True)

k.set_index("TradingDay").to_csv("0805back_input_30_30.csv")
