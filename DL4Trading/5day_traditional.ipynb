# %%
import pandas as pd
import numpy as np
import xgboost as xgb
import matplotlib.pylab as plt
from scipy.stats import pearsonr

from hyperopt import fmin, tpe, hp, partial


def find_time_ind(df):
    day_ind = [0]
    day_temp = df["TradingDay"][0]
    for i in range(1, len(df)):
        if df["TradingDay"][i] != day_temp:
            day_ind.append(i)
            day_temp = df["TradingDay"][i]
    return day_ind

# %%
# input cell
train = pd.read_csv('0805rolling5.csv')
# train = pd.read_csv('08053before_rolling.csv')
# train = pd.read_csv('08052acou_and_factors.csv')
x_column = ["factor"+str(i)+'_'+str(j) for i in range(0,17) for j in range(5)]
# x_column = ["factor"+str(i) for i in range(0,17)]
# for i in range(12):
#     for j in range(5):
#         x_column.append("10M" + str(i) +'_'+str(j))
# for i in range(12):
#     x_column.append("10M" + str(i))

train = train.sort_values(by = ["TradingDay", "SecuCode"], ascending = [True, True])
train.reset_index(drop=True, inplace=True)
X = train[x_column]
target = ['NextReturnCate']
y = train[target]
y += 1
yp = train["NextReturn"]
time_ind = find_time_ind(train)

# %%
# initializing
train_days = 775
delta_days = -776
X_train = X[time_ind[0]:time_ind[train_days]]
X_test = X[time_ind[train_days]:time_ind[train_days+delta_days]]
y_train = y[time_ind[0]:time_ind[train_days]]
y_test = y[time_ind[train_days]:time_ind[train_days+delta_days]]
yp_train = yp[time_ind[0]:time_ind[train_days]]
yp_test = yp[time_ind[train_days]:time_ind[train_days+delta_days]]
dtrain = xgb.DMatrix(data=X_train, label=y_train)
dtest = xgb.DMatrix(data=X_test)
ddev = xgb.DMatrix(data=X_test, label=y_test)

evallist = [(ddev, 'eval'), (dtrain, 'train')]

# %%
# 自定义hyperopt的参数空间
space = {"max_depth": hp.randint("max_depth", 25),
         "n_estimators": hp.randint("n_estimators", 30),
         'learning_rate': hp.uniform('learning_rate', 1e-3, 5e-1),
         "subsample": hp.randint("subsample", 5),
         "min_child_weight": hp.randint("min_child_weight", 6),
         "alpha": hp.uniform("alpha", 0, 1),
         "lambda": hp.uniform("lambda", 0, 1)
         }

def argsDict_tranform(argsDict, isPrint=False):
    argsDict["max_depth"] = argsDict["max_depth"] + 5    # from 5 to 30
    argsDict['n_estimators'] = argsDict['n_estimators'] + 10  # from 10 to 40
    argsDict["learning_rate"] = argsDict["learning_rate"] * 0.02 + 0.001   # from 0.001 to 0.01
    argsDict["subsample"] = argsDict["subsample"] * 0.1 + 0.5  # from 0.5 to 1
    argsDict["min_child_weight"] = argsDict["min_child_weight"] + 1 # from 1 to 6
    argsDict["alpha"] = argsDict["alpha"] * 20
    argsDict["lambda"] = argsDict["lambda"] * 50
    if isPrint:
        print(argsDict)
    else:
        pass

    return argsDict

# %%
from sklearn.metrics import mean_squared_error, zero_one_loss

def xgboost_factory(argsDict):
    argsDict = argsDict_tranform(argsDict)
    
    params = {'nthread': -1,  # 进程数
              'max_depth': argsDict['max_depth'],  # 最大深度
              'n_estimators': argsDict['n_estimators'],  # 树的数量
              'eta': argsDict['learning_rate'],  # 学习率
              'subsample': argsDict['subsample'],  # 采样数
              'min_child_weight': argsDict['min_child_weight'],  # 终点节点最小样本占比的和
              'objective': 'reg:squarederror',
              'silent': 0,  # 是否显示
              'gamma': 0,  # 是否后剪枝
              'colsample_bytree': 0.7,  # 样本列采样
              'alpha': argsDict['alpha'],  # L1 正则化
              'lambda': argsDict['lambda'],  # L2 正则化
              'scale_pos_weight': 0,  # 取值>0时,在数据不平衡时有助于收敛
              'seed': 100,  # 随机种子
              'tree_method':'exact'
              }

    xrf = xgb.train(params, dtrain, params['n_estimators'], evallist,early_stopping_rounds=100)

    return get_tranformer_score(xrf)


def get_tranformer_score(tranformer):
    
    xrf = tranformer
    pred = xrf.predict(ddev, ntree_limit=xrf.best_ntree_limit)
  
    return -pearsonr(np.array(yp_test), pred)[0]

# %%
# 开始使用hyperopt进行自动调参
algo = partial(tpe.suggest, n_startup_jobs=1)
best = fmin(xgboost_factory, space, algo=algo, max_evals=100, pass_expr_memo_ctrl=None)
store = best
print("the best parameter before transformation is:" + best)
print("the best parameter after transformation is:" + argsDict_tranform(best))
# Out:
# [0]	eval-rmse:0.956051	train-rmse:0.929969
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.95452	train-rmse:0.927153
#
# [2]	eval-rmse:0.952931	train-rmse:0.924781
#
# [3]	eval-rmse:0.951267	train-rmse:0.922233
#
# [4]	eval-rmse:0.949732	train-rmse:0.919717
#
# [5]	eval-rmse:0.94814	train-rmse:0.917359
#
# [6]	eval-rmse:0.946586	train-rmse:0.914954
#
# [7]	eval-rmse:0.945101	train-rmse:0.91262
#
# [8]	eval-rmse:0.943708	train-rmse:0.910312
#
# [9]	eval-rmse:0.942272	train-rmse:0.908002
#
# [10]	eval-rmse:0.940817	train-rmse:0.905658
#
# [11]	eval-rmse:0.939378	train-rmse:0.903297
#
# [12]	eval-rmse:0.93797	train-rmse:0.900979
#
# [13]	eval-rmse:0.936629	train-rmse:0.898672
#
# [14]	eval-rmse:0.935321	train-rmse:0.896432
#
# [15]	eval-rmse:0.933924	train-rmse:0.894135
#
# [16]	eval-rmse:0.932619	train-rmse:0.891893
#
# [17]	eval-rmse:0.931263	train-rmse:0.889639
#
# [18]	eval-rmse:0.929981	train-rmse:0.887478
#
# [19]	eval-rmse:0.928656	train-rmse:0.88537
#
# [20]	eval-rmse:0.927353	train-rmse:0.883246
#
# [21]	eval-rmse:0.926183	train-rmse:0.880983
#
# [22]	eval-rmse:0.924973	train-rmse:0.878873
#
# [23]	eval-rmse:0.923743	train-rmse:0.876768
#
# [24]	eval-rmse:0.922519	train-rmse:0.874738
#
# [0]	eval-rmse:0.955953	train-rmse:0.929563
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.954306	train-rmse:0.926537
#
# [2]	eval-rmse:0.95255	train-rmse:0.923729
#
# [3]	eval-rmse:0.950828	train-rmse:0.920808
#
# [4]	eval-rmse:0.94914	train-rmse:0.918057
#
# [5]	eval-rmse:0.947287	train-rmse:0.915392
#
# [6]	eval-rmse:0.945605	train-rmse:0.912655
#
# [7]	eval-rmse:0.94396	train-rmse:0.910125
#
# [8]	eval-rmse:0.942442	train-rmse:0.907558
#
# [9]	eval-rmse:0.940834	train-rmse:0.90485
#
# [10]	eval-rmse:0.939256	train-rmse:0.902222
#
# [11]	eval-rmse:0.937763	train-rmse:0.899598
#
# [12]	eval-rmse:0.936301	train-rmse:0.896933
#
# [13]	eval-rmse:0.934808	train-rmse:0.89435
#
# [14]	eval-rmse:0.933314	train-rmse:0.891863
#
# [15]	eval-rmse:0.93179	train-rmse:0.889281
#
# [16]	eval-rmse:0.930397	train-rmse:0.886766
#
# [17]	eval-rmse:0.928997	train-rmse:0.884276
#
# [18]	eval-rmse:0.927615	train-rmse:0.881816
#
# [19]	eval-rmse:0.926223	train-rmse:0.879443
#
# [20]	eval-rmse:0.924807	train-rmse:0.877053
#
# [21]	eval-rmse:0.923545	train-rmse:0.874561
#
# [22]	eval-rmse:0.922258	train-rmse:0.872171
#
# [23]	eval-rmse:0.920926	train-rmse:0.869847
#
# [24]	eval-rmse:0.919636	train-rmse:0.867573
#
# [0]	eval-rmse:0.957726	train-rmse:0.932092
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.957469	train-rmse:0.931835
#
# [2]	eval-rmse:0.957188	train-rmse:0.931585
#
# [3]	eval-rmse:0.95663	train-rmse:0.931066
#
# [4]	eval-rmse:0.956113	train-rmse:0.930534
#
# [5]	eval-rmse:0.955777	train-rmse:0.930267
#
# [6]	eval-rmse:0.955534	train-rmse:0.929952
#
# [7]	eval-rmse:0.955321	train-rmse:0.929519
#
# [8]	eval-rmse:0.955098	train-rmse:0.928967
#
# [9]	eval-rmse:0.954801	train-rmse:0.928511
#
# [10]	eval-rmse:0.954481	train-rmse:0.928094
#
# [11]	eval-rmse:0.954164	train-rmse:0.927652
#
# [0]	eval-rmse:0.957716	train-rmse:0.932073
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.957438	train-rmse:0.931815
#
# [2]	eval-rmse:0.957136	train-rmse:0.931545
#
# [3]	eval-rmse:0.956382	train-rmse:0.930864
#
# [4]	eval-rmse:0.955996	train-rmse:0.930473
#
# [5]	eval-rmse:0.955656	train-rmse:0.930182
#
# [6]	eval-rmse:0.955443	train-rmse:0.929811
#
# [7]	eval-rmse:0.955211	train-rmse:0.929307
#
# [8]	eval-rmse:0.954951	train-rmse:0.928746
#
# [9]	eval-rmse:0.954601	train-rmse:0.928322
#
# [10]	eval-rmse:0.954274	train-rmse:0.927876
#
# [11]	eval-rmse:0.953959	train-rmse:0.927402
#
# [12]	eval-rmse:0.953633	train-rmse:0.926976
#
# [13]	eval-rmse:0.953321	train-rmse:0.926668
#
# [14]	eval-rmse:0.953048	train-rmse:0.926403
#
# [15]	eval-rmse:0.952765	train-rmse:0.926131
#
# [16]	eval-rmse:0.952473	train-rmse:0.925809
#
# [17]	eval-rmse:0.952165	train-rmse:0.925478
#
# [18]	eval-rmse:0.951853	train-rmse:0.925142
#
# [19]	eval-rmse:0.951541	train-rmse:0.92477
#
# [20]	eval-rmse:0.951196	train-rmse:0.924344
#
# [21]	eval-rmse:0.950891	train-rmse:0.923931
#
# [22]	eval-rmse:0.950582	train-rmse:0.923545
#
# [23]	eval-rmse:0.950283	train-rmse:0.923161
#
# [24]	eval-rmse:0.949953	train-rmse:0.922681
#
# [25]	eval-rmse:0.94967	train-rmse:0.922252
#
# [26]	eval-rmse:0.949375	train-rmse:0.92187
#
# [27]	eval-rmse:0.949093	train-rmse:0.92152
#
# [28]	eval-rmse:0.948785	train-rmse:0.921166
#
# [29]	eval-rmse:0.948465	train-rmse:0.920807
#
# [30]	eval-rmse:0.948191	train-rmse:0.920461
#
# [31]	eval-rmse:0.947885	train-rmse:0.920123
#
# [0]	eval-rmse:0.957728	train-rmse:0.932095
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.957483	train-rmse:0.931853
#
# [2]	eval-rmse:0.957267	train-rmse:0.931654
#
# [3]	eval-rmse:0.956645	train-rmse:0.931152
#
# [4]	eval-rmse:0.95617	train-rmse:0.930648
#
# [5]	eval-rmse:0.955806	train-rmse:0.930378
#
# [6]	eval-rmse:0.955542	train-rmse:0.93007
#
# [7]	eval-rmse:0.955347	train-rmse:0.929669
#
# [8]	eval-rmse:0.955146	train-rmse:0.929208
#
# [9]	eval-rmse:0.954879	train-rmse:0.928775
#
# [10]	eval-rmse:0.954493	train-rmse:0.928312
#
# [11]	eval-rmse:0.954168	train-rmse:0.927897
#
# [0]	eval-rmse:0.957089	train-rmse:0.931419
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.95613	train-rmse:0.930223
#
# [2]	eval-rmse:0.955333	train-rmse:0.928852
#
# [3]	eval-rmse:0.954458	train-rmse:0.927583
#
# [4]	eval-rmse:0.953673	train-rmse:0.926531
#
# [5]	eval-rmse:0.952854	train-rmse:0.925446
#
# [6]	eval-rmse:0.952068	train-rmse:0.924286
#
# [7]	eval-rmse:0.951247	train-rmse:0.923157
#
# [8]	eval-rmse:0.950526	train-rmse:0.921997
#
# [9]	eval-rmse:0.949739	train-rmse:0.920856
#
# [10]	eval-rmse:0.949004	train-rmse:0.919731
#
# [11]	eval-rmse:0.948229	train-rmse:0.918612
#
# [12]	eval-rmse:0.947469	train-rmse:0.917511
#
# [13]	eval-rmse:0.946758	train-rmse:0.916449
#
# [14]	eval-rmse:0.946011	train-rmse:0.91537
#
# [15]	eval-rmse:0.945285	train-rmse:0.91432
#
# [16]	eval-rmse:0.944526	train-rmse:0.913254
#
# [17]	eval-rmse:0.943771	train-rmse:0.912212
#
# [18]	eval-rmse:0.94304	train-rmse:0.911179
#
# [19]	eval-rmse:0.942291	train-rmse:0.910151
#
# [20]	eval-rmse:0.941576	train-rmse:0.909099
#
# [0]	eval-rmse:0.955199	train-rmse:0.92969
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.952845	train-rmse:0.926571
#
# [2]	eval-rmse:0.950334	train-rmse:0.924035
#
# [3]	eval-rmse:0.948034	train-rmse:0.921189
#
# [4]	eval-rmse:0.945777	train-rmse:0.918765
#
# [5]	eval-rmse:0.943353	train-rmse:0.916034
#
# [6]	eval-rmse:0.94117	train-rmse:0.913688
#
# [7]	eval-rmse:0.938835	train-rmse:0.911347
#
# [8]	eval-rmse:0.93668	train-rmse:0.908901
#
# [9]	eval-rmse:0.934564	train-rmse:0.906498
#
# [10]	eval-rmse:0.932508	train-rmse:0.904138
#
# [11]	eval-rmse:0.930449	train-rmse:0.901681
#
# [0]	eval-rmse:0.955153	train-rmse:0.929625
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.952813	train-rmse:0.926532
#
# [2]	eval-rmse:0.950223	train-rmse:0.923969
#
# [3]	eval-rmse:0.947946	train-rmse:0.921109
#
# [4]	eval-rmse:0.945665	train-rmse:0.918656
#
# [5]	eval-rmse:0.943194	train-rmse:0.915884
#
# [6]	eval-rmse:0.94094	train-rmse:0.913497
#
# [7]	eval-rmse:0.938613	train-rmse:0.911145
#
# [8]	eval-rmse:0.936435	train-rmse:0.908647
#
# [9]	eval-rmse:0.934292	train-rmse:0.906264
#
# [10]	eval-rmse:0.932234	train-rmse:0.903863
#
# [11]	eval-rmse:0.930216	train-rmse:0.901425
#
# [12]	eval-rmse:0.928188	train-rmse:0.899091
#
# [13]	eval-rmse:0.926208	train-rmse:0.896842
#
# [14]	eval-rmse:0.92424	train-rmse:0.894706
#
# [15]	eval-rmse:0.922345	train-rmse:0.892626
#
# [16]	eval-rmse:0.920517	train-rmse:0.890528
#
# [17]	eval-rmse:0.918618	train-rmse:0.888358
#
# [18]	eval-rmse:0.916847	train-rmse:0.886268
#
# [19]	eval-rmse:0.915098	train-rmse:0.884262
#
# [20]	eval-rmse:0.913337	train-rmse:0.88227
#
# [21]	eval-rmse:0.911706	train-rmse:0.8803
#
# [22]	eval-rmse:0.910006	train-rmse:0.878343
#
# [23]	eval-rmse:0.90825	train-rmse:0.87651
#
# [24]	eval-rmse:0.906693	train-rmse:0.874691
#
# [25]	eval-rmse:0.905188	train-rmse:0.872944
#
# [26]	eval-rmse:0.903617	train-rmse:0.871192
#
# [27]	eval-rmse:0.902051	train-rmse:0.869397
#
# [28]	eval-rmse:0.900621	train-rmse:0.86764
#
# [29]	eval-rmse:0.899151	train-rmse:0.865938
#
# [30]	eval-rmse:0.897767	train-rmse:0.864235
#
# [31]	eval-rmse:0.896323	train-rmse:0.862665
#
# [32]	eval-rmse:0.894912	train-rmse:0.861115
#
# [33]	eval-rmse:0.89354	train-rmse:0.859501
#
# [34]	eval-rmse:0.892216	train-rmse:0.857953
#
# [35]	eval-rmse:0.890897	train-rmse:0.856403
#
# [36]	eval-rmse:0.889676	train-rmse:0.854936
#
# [37]	eval-rmse:0.888399	train-rmse:0.853459
#
# [0]	eval-rmse:0.955864	train-rmse:0.929419
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.953805	train-rmse:0.92645
#
# [2]	eval-rmse:0.951702	train-rmse:0.923477
#
# [3]	eval-rmse:0.949759	train-rmse:0.920558
#
# [4]	eval-rmse:0.947876	train-rmse:0.917753
#
# [5]	eval-rmse:0.945984	train-rmse:0.915007
#
# [6]	eval-rmse:0.944063	train-rmse:0.912282
#
# [7]	eval-rmse:0.942178	train-rmse:0.909659
#
# [8]	eval-rmse:0.940348	train-rmse:0.906969
#
# [9]	eval-rmse:0.938614	train-rmse:0.904304
#
# [10]	eval-rmse:0.936813	train-rmse:0.901625
#
# [11]	eval-rmse:0.935084	train-rmse:0.898952
#
# [12]	eval-rmse:0.933434	train-rmse:0.896332
#
# [13]	eval-rmse:0.93184	train-rmse:0.89377
#
# [14]	eval-rmse:0.930206	train-rmse:0.891268
#
# [15]	eval-rmse:0.928595	train-rmse:0.888722
#
# [16]	eval-rmse:0.926899	train-rmse:0.886199
#
# [17]	eval-rmse:0.925389	train-rmse:0.88373
#
# [18]	eval-rmse:0.923832	train-rmse:0.881309
#
# [19]	eval-rmse:0.922316	train-rmse:0.878954
#
# [20]	eval-rmse:0.920796	train-rmse:0.876614
#
# [21]	eval-rmse:0.91928	train-rmse:0.874253
#
# [22]	eval-rmse:0.917932	train-rmse:0.871885
#
# [0]	eval-rmse:0.956791	train-rmse:0.931264
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.955497	train-rmse:0.929771
#
# [2]	eval-rmse:0.954383	train-rmse:0.92815
#
# [3]	eval-rmse:0.953233	train-rmse:0.926736
#
# [4]	eval-rmse:0.952232	train-rmse:0.92561
#
# [5]	eval-rmse:0.951064	train-rmse:0.924307
#
# [6]	eval-rmse:0.949967	train-rmse:0.922855
#
# [7]	eval-rmse:0.948901	train-rmse:0.921585
#
# [8]	eval-rmse:0.947859	train-rmse:0.920347
#
# [9]	eval-rmse:0.946857	train-rmse:0.919101
#
# [10]	eval-rmse:0.945801	train-rmse:0.917814
#
# [11]	eval-rmse:0.944744	train-rmse:0.916473
#
# [12]	eval-rmse:0.943728	train-rmse:0.915229
#
# [13]	eval-rmse:0.942751	train-rmse:0.914052
#
# [14]	eval-rmse:0.9418	train-rmse:0.912874
#
# [15]	eval-rmse:0.940757	train-rmse:0.911699
#
# [16]	eval-rmse:0.939746	train-rmse:0.91051
#
# [17]	eval-rmse:0.938754	train-rmse:0.909287
#
# [18]	eval-rmse:0.937768	train-rmse:0.908083
#
# [0]	eval-rmse:0.955692	train-rmse:0.928805
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.953247	train-rmse:0.925371
#
# [2]	eval-rmse:0.950911	train-rmse:0.921868
#
# [3]	eval-rmse:0.948645	train-rmse:0.91849
#
# [4]	eval-rmse:0.946561	train-rmse:0.915217
#
# [5]	eval-rmse:0.944314	train-rmse:0.911973
#
# [6]	eval-rmse:0.94214	train-rmse:0.908745
#
# [7]	eval-rmse:0.939999	train-rmse:0.905683
#
# [8]	eval-rmse:0.937976	train-rmse:0.902533
#
# [9]	eval-rmse:0.936047	train-rmse:0.899342
#
# [10]	eval-rmse:0.93404	train-rmse:0.896213
#
# [11]	eval-rmse:0.932112	train-rmse:0.893107
#
# [12]	eval-rmse:0.930227	train-rmse:0.890082
#
# [13]	eval-rmse:0.92854	train-rmse:0.887098
#
# [14]	eval-rmse:0.926764	train-rmse:0.884147
#
# [15]	eval-rmse:0.924888	train-rmse:0.881194
#
# [16]	eval-rmse:0.923181	train-rmse:0.878228
#
# [17]	eval-rmse:0.921462	train-rmse:0.875298
#
# [18]	eval-rmse:0.919684	train-rmse:0.872464
#
# [19]	eval-rmse:0.917978	train-rmse:0.86976
#
# [20]	eval-rmse:0.916428	train-rmse:0.866951
#
# [21]	eval-rmse:0.914928	train-rmse:0.86415
#
# [22]	eval-rmse:0.913501	train-rmse:0.861428
#
# [23]	eval-rmse:0.912007	train-rmse:0.858678
#
# [24]	eval-rmse:0.910535	train-rmse:0.856064
#
# [25]	eval-rmse:0.909146	train-rmse:0.853387
#
# [26]	eval-rmse:0.907616	train-rmse:0.850732
#
# [0]	eval-rmse:0.956035	train-rmse:0.930611
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.954676	train-rmse:0.928543
#
# [2]	eval-rmse:0.952994	train-rmse:0.926646
#
# [3]	eval-rmse:0.951499	train-rmse:0.92526
#
# [4]	eval-rmse:0.949967	train-rmse:0.923424
#
# [5]	eval-rmse:0.94848	train-rmse:0.921514
#
# [6]	eval-rmse:0.946884	train-rmse:0.919974
#
# [7]	eval-rmse:0.945431	train-rmse:0.918441
#
# [8]	eval-rmse:0.943929	train-rmse:0.916651
#
# [9]	eval-rmse:0.942494	train-rmse:0.914981
#
# [10]	eval-rmse:0.941172	train-rmse:0.913467
#
# [11]	eval-rmse:0.939717	train-rmse:0.911906
#
# [12]	eval-rmse:0.938268	train-rmse:0.910348
#
# [13]	eval-rmse:0.936908	train-rmse:0.908813
#
# [14]	eval-rmse:0.93553	train-rmse:0.907177
#
# [15]	eval-rmse:0.93419	train-rmse:0.905706
#
# [16]	eval-rmse:0.932886	train-rmse:0.904203
#
# [17]	eval-rmse:0.931535	train-rmse:0.902574
#
# [18]	eval-rmse:0.930311	train-rmse:0.901077
#
# [19]	eval-rmse:0.929006	train-rmse:0.899678
#
# [20]	eval-rmse:0.927735	train-rmse:0.898191
#
# [21]	eval-rmse:0.926483	train-rmse:0.896696
#
# [0]	eval-rmse:0.957295	train-rmse:0.931745
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.955954	train-rmse:0.930598
#
# [2]	eval-rmse:0.955272	train-rmse:0.930008
#
# [3]	eval-rmse:0.95475	train-rmse:0.928809
#
# [4]	eval-rmse:0.953763	train-rmse:0.927729
#
# [5]	eval-rmse:0.953048	train-rmse:0.926891
#
# [6]	eval-rmse:0.952365	train-rmse:0.92637
#
# [7]	eval-rmse:0.951538	train-rmse:0.925738
#
# [8]	eval-rmse:0.950771	train-rmse:0.92491
#
# [9]	eval-rmse:0.950002	train-rmse:0.923948
#
# [10]	eval-rmse:0.94921	train-rmse:0.922864
#
# [11]	eval-rmse:0.948435	train-rmse:0.922045
#
# [12]	eval-rmse:0.94776	train-rmse:0.921242
#
# [13]	eval-rmse:0.947065	train-rmse:0.920575
#
# [14]	eval-rmse:0.946346	train-rmse:0.919863
#
# [0]	eval-rmse:0.955413	train-rmse:0.929814
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.953342	train-rmse:0.926792
#
# [2]	eval-rmse:0.95115	train-rmse:0.924356
#
# [3]	eval-rmse:0.949058	train-rmse:0.921622
#
# [4]	eval-rmse:0.947004	train-rmse:0.91921
#
# [5]	eval-rmse:0.944883	train-rmse:0.916789
#
# [6]	eval-rmse:0.942849	train-rmse:0.914291
#
# [7]	eval-rmse:0.940884	train-rmse:0.912041
#
# [8]	eval-rmse:0.939004	train-rmse:0.909728
#
# [9]	eval-rmse:0.937045	train-rmse:0.907343
#
# [10]	eval-rmse:0.935211	train-rmse:0.905098
#
# [11]	eval-rmse:0.933381	train-rmse:0.902698
#
# [12]	eval-rmse:0.931596	train-rmse:0.900364
#
# [13]	eval-rmse:0.929846	train-rmse:0.89815
#
# [14]	eval-rmse:0.928106	train-rmse:0.895949
#
# [15]	eval-rmse:0.926382	train-rmse:0.893728
#
# [16]	eval-rmse:0.924665	train-rmse:0.891621
#
# [17]	eval-rmse:0.923047	train-rmse:0.889572
#
# [18]	eval-rmse:0.92136	train-rmse:0.887517
#
# [19]	eval-rmse:0.919748	train-rmse:0.885454
#
# [20]	eval-rmse:0.918194	train-rmse:0.88347
#
# [21]	eval-rmse:0.916652	train-rmse:0.881389
#
# [22]	eval-rmse:0.915184	train-rmse:0.87934
#
# [23]	eval-rmse:0.913679	train-rmse:0.877432
#
# [24]	eval-rmse:0.91217	train-rmse:0.875559
#
# [25]	eval-rmse:0.910784	train-rmse:0.873676
#
# [26]	eval-rmse:0.909368	train-rmse:0.871836
#
# [27]	eval-rmse:0.907975	train-rmse:0.870044
#
# [28]	eval-rmse:0.906576	train-rmse:0.868254
#
# [29]	eval-rmse:0.905201	train-rmse:0.866494
#
# [30]	eval-rmse:0.903887	train-rmse:0.864729
#
# [31]	eval-rmse:0.90253	train-rmse:0.863017
#
# [32]	eval-rmse:0.901245	train-rmse:0.861298
#
# [33]	eval-rmse:0.900042	train-rmse:0.859611
#
# [0]	eval-rmse:0.956235	train-rmse:0.930819
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.955031	train-rmse:0.929016
#
# [2]	eval-rmse:0.953567	train-rmse:0.927158
#
# [3]	eval-rmse:0.952269	train-rmse:0.925829
#
# [4]	eval-rmse:0.950859	train-rmse:0.924308
#
# [5]	eval-rmse:0.949488	train-rmse:0.922585
#
# [6]	eval-rmse:0.94814	train-rmse:0.921028
#
# [7]	eval-rmse:0.946807	train-rmse:0.919635
#
# [8]	eval-rmse:0.945493	train-rmse:0.91813
#
# [9]	eval-rmse:0.944156	train-rmse:0.916582
#
# [10]	eval-rmse:0.942896	train-rmse:0.915041
#
# [11]	eval-rmse:0.941646	train-rmse:0.913616
#
# [12]	eval-rmse:0.940418	train-rmse:0.912191
#
# [13]	eval-rmse:0.939178	train-rmse:0.910794
#
# [14]	eval-rmse:0.937986	train-rmse:0.909366
#
# [15]	eval-rmse:0.93674	train-rmse:0.907923
#
# [16]	eval-rmse:0.935512	train-rmse:0.906489
#
# [17]	eval-rmse:0.934279	train-rmse:0.905124
#
# [18]	eval-rmse:0.933132	train-rmse:0.903762
#
# [19]	eval-rmse:0.931954	train-rmse:0.902319
#
# [0]	eval-rmse:0.955679	train-rmse:0.930006
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.953729	train-rmse:0.927112
#
# [2]	eval-rmse:0.951693	train-rmse:0.924904
#
# [3]	eval-rmse:0.949743	train-rmse:0.922281
#
# [4]	eval-rmse:0.947851	train-rmse:0.919963
#
# [5]	eval-rmse:0.945828	train-rmse:0.917601
#
# [6]	eval-rmse:0.943897	train-rmse:0.915339
#
# [7]	eval-rmse:0.941984	train-rmse:0.913231
#
# [8]	eval-rmse:0.940146	train-rmse:0.911017
#
# [9]	eval-rmse:0.938296	train-rmse:0.908787
#
# [10]	eval-rmse:0.936493	train-rmse:0.90657
#
# [11]	eval-rmse:0.934805	train-rmse:0.904355
#
# [12]	eval-rmse:0.933165	train-rmse:0.902163
#
# [13]	eval-rmse:0.931518	train-rmse:0.9001
#
# [14]	eval-rmse:0.929785	train-rmse:0.898021
#
# [15]	eval-rmse:0.928118	train-rmse:0.895972
#
# [16]	eval-rmse:0.926496	train-rmse:0.89394
#
# [17]	eval-rmse:0.924986	train-rmse:0.892
#
# [18]	eval-rmse:0.923433	train-rmse:0.890056
#
# [19]	eval-rmse:0.921826	train-rmse:0.888133
#
# [20]	eval-rmse:0.920351	train-rmse:0.886231
#
# [21]	eval-rmse:0.91886	train-rmse:0.884309
#
# [22]	eval-rmse:0.917474	train-rmse:0.882407
#
# [23]	eval-rmse:0.916017	train-rmse:0.880546
#
# [24]	eval-rmse:0.914552	train-rmse:0.878766
#
# [25]	eval-rmse:0.91322	train-rmse:0.876968
#
# [26]	eval-rmse:0.911891	train-rmse:0.875157
#
# [27]	eval-rmse:0.910581	train-rmse:0.87342
#
# [0]	eval-rmse:0.955097	train-rmse:0.929609
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.952644	train-rmse:0.926467
#
# [2]	eval-rmse:0.950147	train-rmse:0.923935
#
# [3]	eval-rmse:0.947792	train-rmse:0.920956
#
# [4]	eval-rmse:0.945564	train-rmse:0.918577
#
# [5]	eval-rmse:0.942976	train-rmse:0.915696
#
# [6]	eval-rmse:0.940654	train-rmse:0.913322
#
# [7]	eval-rmse:0.93835	train-rmse:0.910935
#
# [8]	eval-rmse:0.936093	train-rmse:0.90845
#
# [9]	eval-rmse:0.93394	train-rmse:0.906066
#
# [10]	eval-rmse:0.931823	train-rmse:0.903624
#
# [11]	eval-rmse:0.929797	train-rmse:0.901214
#
# [12]	eval-rmse:0.927691	train-rmse:0.898786
#
# [0]	eval-rmse:0.955454	train-rmse:0.929435
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.953011	train-rmse:0.926097
#
# [2]	eval-rmse:0.950519	train-rmse:0.923127
#
# [3]	eval-rmse:0.948152	train-rmse:0.920207
#
# [4]	eval-rmse:0.945919	train-rmse:0.917328
#
# [5]	eval-rmse:0.94366	train-rmse:0.914504
#
# [6]	eval-rmse:0.941418	train-rmse:0.911863
#
# [7]	eval-rmse:0.939251	train-rmse:0.90925
#
# [8]	eval-rmse:0.937171	train-rmse:0.906544
#
# [9]	eval-rmse:0.93515	train-rmse:0.903837
#
# [10]	eval-rmse:0.933219	train-rmse:0.901174
#
# [11]	eval-rmse:0.931238	train-rmse:0.898476
#
# [12]	eval-rmse:0.929256	train-rmse:0.895883
#
# [0]	eval-rmse:0.955261	train-rmse:0.929863
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.953053	train-rmse:0.926852
#
# [2]	eval-rmse:0.950631	train-rmse:0.924557
#
# [3]	eval-rmse:0.948495	train-rmse:0.921883
#
# [4]	eval-rmse:0.946334	train-rmse:0.919517
#
# [5]	eval-rmse:0.944043	train-rmse:0.917044
#
# [6]	eval-rmse:0.941941	train-rmse:0.914708
#
# [7]	eval-rmse:0.939842	train-rmse:0.912552
#
# [8]	eval-rmse:0.937783	train-rmse:0.910293
#
# [9]	eval-rmse:0.93567	train-rmse:0.907961
#
# [10]	eval-rmse:0.933752	train-rmse:0.9058
#
# [11]	eval-rmse:0.931746	train-rmse:0.903444
#
# [12]	eval-rmse:0.929869	train-rmse:0.901261
#
# [13]	eval-rmse:0.928037	train-rmse:0.89914
#
# [14]	eval-rmse:0.926143	train-rmse:0.897032
#
# [15]	eval-rmse:0.924308	train-rmse:0.895101
#
# [16]	eval-rmse:0.922577	train-rmse:0.893113
#
# [0]	eval-rmse:0.955468	train-rmse:0.930133
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.953636	train-rmse:0.927481
#
# [2]	eval-rmse:0.951692	train-rmse:0.925614
#
# [3]	eval-rmse:0.949729	train-rmse:0.923332
#
# [4]	eval-rmse:0.947826	train-rmse:0.920962
#
# [5]	eval-rmse:0.945924	train-rmse:0.919055
#
# [6]	eval-rmse:0.943876	train-rmse:0.916859
#
# [7]	eval-rmse:0.942082	train-rmse:0.914849
#
# [8]	eval-rmse:0.940398	train-rmse:0.912921
#
# [9]	eval-rmse:0.938456	train-rmse:0.910966
#
# [10]	eval-rmse:0.936708	train-rmse:0.909018
#
# [11]	eval-rmse:0.935017	train-rmse:0.906947
#
# [12]	eval-rmse:0.933332	train-rmse:0.905125
#
# [0]	eval-rmse:0.955945	train-rmse:0.93029
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.954567	train-rmse:0.927995
#
# [2]	eval-rmse:0.952962	train-rmse:0.92603
#
# [3]	eval-rmse:0.951376	train-rmse:0.924033
#
# [4]	eval-rmse:0.949851	train-rmse:0.921886
#
# [5]	eval-rmse:0.948318	train-rmse:0.919958
#
# [6]	eval-rmse:0.946777	train-rmse:0.918045
#
# [7]	eval-rmse:0.945285	train-rmse:0.916158
#
# [8]	eval-rmse:0.943837	train-rmse:0.914253
#
# [9]	eval-rmse:0.942383	train-rmse:0.912419
#
# [10]	eval-rmse:0.940964	train-rmse:0.910563
#
# [11]	eval-rmse:0.939585	train-rmse:0.908626
#
# [12]	eval-rmse:0.938172	train-rmse:0.906787
#
# [13]	eval-rmse:0.936824	train-rmse:0.90496
#
# [14]	eval-rmse:0.935494	train-rmse:0.903121
#
# [15]	eval-rmse:0.934077	train-rmse:0.901268
# [16]	eval-rmse:0.932749	train-rmse:0.899434
#
# [17]	eval-rmse:0.93146	train-rmse:0.897635
#
# [0]	eval-rmse:0.955211	train-rmse:0.929548
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.952695	train-rmse:0.926349
#
# [2]	eval-rmse:0.950164	train-rmse:0.923641
#
# [3]	eval-rmse:0.947767	train-rmse:0.920658
#
# [4]	eval-rmse:0.945418	train-rmse:0.917964
#
# [5]	eval-rmse:0.943061	train-rmse:0.915242
#
# [6]	eval-rmse:0.940778	train-rmse:0.91274
#
# [7]	eval-rmse:0.938502	train-rmse:0.910275
#
# [8]	eval-rmse:0.936249	train-rmse:0.907656
#
# [9]	eval-rmse:0.934138	train-rmse:0.905133
#
# [10]	eval-rmse:0.932099	train-rmse:0.902552
#
# [11]	eval-rmse:0.930048	train-rmse:0.900027
#
# [12]	eval-rmse:0.928024	train-rmse:0.897576
#
# [13]	eval-rmse:0.926088	train-rmse:0.895238
#
# [14]	eval-rmse:0.924153	train-rmse:0.892949
#
# [15]	eval-rmse:0.92223	train-rmse:0.890737
#
# [16]	eval-rmse:0.920295	train-rmse:0.888435
#
# [17]	eval-rmse:0.918435	train-rmse:0.886156
#
# [18]	eval-rmse:0.916604	train-rmse:0.883993
#
# [19]	eval-rmse:0.914816	train-rmse:0.881863
#
# [20]	eval-rmse:0.913098	train-rmse:0.879744
#
# [21]	eval-rmse:0.911501	train-rmse:0.877622
#
# [22]	eval-rmse:0.909844	train-rmse:0.875598
#
# [23]	eval-rmse:0.908118	train-rmse:0.873611
#
# [24]	eval-rmse:0.906564	train-rmse:0.871659
#
# [25]	eval-rmse:0.905041	train-rmse:0.869745
#
# [26]	eval-rmse:0.903455	train-rmse:0.867832
#
# [27]	eval-rmse:0.901973	train-rmse:0.865939
#
# [28]	eval-rmse:0.900562	train-rmse:0.864097
#
# [0]	eval-rmse:0.955683	train-rmse:0.930232
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.953936	train-rmse:0.927709
#
# [2]	eval-rmse:0.952112	train-rmse:0.925728
#
# [3]	eval-rmse:0.950181	train-rmse:0.923529
#
# [4]	eval-rmse:0.948424	train-rmse:0.92126
#
# [5]	eval-rmse:0.946577	train-rmse:0.919292
#
# [6]	eval-rmse:0.944721	train-rmse:0.91722
#
# [7]	eval-rmse:0.942907	train-rmse:0.915234
#
# [8]	eval-rmse:0.941198	train-rmse:0.913284
#
# [9]	eval-rmse:0.939526	train-rmse:0.911357
#
# [10]	eval-rmse:0.937867	train-rmse:0.909396
#
# [11]	eval-rmse:0.936198	train-rmse:0.907398
#
# [12]	eval-rmse:0.934574	train-rmse:0.905499
#
# [13]	eval-rmse:0.933035	train-rmse:0.90363
#
# [14]	eval-rmse:0.931455	train-rmse:0.901707
#
# [15]	eval-rmse:0.929904	train-rmse:0.899846
#
# [16]	eval-rmse:0.92831	train-rmse:0.89797
#
# [17]	eval-rmse:0.926824	train-rmse:0.896168
#
# [18]	eval-rmse:0.925366	train-rmse:0.894433
#
# [19]	eval-rmse:0.923862	train-rmse:0.892756
#
# [20]	eval-rmse:0.922464	train-rmse:0.891095
#
# [21]	eval-rmse:0.921008	train-rmse:0.889402
#
# [22]	eval-rmse:0.919575	train-rmse:0.887652
#
# [23]	eval-rmse:0.918141	train-rmse:0.886007
#
# [0]	eval-rmse:0.955356	train-rmse:0.929625
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.953145	train-rmse:0.926564
#
# [2]	eval-rmse:0.950854	train-rmse:0.923975
#
# [3]	eval-rmse:0.948733	train-rmse:0.921202
#
# [4]	eval-rmse:0.946642	train-rmse:0.918628
#
# [5]	eval-rmse:0.944396	train-rmse:0.915955
#
# [6]	eval-rmse:0.942285	train-rmse:0.913519
#
# [7]	eval-rmse:0.940163	train-rmse:0.911158
#
# [8]	eval-rmse:0.938242	train-rmse:0.908664
#
# [9]	eval-rmse:0.936205	train-rmse:0.906179
#
# [10]	eval-rmse:0.934259	train-rmse:0.903755
#
# [11]	eval-rmse:0.93238	train-rmse:0.901231
#
# [12]	eval-rmse:0.930453	train-rmse:0.898793
#
# [13]	eval-rmse:0.92866	train-rmse:0.89649
#
# [14]	eval-rmse:0.926837	train-rmse:0.894224
#
# [15]	eval-rmse:0.925004	train-rmse:0.892003
#
# [16]	eval-rmse:0.923221	train-rmse:0.889759
#
# [17]	eval-rmse:0.921477	train-rmse:0.887516
#
# [18]	eval-rmse:0.919756	train-rmse:0.885379
#
# [19]	eval-rmse:0.918064	train-rmse:0.883269
#
# [20]	eval-rmse:0.916433	train-rmse:0.881126
#
# ...
#
# [9]	eval-rmse:0.942259	train-rmse:0.91357
#
# [10]	eval-rmse:0.940801	train-rmse:0.911849
#
# [11]	eval-rmse:0.939437	train-rmse:0.91011
#
# [12]	eval-rmse:0.938035	train-rmse:0.908287
#
# [13]	eval-rmse:0.936715	train-rmse:0.90657
#
# [14]	eval-rmse:0.93539	train-rmse:0.9049
#
# [0]	eval-rmse:0.955483	train-rmse:0.929689
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.953273	train-rmse:0.926669
#
# [2]	eval-rmse:0.951016	train-rmse:0.924084
#
# [3]	eval-rmse:0.948875	train-rmse:0.92128
#
# [4]	eval-rmse:0.946724	train-rmse:0.918778
#
# [5]	eval-rmse:0.944412	train-rmse:0.916161
#
# [6]	eval-rmse:0.942281	train-rmse:0.913724
#
# [7]	eval-rmse:0.940226	train-rmse:0.911376
#
# [8]	eval-rmse:0.938199	train-rmse:0.908923
#
# [9]	eval-rmse:0.936183	train-rmse:0.906492
#
# [10]	eval-rmse:0.93416	train-rmse:0.904095
#
# [11]	eval-rmse:0.932323	train-rmse:0.901674
#
# [12]	eval-rmse:0.930362	train-rmse:0.899287
#
# [13]	eval-rmse:0.928583	train-rmse:0.89701
#
# [14]	eval-rmse:0.926714	train-rmse:0.894764
#
# [0]	eval-rmse:0.955518	train-rmse:0.929974
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.953459	train-rmse:0.927098
#
# [2]	eval-rmse:0.951428	train-rmse:0.924931
#
# [3]	eval-rmse:0.949355	train-rmse:0.922336
#
# [4]	eval-rmse:0.947421	train-rmse:0.920049
#
# [5]	eval-rmse:0.945345	train-rmse:0.917752
#
# [6]	eval-rmse:0.943327	train-rmse:0.915474
#
# [7]	eval-rmse:0.941421	train-rmse:0.913384
#
# [8]	eval-rmse:0.939536	train-rmse:0.911176
#
# [9]	eval-rmse:0.937734	train-rmse:0.909004
#
# [10]	eval-rmse:0.935951	train-rmse:0.90681
#
# [11]	eval-rmse:0.934211	train-rmse:0.904589
#
# [12]	eval-rmse:0.932504	train-rmse:0.902402
#
# [13]	eval-rmse:0.930831	train-rmse:0.900326
#
# [14]	eval-rmse:0.929129	train-rmse:0.898267
#
# [0]	eval-rmse:0.955225	train-rmse:0.929646
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.952822	train-rmse:0.926505
#
# [2]	eval-rmse:0.950313	train-rmse:0.924031
#
# [3]	eval-rmse:0.947956	train-rmse:0.921077
#
# [4]	eval-rmse:0.945654	train-rmse:0.918549
#
# [5]	eval-rmse:0.943257	train-rmse:0.915875
#
# [6]	eval-rmse:0.94104	train-rmse:0.913489
#
# [7]	eval-rmse:0.938752	train-rmse:0.91111
#
# [8]	eval-rmse:0.936559	train-rmse:0.90858
#
# [9]	eval-rmse:0.934433	train-rmse:0.906169
#
# [10]	eval-rmse:0.93232	train-rmse:0.903714
#
# [11]	eval-rmse:0.930344	train-rmse:0.901285
#
# [12]	eval-rmse:0.92828	train-rmse:0.898954
#
# [13]	eval-rmse:0.92634	train-rmse:0.896691
#
# [14]	eval-rmse:0.924391	train-rmse:0.894485
#
# [15]	eval-rmse:0.922543	train-rmse:0.892396
#
# [16]	eval-rmse:0.920662	train-rmse:0.890303
#
# [17]	eval-rmse:0.918767	train-rmse:0.888112
#
# [18]	eval-rmse:0.917014	train-rmse:0.886008
#
# [19]	eval-rmse:0.91526	train-rmse:0.884024
#
# [20]	eval-rmse:0.913537	train-rmse:0.882031
#
# [21]	eval-rmse:0.911878	train-rmse:0.880033
#
# [22]	eval-rmse:0.910183	train-rmse:0.87805
#
# [23]	eval-rmse:0.908467	train-rmse:0.876216
#
# [24]	eval-rmse:0.906899	train-rmse:0.874372
#
# [25]	eval-rmse:0.905451	train-rmse:0.872599
#
# [26]	eval-rmse:0.903854	train-rmse:0.870809
#
# [27]	eval-rmse:0.902282	train-rmse:0.869011
#
# [28]	eval-rmse:0.900866	train-rmse:0.867234
#
# [29]	eval-rmse:0.899407	train-rmse:0.865502
#
# [30]	eval-rmse:0.897966	train-rmse:0.863814
#
# [31]	eval-rmse:0.896584	train-rmse:0.86222
#
# [32]	eval-rmse:0.895246	train-rmse:0.860625
#
# [33]	eval-rmse:0.893858	train-rmse:0.858992
#
# [0]	eval-rmse:0.955552	train-rmse:0.929833
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.953625	train-rmse:0.926908
#
# [2]	eval-rmse:0.951533	train-rmse:0.924476
#
# [3]	eval-rmse:0.949457	train-rmse:0.921742
#
# [4]	eval-rmse:0.94748	train-rmse:0.919346
#
# [5]	eval-rmse:0.945421	train-rmse:0.916914
#
# [6]	eval-rmse:0.943408	train-rmse:0.914465
#
# [7]	eval-rmse:0.941481	train-rmse:0.912208
#
# [8]	eval-rmse:0.939638	train-rmse:0.909868
#
# [9]	eval-rmse:0.937822	train-rmse:0.907442
#
# [10]	eval-rmse:0.93597	train-rmse:0.905132
#
# [11]	eval-rmse:0.934206	train-rmse:0.902812
#
# [12]	eval-rmse:0.93254	train-rmse:0.900435
#
# [13]	eval-rmse:0.930803	train-rmse:0.898204
#
# [14]	eval-rmse:0.929151	train-rmse:0.895987
#
# [15]	eval-rmse:0.92753	train-rmse:0.893746
#
# [16]	eval-rmse:0.92587	train-rmse:0.891592
#
# [17]	eval-rmse:0.924241	train-rmse:0.889486
#
# [18]	eval-rmse:0.922603	train-rmse:0.887386
#
# [19]	eval-rmse:0.921022	train-rmse:0.885311
#
# [0]	eval-rmse:0.956311	train-rmse:0.93093
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.955172	train-rmse:0.929211
#
# [2]	eval-rmse:0.953697	train-rmse:0.92735
#
# [3]	eval-rmse:0.952523	train-rmse:0.926078
#
# [4]	eval-rmse:0.951244	train-rmse:0.924599
#
# [5]	eval-rmse:0.94993	train-rmse:0.922932
#
# [6]	eval-rmse:0.948704	train-rmse:0.92147
#
# [7]	eval-rmse:0.94741	train-rmse:0.920074
#
# [8]	eval-rmse:0.946189	train-rmse:0.918624
#
# [9]	eval-rmse:0.944976	train-rmse:0.917118
#
# [10]	eval-rmse:0.943796	train-rmse:0.915652
#
# [11]	eval-rmse:0.942628	train-rmse:0.914254
#
# [12]	eval-rmse:0.941469	train-rmse:0.912885
#
# [13]	eval-rmse:0.940335	train-rmse:0.911524
#
# [14]	eval-rmse:0.939223	train-rmse:0.910173
#
# [15]	eval-rmse:0.937992	train-rmse:0.908776
#
# [16]	eval-rmse:0.936889	train-rmse:0.907391
#
# [17]	eval-rmse:0.935754	train-rmse:0.906045
#
# [18]	eval-rmse:0.934665	train-rmse:0.904683
#
# [19]	eval-rmse:0.933559	train-rmse:0.903337
#
# [20]	eval-rmse:0.932536	train-rmse:0.902015
#
# [21]	eval-rmse:0.931455	train-rmse:0.900676
#
# [22]	eval-rmse:0.930417	train-rmse:0.89935
#
# [23]	eval-rmse:0.929333	train-rmse:0.898062
#
# [24]	eval-rmse:0.928248	train-rmse:0.896792
#
# [25]	eval-rmse:0.927255	train-rmse:0.895533
#
# [26]	eval-rmse:0.926199	train-rmse:0.8943
#
# [27]	eval-rmse:0.92525	train-rmse:0.893108
#
# [0]	eval-rmse:0.955647	train-rmse:0.930364
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.954147	train-rmse:0.928136
#
# [2]	eval-rmse:0.952343	train-rmse:0.926355
#
# [3]	eval-rmse:0.950518	train-rmse:0.924525
#
# [4]	eval-rmse:0.948831	train-rmse:0.922339
#
# [5]	eval-rmse:0.947011	train-rmse:0.920601
#
# [6]	eval-rmse:0.945529	train-rmse:0.919053
#
# [7]	eval-rmse:0.943662	train-rmse:0.917045
#
# [8]	eval-rmse:0.942094	train-rmse:0.915181
#
# [9]	eval-rmse:0.940539	train-rmse:0.913584
#
# [10]	eval-rmse:0.938881	train-rmse:0.911881
#
# [11]	eval-rmse:0.937432	train-rmse:0.91028
#
# [12]	eval-rmse:0.935691	train-rmse:0.908381
#
# [13]	eval-rmse:0.934255	train-rmse:0.90679
#
# [14]	eval-rmse:0.932861	train-rmse:0.905205
#
# [15]	eval-rmse:0.931198	train-rmse:0.903383
#
# [16]	eval-rmse:0.929846	train-rmse:0.901778
#
# [17]	eval-rmse:0.928345	train-rmse:0.900107
#
# [18]	eval-rmse:0.927021	train-rmse:0.898495
#
# [19]	eval-rmse:0.925576	train-rmse:0.897054
#
# [20]	eval-rmse:0.924294	train-rmse:0.895709
#
# [21]	eval-rmse:0.922877	train-rmse:0.894196
#
# [22]	eval-rmse:0.921479	train-rmse:0.892734
#
# [23]	eval-rmse:0.920176	train-rmse:0.891342
#
# [24]	eval-rmse:0.918833	train-rmse:0.889745
#
# [25]	eval-rmse:0.917665	train-rmse:0.888282
#
# [26]	eval-rmse:0.916327	train-rmse:0.886832
#
# [27]	eval-rmse:0.91506	train-rmse:0.885405
#
# [28]	eval-rmse:0.913753	train-rmse:0.884041
#
# [0]	eval-rmse:0.955415	train-rmse:0.929939
#
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
#
# Will train until train-rmse hasn't improved in 100 rounds.
#
# [1]	eval-rmse:0.953261	train-rmse:0.926967
#
# [2]	eval-rmse:0.951105	train-rmse:0.92479
#
# [3]	eval-rmse:0.948975	train-rmse:0.922128
#
# [4]	eval-rmse:0.946934	train-rmse:0.919847
#
# [5]	eval-rmse:0.94466	train-rmse:0.917422
#
# [6]	eval-rmse:0.942586	train-rmse:0.915131
#
# [7]	eval-rmse:0.940529	train-rmse:0.913034
#
# [8]	eval-rmse:0.938507	train-rmse:0.910833
#
# [9]	eval-rmse:0.936461	train-rmse:0.908581
#
# [10]	eval-rmse:0.934624	train-rmse:0.906374
#
# [11]	eval-rmse:0.932732	train-rmse:0.90418
#
# [12]	eval-rmse:0.930854	train-rmse:0.90202
#
# [13]	eval-rmse:0.929117	train-rmse:0.899946
#
# [14]	eval-rmse:0.927285	train-rmse:0.897868
#
# [15]	eval-rmse:0.925516	train-rmse:0.89586
#
# [16]	eval-rmse:0.923819	train-rmse:0.893874
#
# [17]	eval-rmse:0.92217	train-rmse:0.891978
#
# 100%|██████████| 100/100 [6:34:25<00:00, 199.88s/it, best loss: -0.07778958839647176]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-0c2c656d9fd7> in <module>()
#       3 best = fmin(xgboost_factory, space, algo=algo, max_evals=100, pass_expr_memo_ctrl=None)
#       4 store = best
# ----> 5 print("the best parameter before transformation is:" + best)
#       6 print("the best parameter after transformation is:" + argsDict_tranform(best))
#
# TypeError: must be str, not dict

# %%
best
# Out:
# {'alpha': 0.6145289893746854,
#  'lambda': 0.848151241595682,
#  'learning_rate': 0.48805216458277617,
#  'max_depth': 0,
#  'min_child_weight': 5,
#  'n_estimators': 3,
#  'subsample': 2}

# %%
argsDict_tranform(best)
# Out:
# {'alpha': 12.290579787493707,
#  'lambda': 42.4075620797841,
#  'learning_rate': 0.010761043291655524,
#  'max_depth': 5,
#  'min_child_weight': 6,
#  'n_estimators': 13,
#  'subsample': 0.7}

# %%
best
# Out:
# {'alpha': 182.91075892028954,
#  'lambda': 305.363687026092,
#  'learning_rate': 0.0011815142243762745,
#  'max_depth': 17,
#  'min_child_weight': 4,
#  'n_estimators': 30,
#  'subsample': 0.56}

# %%
 xgboost_factory(argsDict_tranform(best))
# Out:
# [0]	eval-rmse:0.887142	train-rmse:0.91346
# Multiple eval metrics have been passed: 'train-rmse' will be used for early stopping.
#
# Will train until train-rmse hasn't improved in 100 rounds.
# [1]	eval-rmse:0.876897	train-rmse:0.894919
# [2]	eval-rmse:0.868053	train-rmse:0.878668
# [3]	eval-rmse:0.859192	train-rmse:0.86251
# [4]	eval-rmse:0.851483	train-rmse:0.848265
# [5]	eval-rmse:0.844992	train-rmse:0.833192
# [6]	eval-rmse:0.838924	train-rmse:0.820392
# [7]	eval-rmse:0.833219	train-rmse:0.807377
# [8]	eval-rmse:0.828818	train-rmse:0.794724
# [9]	eval-rmse:0.824214	train-rmse:0.783454
# [10]	eval-rmse:0.820525	train-rmse:0.772966
# [11]	eval-rmse:0.817106	train-rmse:0.762479
# [12]	eval-rmse:0.814711	train-rmse:0.752645
# [13]	eval-rmse:0.812286	train-rmse:0.743479
# [14]	eval-rmse:0.810634	train-rmse:0.734102
# [15]	eval-rmse:0.808537	train-rmse:0.72533
# [16]	eval-rmse:0.807054	train-rmse:0.716354
# [17]	eval-rmse:0.805628	train-rmse:0.707871
# [18]	eval-rmse:0.804132	train-rmse:0.699963
# [19]	eval-rmse:0.803122	train-rmse:0.692472
# [20]	eval-rmse:0.802222	train-rmse:0.686265
# [21]	eval-rmse:0.801558	train-rmse:0.678802
# [22]	eval-rmse:0.800949	train-rmse:0.672142
# [23]	eval-rmse:0.800676	train-rmse:0.665405
# [24]	eval-rmse:0.800251	train-rmse:0.659376
# [25]	eval-rmse:0.799761	train-rmse:0.653864
# [26]	eval-rmse:0.799646	train-rmse:0.647186
# [27]	eval-rmse:0.799241	train-rmse:0.640191
# [28]	eval-rmse:0.799364	train-rmse:0.635241
# -0.06243747878596423

# %%
bst=xgb.train(params,dtrain=dtrain,num_boost_round=1,early_stopping_rounds=None,evals=[(dtrain,'train'),(ddev,'test')],verbose_eval=3)
# Out:
# [0]	train-rmse:0.926187	test-rmse:0.896756

# %%
xrf = xgb.train(params, dtrain,num_boost_round=1,early_stopping_rounds=None)

# %%
# first time training

bst=xgb.train(params=xgb_param,dtrain=dtrain,num_boost_round=1,early_stopping_rounds=None,evals=[(dtrain,'train'),(ddev,'test')],verbose_eval=3)
pred = bst.predict(dtest)
predtrain = bst.predict(dtrain)
print(pearsonr(np.array(yp_train), predtrain))
print(pearsonr(np.array(yp_test), pred))


# first time training - continued
for kk in range(29):
    bst=xgb.train(params=xgb_param,dtrain=dtrain,num_boost_round=1,early_stopping_rounds=None,evals=[(dtrain,'train'),(ddev,'test')],verbose_eval=3, xgb_model = bst)
    pred = bst.predict(dtest)
    predtrain = bst.predict(dtrain)
print(pearsonr(np.array(yp_train), predtrain))
# print(pearsonr(np.array(y_train.T)[0], predtrain))
print(pearsonr(np.array(yp_test), pred))
# print(pearsonr(np.array(y_test.T)[0], pred))

# concatenate predictions

g =  train[["TradingDay", "SecuCode"]][time_ind[train_days]:time_ind[train_days+delta_days]]
g["NextCatPred"] = pred
k = g.pivot_table(columns='SecuCode', index='TradingDay', values='NextCatPred').reset_index().sort_values("TradingDay")

# %%
# second traininng and so on

# change dataset
drift = 1
while drift * delta_days + train_days + delta_days < len(time_ind):
    X_train = X[time_ind[drift * delta_days]:time_ind[train_days + drift * delta_days]]
    X_test = X[time_ind[train_days + drift * delta_days]:time_ind[train_days+delta_days + drift * delta_days]]
    y_train = y[time_ind[drift * delta_days]:time_ind[train_days + drift * delta_days]]
    y_test = y[time_ind[train_days + drift * delta_days]:time_ind[train_days+delta_days + drift * delta_days]]
    yp_train = yp[time_ind[drift * delta_days]:time_ind[train_days + drift * delta_days]]
    yp_test = yp[time_ind[train_days + drift * delta_days]:time_ind[train_days+delta_days + drift * delta_days]]
    dtrain = xgb.DMatrix(data=X_train, label=y_train)
    dtest = xgb.DMatrix(data=X_test)
    ddev = xgb.DMatrix(data=X_test, label=y_test)
    bst=xgb.train(params=xgb_param,dtrain=dtrain,num_boost_round=1,early_stopping_rounds=None,evals=[(dtrain,'train'),(ddev,'test')],verbose_eval=3)

    for kk in range(29):
        bst=xgb.train(params=xgb_param,dtrain=dtrain,num_boost_round=1,early_stopping_rounds=None,evals=[(dtrain,'train'),(ddev,'test')],verbose_eval=3, xgb_model = bst)
#         bst=xgb.train(params=xgb_param,dtrain=dtrain,num_boost_round=1,early_stopping_rounds=None,evals=[(dtrain,'train'),(ddev,'test')],verbose_eval=3)
        pred = bst.predict(dtest)
        predtrain = bst.predict(dtrain)
    print(pearsonr(np.array(yp_train), predtrain))
    # print(pearsonr(np.array(y_train.T)[0], predtrain))
    print(pearsonr(np.array(yp_test), pred))
    # print(pearsonr(np.array(y_test.T)[0], pred))
    gt =  train[["TradingDay", "SecuCode"]][time_ind[train_days + drift * delta_days]:time_ind[train_days+delta_days + drift * delta_days]]
    gt["NextCatPred"] = pred
    kt = gt.pivot_table(columns='SecuCode', index='TradingDay', values='NextCatPred').reset_index().sort_values("TradingDay")
    k = pd.concat([k, kt],ignore_index=True)
    drift += 1

# the last dataset
if drift * delta_days + train_days + delta_days > len(time_ind):
    X_train = X[time_ind[drift * delta_days]:time_ind[train_days + drift * delta_days]]
    X_test = X[time_ind[train_days + drift * delta_days]:]
    y_train = y[time_ind[drift * delta_days]:time_ind[train_days + drift * delta_days]]
    y_test = y[time_ind[train_days + drift * delta_days]:]
    yp_train = yp[time_ind[drift * delta_days]:time_ind[train_days + drift * delta_days]]
    yp_test = yp[time_ind[train_days + drift * delta_days]:]
    dtrain = xgb.DMatrix(data=X_train, label=y_train)
    dtest = xgb.DMatrix(data=X_test)
    ddev = xgb.DMatrix(data=X_test, label=y_test)
    bst=xgb.train(params=xgb_param,dtrain=dtrain,num_boost_round=1,early_stopping_rounds=None,evals=[(dtrain,'train'),(ddev,'test')],verbose_eval=3)

    for kk in range(29):
        bst=xgb.train(params=xgb_param,dtrain=dtrain,num_boost_round=1,early_stopping_rounds=None,evals=[(dtrain,'train'),(ddev,'test')],verbose_eval=3, xgb_model = bst)
        pred = bst.predict(dtest)
        predtrain = bst.predict(dtrain)
    print(pearsonr(np.array(yp_train), predtrain))
    # print(pearsonr(np.array(y_train.T)[0], predtrain))
    print(pearsonr(np.array(yp_test), pred))
    # print(pearsonr(np.array(y_test.T)[0], pred))
    gt =  train[["TradingDay", "SecuCode"]][time_ind[train_days + drift * delta_days]:]
    gt["NextCatPred"] = pred
    kt = gt.pivot_table(columns='SecuCode', index='TradingDay', values='NextCatPred').reset_index().sort_values("TradingDay")
    k = pd.concat([k, kt],ignore_index=True)

k.set_index("TradingDay").to_csv("0805back_input_30_30.csv")
