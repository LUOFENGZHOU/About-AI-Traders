# %%
# -*- coding=utf-8 -*-
import pymysql
import sys
pymysql.install_as_MySQLdb()
import MySQLdb as mdb
import numpy as np
import pandas as pd
from sqlalchemy import create_engine
from itertools import chain
import warnings
import os

warnings.filterwarnings('ignore')

default_config_115 = {
    'host': '175.25.50.115',
    'port': 3306,
    'user': 'xtech',
    'passwd': 'x-tech-123',
    'db': 'jydb',
    'charset': 'gbk'
}

xtech_config = {
    'host': '175.25.50.115',
    'port': 3306,
    'user': 'xtech',
    'passwd': 'x-tech-123',
    'db': 'xtech',
    'charset': 'gbk',
}


class FetchData(object):
    def __init__(self, config):
        self.config = config
        # self.conn = mdb.connect(**config)
        # self.conn.autocommit(1)
        self.conn = None

    def __del__(self):
        if self.conn is not None:
            self.conn.close()

    def _exec(self, query, describe=False):
        if self.conn is None:
            self.conn = mdb.connect(**self.config)
            self.conn.autocommit(1)
        try:
            cursor = self.conn.cursor()
            cursor.execute(query)
            cursor.scroll(0, mode='absolute')
            results = cursor.fetchall()
            description = cursor.description
        except:
            # print(query, ' error')
            # import traceback
            # traceback.print_exc()
            self.conn.rollback()
            cursor.close()
            return None, None
        cursor.close()
        if not describe:
            return results
        else:
            columns = []
            for x in description:
                columns.append(x[0])
            return columns, results

    def fetch_tables(self, verbose=False):
        tables = []
        query = 'SHOW TABLES'
        results = self._exec(query)

        for x in results:
            tables.append(x[0])
        if verbose is True:
            print(results)
        return tables

    def fetch_columns(self, table_name, verbose=False):
        columns = []
        query = 'SHOW COLUMNS FROM %s' % table_name
        results = self._exec(query)
        for x in results:
            columns.append(x[0])
        if verbose is True:
            print(results)
        return columns

    def _fetch_index(self, table_name, verbose=False):
        ids = []
        query = 'SHOW INDEX FROM %s' % table_name
        results = self._exec(query)
        for x in results:
            ids.append(x[0])
        if verbose is True:
            print(results)
        return ids

    def ping(self, table_name, verbose=False):
        query = 'SELECT * FROM %s LIMIT %s' % (table_name, 1)
        columns, result = self._exec(query)
        if verbose is True:
            print(result[0])
        if result is None:
            print('Query failed!')
        else:
            print('Query success!')
        return result

    def head(self, table_name, limit=5):
        query = 'SELECT * FROM %s  ORDER BY id ASC LIMIT %s' % (table_name, limit)
        columns, results = self._exec(query, True)
        # columns = self.fetch_columns(table_name)
        df_head = pd.DataFrame(np.array(results), columns=columns)
        print(df_head)
        return df_head

    def tail(self, table_name, limit=5):
        query = 'SELECT * FROM %s ORDER BY id DESC LIMIT %s' % (table_name, limit)
        columns, results = self._exec(query, True)
        # columns = self.fetch_columns(table_name)
        df_tail = pd.DataFrame(np.array(results), columns=columns)
        # print (df_tail)
        return df_tail

    def getdata(self, table_name, columns=None, date_name=None, start_date=None, end_date=None):
        if isinstance(columns, list):
            columns = ",".join(columns)
        else:
            columns = '*'

        if date_name is None:
            query = 'SELECT %s FROM %s' % (columns, table_name)
        else:
            start_date = '"' + start_date + '"'
            end_date = '"' + end_date + '"'
            query = 'SELECT %s FROM %s  where %s >= %s and %s <= %s order by %s asc;' % (
            columns, table_name, date_name, start_date, date_name, end_date, date_name)

        columns, results = self._exec(query)
        # print(results)
        if results is None:
            print('Query Failed!')
            df = None
        else:
            df = pd.DataFrame(np.array(results), columns=columns)
        return df

    def get_minmax(self, table_name, columns):
        code = self.getdata(table_name, columns)
        print(code.min(), code.max())
        return (code.min(), code.max())

    def get_data(self, table_name):
        query = 'SELECT * FROM {}'.format(table_name)
        columns, results = self._exec(query, True)
        if results is None:
            # print("Query Failed!")
            df = None
        else:
            df = pd.DataFrame(np.array(results), columns=columns)
            df.index = np.arange(df.shape[0])
        return df

    def get_day_data(self, table_name, date_name, date):
        query = 'SELECT * FROM {} where {} = "{}" '.format(table_name, date_name, date)
        columns, results = self._exec(query, True)
        if results is None:
            print('Query Failed!')
            df = None
        else:
            # df_col = self.fetch_columns(table_name)
            df = pd.DataFrame(np.array(results), columns=columns)
            df.index = np.arange(df.shape[0])
        return df

    def get_quarter_data(self, table_name, date_name, quarter_time, limit):
        query = 'SELECT * FROM %s where %s <= "%s" ORDER BY %s DESC limit %s' % (
        table_name, date_name, quarter_time, date_name, limit)
        columns, results = self._exec(query, True)
        if results is None:
            print('Query Failed!')
            df = None
        else:
            # df_col = self.fetch_columns(table_name)
            df = pd.DataFrame(np.array(results), columns=columns)
            df.index = np.arange(df.shape[0])
        return df

    def exec_sql(self, query):
        columns, results = self._exec(query, True)
        if results is None:
            return None
        else:
            df = pd.DataFrame(np.array(results), columns=columns)
            return df

    def exec_file(self, filename):
        with open(filename, 'r') as f:
            query = f.read()
            columns, results = self._exec(query, True)
            df = pd.DataFrame(np.array(results), columns=columns)
        return df


class Wapper_FetchData(FetchData):
    def __init__(self, config, SecuCategory=1):
        super(Wapper_FetchData, self).__init__(config=config)
        self.SecuCategory = SecuCategory

    def set_SecuCategory(self, SecuCategory):
        self.SecuCategory = SecuCategory
        print("Now SecuCategory:", self.SecuCategory)

    def decorator(func):
        def wrapper(self, *args, **kw):
            describe = True
            if not describe:
                return func(*args, **kw)
            else:
                columns, results = func(self, *args, **kw)
                if results is None:
                    return columns, results
                elif ("SecuCode" in columns):
                    return columns, results
                elif ("InnerCode" in columns):
                    query = 'SELECT InnerCode,SecuCode FROM SecuMain where SecuCategory = %s and (SecuMarket = 83 or SecuMarket = 90);' % (
                        self.SecuCategory)
                    df_main = self.exec_sql(query)
                    df_main = df_main[['InnerCode', 'SecuCode']]
                    df_main['InnerCode'] = df_main['InnerCode'].astype(np.int64)
                    df = pd.DataFrame(np.array(results), columns=columns)
                    df['InnerCode'] = df['InnerCode'].astype(np.int64)
                    out_df = pd.merge(df_main, df, on="InnerCode")
                    return out_df.columns, out_df.values
                elif ("CompanyCode" in columns):
                    query = 'SELECT CompanyCode,SecuCode FROM SecuMain where SecuCategory = %s and (SecuMarket = 83 or SecuMarket = 90);' % (
                        self.SecuCategory)
                    df_main = self.exec_sql(query)
                    df_main = df_main[['CompanyCode', 'SecuCode']]
                    df_main['CompanyCode'] = df_main['CompanyCode'].astype(np.int64)
                    df = pd.DataFrame(np.array(results), columns=columns)
                    df['CompanyCode'] = df['CompanyCode'].astype(np.int64)
                    out_df = pd.merge(df_main, df, on="CompanyCode")
                    columns = out_df.columns
                    results = out_df.values
                    return out_df.columns, out_df.values
                else:
                    return columns, results

        return wrapper

    @decorator
    def _exec(self, query, describe=True):
        if self.conn is None:
            self.conn = mdb.connect(**self.config)
            self.conn.autocommit(1)

        try:
            cursor = self.conn.cursor()
            cursor.execute(query)
            cursor.scroll(0, mode='absolute')
            results = cursor.fetchall()
            description = cursor.description
        except:
            # print(query, ' error')
            # import traceback
            # traceback.print_exc()
            self.conn.rollback()
            results = None
            description = None
            return None, None
        cursor.close()
        if not describe:
            return results
        else:
            columns = []
            for x in description:
                columns.append(x[0])
            return columns, results

    def get_IndexComponent(self, SecuCode, Date):
        '''
            SecuCode type:str  exmple: '000300' (hs300)
            Date: type:str. exmple '2017-04-10'
        '''
        query = 'SELECT InnerCode, SecuCode FROM SecuMain where SecuCode = {} and SecuCategory = 4 and (SecuMarket = 83 or SecuMarket = 90);'.format(
            SecuCode)
        df_main = self.exec_sql(query)
        # print(df_main)
        assert len(df_main) == 1
        IndexCode = int(df_main['InnerCode'].values)
        Date = pd.to_datetime(Date)
        query2 = 'select InnerCode from SA_TradableShare where IndexCode = {} and EndDate = "{}" '.format(IndexCode,
                                                                                                          Date)
        df = self.exec_sql(query2)
        result = pd.DataFrame(df['SecuCode'].unique(), columns=[SecuCode])
        return result

    def get_IndexComponent2(self, SecuCode, Date=None):
        '''
            SecuCode type:str  exmple: '000300' (hs300)
            Date: type:str. exmple '2017-04-10'
        '''
        query = 'SELECT InnerCode, SecuCode FROM SecuMain where SecuCode = {} and SecuCategory = 4 and (SecuMarket = 83 or SecuMarket = 90);'.format(
            SecuCode)
        df_main = self.exec_sql(query)
        # print(df_main)
        assert len(df_main) == 1
        IndexCode = int(df_main['InnerCode'].values)
        Date = pd.to_datetime(Date)
        query2 = 'select SecuInnerCode as InnerCode from LC_IndexComponent where IndexInnerCode = {} and OutDate is Null'.format(
            IndexCode)
        df = self.exec_sql(query2)
        result = pd.DataFrame(df['SecuCode'].unique(), columns=[SecuCode])
        return result


class XTechData(FetchData):
    def __init__(self, config):
        super(XTechData, self).__init__(config=config)
        DB_URI = 'mysql+mysqldb://{}:{}@{}:{}/{}?charset=utf8'.format(config['user'],
                                                                      config['passwd'],
                                                                      config['host'],
                                                                      config['port'],
                                                                      config['db'])
        self.engine = create_engine(DB_URI, encoding='utf-8')

    def insert(self, df, date, mode='append'):
        with self.engine.connect() as conn:
            df.to_sql(date, conn, if_exists=mode)

# %%
import baostock as bs
def find_index(date):
    lg = bs.login()
    rs = bs.query_zz500_stocks(date)
    _stocks = []
    while (rs.error_code == '0') & rs.next():
        # 获取一条记录，将记录合并在一起
        _stocks.append(rs.get_row_data())
    a = list(pd.DataFrame(_stocks)[1])
    symbol_list =  [ _[3:] for _ in a]
    bs.logout()
    return symbol_list

# %%
def get_all_data():
    jydb_loader = FetchData(config=default_config_115)
    secu_loader = Wapper_FetchData(config=default_config_115)
    xtech_db = XTechData(config=xtech_config)
    all_date = xtech_db.fetch_tables()
    all_date = [i for i in all_date if i[:4]=='2017' or i[:4]=='2018' or i[:4]=='2016' or i[:4] == '2015']
    fetch = xtech_db.get_data("`{}`".format(all_date[0])).sort_values('SecuCode')
    all_data = pd.DataFrame()
    print('fetching data from server....')
    for i in range(len(all_date) - 1):
        p = str(i+1)+'/'+str(len(all_date)-1)+'    '+str(all_date[i+1])
#         print (p, end="\r")
        print(p)
        next_fetch = xtech_db.get_data("`{}`".format(all_date[i+1])).sort_values('SecuCode')
        fetch["NextReturn"] = 100 * (next_fetch['ClosePrice'].astype('float32') - next_fetch['PrevClosePrice'].astype('float32'))/next_fetch['PrevClosePrice'].astype('float32')
#         print(fetch["SecuCode"] in find_index(str(all_date[i])))
        stkpool = find_index(str(all_date[i]))
        stock_pool = [_ in stkpool for _ in fetch["SecuCode"]]
        print(len(fetch[stock_pool]))
        all_data = all_data.append(fetch[stock_pool])
        fetch = next_fetch
    print(all_data.columns)
    all_data['TradingDay'] = all_data['TradingDay'].astype('datetime64')
    #deal with nan
    all_data['NextReturn'] = np.nan_to_num(all_data['NextReturn'].values)
    return all_data

# %%
len(find_index(str(all_date[-1])))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-67cb169f1952> in <module>()
# ----> 1 len(find_index(str(all_date[-1])))
#
# NameError: name 'all_date' is not defined

# %%
all_data = get_all_data()
# Out:
# fetching data from server....
# 1/974    2015-01-06
# login success!
# logout success!
# 500
# 2/974    2015-01-07
# login success!
# logout success!
# 500
# 3/974    2015-01-08
# login success!
# logout success!
# 500
# 4/974    2015-01-09
# login success!
# logout success!
# 500
# 5/974    2015-01-12
# login success!
# logout success!
# 500
# 6/974    2015-01-13
# login success!
# logout success!
# 500
# 7/974    2015-01-14
# login success!
# logout success!
# 500
# 8/974    2015-01-15
# login success!
# logout success!
# 500
# 9/974    2015-01-16
# login success!
# logout success!
# 500
# 10/974    2015-01-19
# login success!
# logout success!
# 500
# 11/974    2015-01-20
# login success!
# logout success!
# 500
# 12/974    2015-01-21
# login success!
# logout success!
# 500
# 13/974    2015-01-22
# login success!
# logout success!
# 500
# 14/974    2015-01-23
# login success!
# logout success!
# 500
# 15/974    2015-01-26
# login success!
# logout success!
# 500
# 16/974    2015-01-27
# login success!
# logout success!
# 500
# 17/974    2015-01-28
# login success!
# logout success!
# 500
# 18/974    2015-01-29
# login success!
# logout success!
# 500
# 19/974    2015-01-30
# login success!
# logout success!
# 500
# 20/974    2015-02-02
# login success!
# logout success!
# 500
# 21/974    2015-02-03
# login success!
# logout success!
# 500
# 22/974    2015-02-04
# login success!
# logout success!
# 500
# 23/974    2015-02-05
# login success!
# logout success!
# 500
# 24/974    2015-02-06
# login success!
# logout success!
# 500
# 25/974    2015-02-09
# login success!
# logout success!
# 500
# 26/974    2015-02-10
# login success!
# logout success!
# 500
# 27/974    2015-02-11
# login success!
# logout success!
# 500
# 28/974    2015-02-12
# login success!
# logout success!
# 500
# 29/974    2015-02-13
# login success!
# logout success!
# 500
# 30/974    2015-02-16
# login success!
# logout success!
# 500
# 31/974    2015-02-17
# login success!
# logout success!
# 500
# 32/974    2015-02-25
# login success!
# logout success!
# 500
# 33/974    2015-02-26
# login success!
# logout success!
# 500
# 34/974    2015-02-27
# login success!
# logout success!
# 500
# 35/974    2015-03-02
# login success!
# logout success!
# 500
# 36/974    2015-03-03
# login success!
# logout success!
# 500
# 37/974    2015-03-04
# login success!
# logout success!
# 500
# 38/974    2015-03-05
# login success!
# logout success!
# 500
# 39/974    2015-03-06
# login success!
# logout success!
# 500
# 40/974    2015-03-09
# login success!
# logout success!
# 500
# 41/974    2015-03-10
# login success!
# logout success!
# 500
# 42/974    2015-03-11
# login success!
# logout success!
# 500
# 43/974    2015-03-12
# login success!
# logout success!
# 500
# 44/974    2015-03-13
# login success!
# logout success!
# 500
# 45/974    2015-03-16
# login success!
# logout success!
# 500
# 46/974    2015-03-17
# login success!
# logout success!
# 500
# 47/974    2015-03-18
# login success!
# logout success!
# 500
# 48/974    2015-03-19
# login success!
# logout success!
# 500
# 49/974    2015-03-20
# login success!
# logout success!
# 500
# 50/974    2015-03-23
# login success!
# logout success!
# 500
# 51/974    2015-03-24
# login success!
# logout success!
# 500
# 52/974    2015-03-25
# login success!
# logout success!
# 500
# 53/974    2015-03-26
# login success!
# logout success!
# 500
# 54/974    2015-03-27
# login success!
# logout success!
# 500
# 55/974    2015-03-30
# login success!
# logout success!
# 500
# 56/974    2015-03-31
# login success!
# logout success!
# 500
# 57/974    2015-04-01
# login success!
# logout success!
# 500
# 58/974    2015-04-02
# login success!
# logout success!
# 500
# 59/974    2015-04-03
# login success!
# logout success!
# 500
# 60/974    2015-04-07
# login success!
# logout success!
# 500
# 61/974    2015-04-08
# login success!
# logout success!
# 500
# 62/974    2015-04-09
# login success!
# logout success!
# 500
# 63/974    2015-04-10
# login success!
# logout success!
# 500
# 64/974    2015-04-13
# login success!
# logout success!
# 500
# 65/974    2015-04-14
# login success!
# logout success!
# 500
# 66/974    2015-04-15
# login success!
# logout success!
# 500
# 67/974    2015-04-16
# login success!
# logout success!
# 500
# 68/974    2015-04-17
# login success!
# logout success!
# 500
# 69/974    2015-04-20
# login success!
# logout success!
# 500
# 70/974    2015-04-21
# login success!
# logout success!
# 500
# 71/974    2015-04-22
# login success!
# logout success!
# 500
# 72/974    2015-04-23
# login success!
# logout success!
# 500
# 73/974    2015-04-24
# login success!
# logout success!
# 500
# 74/974    2015-04-27
# login success!
# logout success!
# 500
# 75/974    2015-04-28
# login success!
# logout success!
# 500
# 76/974    2015-04-29
# login success!
# logout success!
# 500
# 77/974    2015-04-30
# login success!
# logout success!
# 500
# 78/974    2015-05-04
# login success!
# logout success!
# 500
# 79/974    2015-05-05
# login success!
# logout success!
# 500
# 80/974    2015-05-06
# login success!
# logout success!
# 500
# 81/974    2015-05-07
# login success!
# logout success!
# 500
# 82/974    2015-05-08
# login success!
# logout success!
# 500
# 83/974    2015-05-11
# login success!
# logout success!
# 500
# 84/974    2015-05-12
# login success!
# logout success!
# 500
# 85/974    2015-05-13
# login success!
# logout success!
# 500
# 86/974    2015-05-14
# login success!
# logout success!
# 500
# 87/974    2015-05-15
# login success!
# logout success!
# 500
# 88/974    2015-05-18
# login success!
# logout success!
# 500
# 89/974    2015-05-19
# login success!
# logout success!
# 500
# 90/974    2015-05-20
# login success!
# logout success!
# 500
# 91/974    2015-05-21
# login success!
# logout success!
# 500
# 92/974    2015-05-22
# login success!
# logout success!
# 500
# 93/974    2015-05-25
# login success!
# logout success!
# 500
# 94/974    2015-05-26
# login success!
# logout success!
# 500
# 95/974    2015-05-27
# login success!
# logout success!
# 500
# 96/974    2015-05-28
# login success!
# logout success!
# 500
# 97/974    2015-05-29
# login success!
# logout success!
# 500
# 98/974    2015-06-01
# login success!
# logout success!
# 500
# 99/974    2015-06-02
# login success!
# logout success!
# 500
# 100/974    2015-06-03
# login success!
# logout success!
# 500
# 101/974    2015-06-04
# login success!
# logout success!
# 500
# 102/974    2015-06-05
# login success!
# logout success!
# 500
# 103/974    2015-06-08
# login success!
# logout success!
# 500
# 104/974    2015-06-09
# login success!
# logout success!
# 500
# 105/974    2015-06-10
# login success!
# logout success!
# 500
# 106/974    2015-06-11
# login success!
# logout success!
# 500
# 107/974    2015-06-12
# login success!
# logout success!
# 500
# 108/974    2015-06-15
# login success!
# logout success!
# 500
# 109/974    2015-06-16
# login success!
# logout success!
# 500
# 110/974    2015-06-17
# login success!
# logout success!
# 500
# 111/974    2015-06-18
# login success!
# logout success!
# 500
# 112/974    2015-06-19
# login success!
# logout success!
# 500
# 113/974    2015-06-23
# login success!
# logout success!
# 500
# 114/974    2015-06-24
# login success!
# logout success!
# 500
# 115/974    2015-06-25
# login success!
# logout success!
# 500
# 116/974    2015-06-26
# login success!
# logout success!
# 500
# 117/974    2015-06-29
# login success!
# logout success!
# 500
# 118/974    2015-06-30
# login success!
# logout success!
# 500
# 119/974    2015-07-01
# login success!
# logout success!
# 500
# 120/974    2015-07-02
# login success!
# logout success!
# 500
# 121/974    2015-07-03
# login success!
# logout success!
# 500
# 122/974    2015-07-06
# login success!
# logout success!
# 500
# 123/974    2015-07-07
# login success!
# logout success!
# 500
# 124/974    2015-07-08
# login success!
# logout success!
# 500
# 125/974    2015-07-09
# login success!
# logout success!
# 500
# 126/974    2015-07-10
# login success!
# logout success!
# 500
# 127/974    2015-07-13
# login success!
# logout success!
# 500
# 128/974    2015-07-14
# login success!
# logout success!
# 500
# 129/974    2015-07-15
# login success!
# logout success!
# 500
# 130/974    2015-07-16
# login success!
# logout success!
# 500
# 131/974    2015-07-17
# login success!
# logout success!
# 500
# 132/974    2015-07-20
# login success!
# logout success!
# 500
# 133/974    2015-07-21
# login success!
# logout success!
# 500
# 134/974    2015-07-22
# login success!
# logout success!
# 500
# 135/974    2015-07-23
# login success!
# logout success!
# 500
# 136/974    2015-07-24
# login success!
# logout success!
# 500
# 137/974    2015-07-27
# login success!
# logout success!
# 500
# 138/974    2015-07-28
# login success!
# logout success!
# 500
# 139/974    2015-07-29
# login success!
# logout success!
# 500
# 140/974    2015-07-30
# login success!
# logout success!
# 500
# 141/974    2015-07-31
# login success!
# logout success!
# 500
# 142/974    2015-08-03
# login success!
# logout success!
# 500
# 143/974    2015-08-04
# login success!
# logout success!
# 500
# 144/974    2015-08-05
# login success!
# logout success!
# 500
# 145/974    2015-08-06
# login success!
# logout success!
# 500
# 146/974    2015-08-07
# login success!
# logout success!
# 500
# 147/974    2015-08-10
# login success!
# logout success!
# 500
# 148/974    2015-08-11
# login success!
# logout success!
# 500
# 149/974    2015-08-12
# login success!
# logout success!
# 500
# 150/974    2015-08-13
# login success!
# logout success!
# 500
# 151/974    2015-08-14
# login success!
# logout success!
# 500
# 152/974    2015-08-17
# login success!
# logout success!
# 500
# 153/974    2015-08-18
# login success!
# logout success!
# 500
# 154/974    2015-08-19
# login success!
# logout success!
# 500
# 155/974    2015-08-20
# login success!
# logout success!
# 500
# 156/974    2015-08-21
# login success!
# logout success!
# 500
# 157/974    2015-08-24
# login success!
# logout success!
# 500
# 158/974    2015-08-25
# login success!
# logout success!
# 500
# 159/974    2015-08-26
# login success!
# logout success!
# 500
# 160/974    2015-08-27
# login success!
# logout success!
# 500
# 161/974    2015-08-28
# login success!
# logout success!
# 500
# 162/974    2015-08-31
# login success!
# logout success!
# 500
# 163/974    2015-09-01
# login success!
# logout success!
# 500
# 164/974    2015-09-02
# login success!
# logout success!
# 500
# 165/974    2015-09-07
# login success!
# logout success!
# 500
# 166/974    2015-09-08
# login success!
# logout success!
# 500
# 167/974    2015-09-09
# login success!
# logout success!
# 500
# 168/974    2015-09-10
# login success!
# logout success!
# 500
# 169/974    2015-09-11
# login success!
# logout success!
# 500
# 170/974    2015-09-14
# login success!
# logout success!
# 500
# 171/974    2015-09-15
# login success!
# logout success!
# 500
# 172/974    2015-09-16
# login success!
# logout success!
# 500
# 173/974    2015-09-17
# login success!
# logout success!
# 500
# 174/974    2015-09-18
# login success!
# logout success!
# 500
# 175/974    2015-09-21
# login success!
# logout success!
# 500
# 176/974    2015-09-22
# login success!
# logout success!
# 500
# 177/974    2015-09-23
# login success!
# logout success!
# 500
# 178/974    2015-09-24
# login success!
# logout success!
# 500
# 179/974    2015-09-25
# login success!
# logout success!
# 500
# 180/974    2015-09-28
# login success!
# logout success!
# 500
# 181/974    2015-09-29
# login success!
# logout success!
# 500
# 182/974    2015-09-30
# login success!
# logout success!
# 500
# 183/974    2015-10-08
# login success!
# logout success!
# 500
# 184/974    2015-10-09
# login success!
# logout success!
# 500
# 185/974    2015-10-12
# login success!
# logout success!
# 500
# 186/974    2015-10-13
# login success!
# logout success!
# 500
# 187/974    2015-10-14
# login success!
# logout success!
# 500
# 188/974    2015-10-15
# login success!
# logout success!
# 500
# 189/974    2015-10-16
# login success!
# logout success!
# 500
# 190/974    2015-10-19
# login success!
# logout success!
# 500
# 191/974    2015-10-20
# login success!
# logout success!
# 500
# 192/974    2015-10-21
# login success!
# logout success!
# 500
# 193/974    2015-10-22
# login success!
# logout success!
# 500
# 194/974    2015-10-23
# login success!
# logout success!
# 500
# 195/974    2015-10-26
# login success!
# logout success!
# 500
# 196/974    2015-10-27
# login success!
# logout success!
# 500
# 197/974    2015-10-28
# login success!
# logout success!
# 500
# 198/974    2015-10-29
# login success!
# logout success!
# 500
# 199/974    2015-10-30
# login success!
# logout success!
# 500
# 200/974    2015-11-02
# login success!
# logout success!
# 500
# 201/974    2015-11-03
# login success!
# logout success!
# 500
# 202/974    2015-11-04
# login success!
# logout success!
# 500
# 203/974    2015-11-05
# login success!
# logout success!
# 500
# 204/974    2015-11-06
# login success!
# logout success!
# 500
# 205/974    2015-11-09
# login success!
# logout success!
# 500
# 206/974    2015-11-10
# login success!
# logout success!
# 500
# 207/974    2015-11-11
# login success!
# logout success!
# 500
# 208/974    2015-11-12
# login success!
# logout success!
# 500
# 209/974    2015-11-13
# login success!
# logout success!
# 500
# 210/974    2015-11-16
# login success!
# logout success!
# 500
# 211/974    2015-11-17
# login success!
# logout success!
# 500
# 212/974    2015-11-18
# login success!
# logout success!
# 500
# 213/974    2015-11-19
# login success!
# logout success!
# 500
# 214/974    2015-11-20
# login success!
# logout success!
# 500
# 215/974    2015-11-23
# login success!
# logout success!
# 500
# 216/974    2015-11-24
# login success!
# logout success!
# 500
# 217/974    2015-11-25
# login success!
# logout success!
# 500
# 218/974    2015-11-26
# login success!
# logout success!
# 500
# 219/974    2015-11-27
# login success!
# logout success!
# 500
# 220/974    2015-11-30
# login success!
# logout success!
# 500
# 221/974    2015-12-01
# login success!
# logout success!
# 500
# 222/974    2015-12-02
# login success!
# logout success!
# 500
# 223/974    2015-12-03
# login success!
# logout success!
# 500
# 224/974    2015-12-04
# login success!
# logout success!
# 500
# 225/974    2015-12-07
# login success!
# logout success!
# 500
# 226/974    2015-12-08
# login success!
# logout success!
# 500
# 227/974    2015-12-09
# login success!
# logout success!
# 500
# 228/974    2015-12-10
# login success!
# logout success!
# 500
# 229/974    2015-12-11
# login success!
# logout success!
# 500
# 230/974    2015-12-14
# login success!
# logout success!
# 500
# 231/974    2015-12-15
# login success!
# logout success!
# 500
# 232/974    2015-12-16
# login success!
# logout success!
# 500
# 233/974    2015-12-17
# login success!
# logout success!
# 500
# 234/974    2015-12-18
# login success!
# logout success!
# 500
# 235/974    2015-12-21
# login success!
# logout success!
# 500
# 236/974    2015-12-22
# login success!
# logout success!
# 500
# 237/974    2015-12-23
# login success!
# logout success!
# 500
# 238/974    2015-12-24
# login success!
# logout success!
# 500
# 239/974    2015-12-25
# login success!
# logout success!
# 500
# 240/974    2015-12-28
# login success!
# logout success!
# 500
# 241/974    2015-12-29
# login success!
# logout success!
# 500
# 242/974    2015-12-30
# login success!
# logout success!
# 500
# 243/974    2015-12-31
# login success!
# logout success!
# 500
# 244/974    2016-01-04
# login success!
# logout success!
# 500
# 245/974    2016-01-05
# login success!
# logout success!
# 500
# 246/974    2016-01-06
# login success!
# logout success!
# 500
# 247/974    2016-01-07
# login success!
# logout success!
# 500
# 248/974    2016-01-08
# login success!
# logout success!
# 500
# 249/974    2016-01-11
# login success!
# logout success!
# 500
# 250/974    2016-01-12
# login success!
# logout success!
# 500
# 251/974    2016-01-13
# login success!
# logout success!
# 500
# 252/974    2016-01-14
# login success!
# logout success!
# 500
# 253/974    2016-01-15
# login success!
# logout success!
# 500
# 254/974    2016-01-18
# login success!
# logout success!
# 500
# 255/974    2016-01-19
# login success!
# logout success!
# 500
# 256/974    2016-01-20
# login success!
# logout success!
# 500
# 257/974    2016-01-21
# login success!
# logout success!
# 500
# 258/974    2016-01-22
# login success!
# logout success!
# 500
# 259/974    2016-01-25
# login success!
# logout success!
# 500
# 260/974    2016-01-26
# login success!
# logout success!
# 500
# 261/974    2016-01-27
# login success!
# logout success!
# 500
# 262/974    2016-01-28
# login success!
# logout success!
# 500
# 263/974    2016-01-29
# login success!
# logout success!
# 500
# 264/974    2016-02-01
# login success!
# logout success!
# 500
# 265/974    2016-02-02
# login success!
# logout success!
# 500
# 266/974    2016-02-03
# login success!
# logout success!
# 500
# 267/974    2016-02-04
# login success!
# logout success!
# 500
# 268/974    2016-02-05
# login success!
# logout success!
# 500
# 269/974    2016-02-15
# login success!
# logout success!
# 500
# 270/974    2016-02-16
# login success!
# logout success!
# 500
# 271/974    2016-02-17
# login success!
# logout success!
# 500
# 272/974    2016-02-18
# login success!
# logout success!
# 500
# 273/974    2016-02-19
# login success!
# logout success!
# 500
# 274/974    2016-02-22
# login success!
# logout success!
# 500
# 275/974    2016-02-23
# login success!
# logout success!
# 500
# 276/974    2016-02-24
# login success!
# logout success!
# 500
# 277/974    2016-02-25
# login success!
# logout success!
# 500
# 278/974    2016-02-26
# login success!
# logout success!
# 500
# 279/974    2016-02-29
# login success!
# logout success!
# 500
# 280/974    2016-03-01
# login success!
# logout success!
# 500
# 281/974    2016-03-02
# login success!
# logout success!
# 500
# 282/974    2016-03-03
# login success!
# logout success!
# 500
# 283/974    2016-03-04
# login success!
# logout success!
# 500
# 284/974    2016-03-07
# login success!
# logout success!
# 500
# 285/974    2016-03-08
# login success!
# logout success!
# 500
# 286/974    2016-03-09
# login success!
# logout success!
# 500
# 287/974    2016-03-10
# login success!
# logout success!
# 500
# 288/974    2016-03-11
# login success!
# logout success!
# 500
# 289/974    2016-03-14
# login success!
# logout success!
# 500
# 290/974    2016-03-15
# login success!
# logout success!
# 500
# 291/974    2016-03-16
# login success!
# logout success!
# 500
# 292/974    2016-03-17
# login success!
# logout success!
# 500
# 293/974    2016-03-18
# login success!
# logout success!
# 500
# 294/974    2016-03-21
# login success!
# logout success!
# 500
# 295/974    2016-03-22
# login success!
# logout success!
# 500
# 296/974    2016-03-23
# login success!
# logout success!
# 500
# 297/974    2016-03-24
# login success!
# logout success!
# 500
# 298/974    2016-03-25
# login success!
# logout success!
# 500
# 299/974    2016-03-28
# login success!
# logout success!
# 500
# 300/974    2016-03-29
# login success!
# logout success!
# 500
# 301/974    2016-03-30
# login success!
# logout success!
# 500
# 302/974    2016-03-31
# login success!
# logout success!
# 500
# 303/974    2016-04-01
# login success!
# logout success!
# 500
# 304/974    2016-04-05
# login success!
# logout success!
# 500
# 305/974    2016-04-06
# login success!
# logout success!
# 500
# 306/974    2016-04-07
# login success!
# logout success!
# 500
# 307/974    2016-04-08
# login success!
# logout success!
# 500
# 308/974    2016-04-11
# login success!
# logout success!
# 500
# 309/974    2016-04-12
# login success!
# logout success!
# 500
# 310/974    2016-04-13
# login success!
# logout success!
# 500
# 311/974    2016-04-14
# login success!
# logout success!
# 500
# 312/974    2016-04-15
# login success!
# logout success!
# 500
# 313/974    2016-04-18
# login success!
# logout success!
# 500
# 314/974    2016-04-19
# login success!
# logout success!
# 500
# 315/974    2016-04-20
# login success!
# logout success!
# 500
# 316/974    2016-04-21
# login success!
# logout success!
# 500
# 317/974    2016-04-22
# login success!
# logout success!
# 500
# 318/974    2016-04-25
# login success!
# logout success!
# 500
# 319/974    2016-04-26
# login success!
# logout success!
# 500
# 320/974    2016-04-27
# login success!
# logout success!
# 500
# 321/974    2016-04-28
# login success!
# logout success!
# 500
# 322/974    2016-04-29
# login success!
# logout success!
# 500
# 323/974    2016-05-03
# login success!
# logout success!
# 500
# 324/974    2016-05-04
# login success!
# logout success!
# 500
# 325/974    2016-05-05
# login success!
# logout success!
# 500
# 326/974    2016-05-06
# login success!
# logout success!
# 500
# 327/974    2016-05-09
# login success!
# logout success!
# 500
# 328/974    2016-05-10
# login success!
# logout success!
# 500
# 329/974    2016-05-11
# login success!
# logout success!
# 500
# 330/974    2016-05-12
# login success!
# logout success!
# 500
# 331/974    2016-05-13
# login success!
# logout success!
# 500
# 332/974    2016-05-16
# login success!
# logout success!
# 500
# 333/974    2016-05-17
# login success!
# logout success!
# 500
# 334/974    2016-05-18
# login success!
# logout success!
# 500
# 335/974    2016-05-19
# login success!
# logout success!
# 500
# 336/974    2016-05-20
# login success!
# logout success!
# 500
# 337/974    2016-05-23
# login success!
# logout success!
# 500
# 338/974    2016-05-24
# login success!
# logout success!
# 500
# 339/974    2016-05-25
# login success!
# logout success!
# 500
# 340/974    2016-05-26
# login success!
# logout success!
# 500
# 341/974    2016-05-27
# login success!
# logout success!
# 500
# 342/974    2016-05-30
# login success!
# logout success!
# 500
# 343/974    2016-05-31
# login success!
# logout success!
# 500
# 344/974    2016-06-01
# login success!
# logout success!
# 500
# 345/974    2016-06-02
# login success!
# logout success!
# 500
# 346/974    2016-06-03
# login success!
# logout success!
# 500
# 347/974    2016-06-06
# login success!
# logout success!
# 500
# 348/974    2016-06-07
# login success!
# logout success!
# 500
# 349/974    2016-06-08
# login success!
# logout success!
# 500
# 350/974    2016-06-13
# login success!
# logout success!
# 500
# 351/974    2016-06-14
# login success!
# logout success!
# 500
# 352/974    2016-06-15
# login success!
# logout success!
# 500
# 353/974    2016-06-16
# login success!
# logout success!
# 500
# 354/974    2016-06-17
# login success!
# logout success!
# 500
# 355/974    2016-06-20
# login success!
# logout success!
# 500
# 356/974    2016-06-21
# login success!
# logout success!
# 500
# 357/974    2016-06-22
# login success!
# logout success!
# 500
# 358/974    2016-06-23
# login success!
# logout success!
# 500
# 359/974    2016-06-24
# login success!
# logout success!
# 500
# 360/974    2016-06-27
# login success!
# logout success!
# 500
# 361/974    2016-06-28
# login success!
# logout success!
# 500
# 362/974    2016-06-29
# login success!
# logout success!
# 500
# 363/974    2016-06-30
# login success!
# logout success!
# 500
# 364/974    2016-07-01
# login success!
# logout success!
# 500
# 365/974    2016-07-04
# login success!
# logout success!
# 500
# 366/974    2016-07-05
# login success!
# logout success!
# 500
# 367/974    2016-07-06
# login success!
# logout success!
# 500
# 368/974    2016-07-07
# login success!
# logout success!
# 500
# 369/974    2016-07-08
# login success!
# logout success!
# 500
# 370/974    2016-07-11
# login success!
# logout success!
# 500
# 371/974    2016-07-12
# login success!
# logout success!
# 500
# 372/974    2016-07-13
# login success!
# logout success!
# 500
# 373/974    2016-07-14
# login success!
# logout success!
# 500
# 374/974    2016-07-15
# login success!
# logout success!
# 500
# 375/974    2016-07-18
# login success!
# logout success!
# 500
# 376/974    2016-07-19
# login success!
# logout success!
# 500
# 377/974    2016-07-20
# login success!
# logout success!
# 500
# 378/974    2016-07-21
# login success!
# logout success!
# 500
# 379/974    2016-07-22
# login success!
# logout success!
# 500
# 380/974    2016-07-25
# login success!
# logout success!
# 500
# 381/974    2016-07-26
# login success!
# logout success!
# 500
# 382/974    2016-07-27
# login success!
# logout success!
# 500
# 383/974    2016-07-28
# login success!
# logout success!
# 500
# 384/974    2016-07-29
# login success!
# logout success!
# 500
# 385/974    2016-08-01
# login success!
# logout success!
# 500
# 386/974    2016-08-02
# login success!
# logout success!
# 500
# 387/974    2016-08-03
# login success!
# logout success!
# 500
# 388/974    2016-08-04
# login success!
# logout success!
# 500
# 389/974    2016-08-05
# login success!
# logout success!
# 500
# 390/974    2016-08-08
# login success!
# logout success!
# 500
# 391/974    2016-08-09
# login success!
# logout success!
# 500
# 392/974    2016-08-10
# login success!
# logout success!
# 500
# 393/974    2016-08-11
# login success!
# logout success!
# 500
# 394/974    2016-08-12
# login success!
# logout success!
# 500
# 395/974    2016-08-15
# login success!
# logout success!
# 500
# 396/974    2016-08-16
# login success!
# logout success!
# 500
# 397/974    2016-08-17
# login success!
# logout success!
# 500
# 398/974    2016-08-18
# login success!
# logout success!
# 500
# 399/974    2016-08-19
# login success!
# logout success!
# 500
# 400/974    2016-08-22
# login success!
# logout success!
# 500
# 401/974    2016-08-23
# login success!
# logout success!
# 500
# 402/974    2016-08-24
# login success!
# logout success!
# 500
# 403/974    2016-08-25
# login success!
# logout success!
# 500
# 404/974    2016-08-26
# login success!
# logout success!
# 500
# 405/974    2016-08-29
# login success!
# logout success!
# 500
# 406/974    2016-08-30
# login success!
# logout success!
# 500
# 407/974    2016-08-31
# login success!
# logout success!
# 500
# 408/974    2016-09-01
# login success!
# logout success!
# 500
# 409/974    2016-09-02
# login success!
# logout success!
# 500
# 410/974    2016-09-05
# login success!
# logout success!
# 500
# 411/974    2016-09-06
# login success!
# logout success!
# 500
# 412/974    2016-09-07
# login success!
# logout success!
# 500
# 413/974    2016-09-08
# login success!
# logout success!
# 500
# 414/974    2016-09-09
# login success!
# logout success!
# 500
# 415/974    2016-09-12
# login success!
# logout success!
# 500
# 416/974    2016-09-13
# login success!
# logout success!
# 500
# 417/974    2016-09-14
# login success!
# logout success!
# 500
# 418/974    2016-09-19
# login success!
# logout success!
# 500
# 419/974    2016-09-20
# login success!
# logout success!
# 500
# 420/974    2016-09-21
# login success!
# logout success!
# 500
# 421/974    2016-09-22
# login success!
# logout success!
# 500
# 422/974    2016-09-23
# login success!
# logout success!
# 500
# 423/974    2016-09-26
# login success!
# logout success!
# 500
# 424/974    2016-09-27
# login success!
# logout success!
# 500
# 425/974    2016-09-28
# login success!
# logout success!
# 500
# 426/974    2016-09-29
# login success!
# logout success!
# 500
# 427/974    2016-09-30
# login success!
# logout success!
# 500
# 428/974    2016-10-10
# login success!
# logout success!
# 500
# 429/974    2016-10-11
# login success!
# logout success!
# 500
# 430/974    2016-10-12
# login success!
# logout success!
# 500
# 431/974    2016-10-13
# login success!
# logout success!
# 500
# 432/974    2016-10-14
# login success!
# logout success!
# 500
# 433/974    2016-10-17
# login success!
# logout success!
# 500
# 434/974    2016-10-18
# login success!
# logout success!
# 500
# 435/974    2016-10-19
# login success!
# logout success!
# 500
# 436/974    2016-10-20
# login success!
# logout success!
# 500
# 437/974    2016-10-21
# login success!
# logout success!
# 500
# 438/974    2016-10-24
# login success!
# logout success!
# 500
# 439/974    2016-10-25
# login success!
# logout success!
# 500
# 440/974    2016-10-26
# login success!
# logout success!
# 500
# 441/974    2016-10-27
# login success!
# logout success!
# 500
# 442/974    2016-10-28
# login success!
# logout success!
# 500
# 443/974    2016-10-31
# login success!
# logout success!
# 500
# 444/974    2016-11-01
# login success!
# logout success!
# 500
# 445/974    2016-11-02
# login success!
# logout success!
# 500
# 446/974    2016-11-03
# login success!
# logout success!
# 500
# 447/974    2016-11-04
# login success!
# logout success!
# 500
# 448/974    2016-11-07
# login success!
# logout success!
# 500
# 449/974    2016-11-08
# login success!
# logout success!
# 500
# 450/974    2016-11-09
# login success!
# logout success!
# 500
# 451/974    2016-11-10
# login success!
# logout success!
# 500
# 452/974    2016-11-11
# login success!
# logout success!
# 500
# 453/974    2016-11-14
# login success!
# logout success!
# 500
# 454/974    2016-11-15
# login success!
# logout success!
# 500
# 455/974    2016-11-16
# login success!
# logout success!
# 500
# 456/974    2016-11-17
# login success!
# logout success!
# 500
# 457/974    2016-11-18
# login success!
# logout success!
# 500
# 458/974    2016-11-21
# login success!
# logout success!
# 500
# 459/974    2016-11-22
# login success!
# logout success!
# 500
# 460/974    2016-11-23
# login success!
# logout success!
# 500
# 461/974    2016-11-24
# login success!
# logout success!
# 500
# 462/974    2016-11-25
# login success!
# logout success!
# 500
# 463/974    2016-11-28
# login success!
# logout success!
# 500
# 464/974    2016-11-29
# login success!
# logout success!
# 500
# 465/974    2016-11-30
# login success!
# logout success!
# 500
# 466/974    2016-12-01
# login success!
# logout success!
# 500
# 467/974    2016-12-02
# login success!
# logout success!
# 500
# 468/974    2016-12-05
# login success!
# logout success!
# 500
# 469/974    2016-12-06
# login success!
# logout success!
# 500
# 470/974    2016-12-07
# login success!
# logout success!
# 500
# 471/974    2016-12-08
# login success!
# logout success!
# 500
# 472/974    2016-12-09
# login success!
# logout success!
# 500
# 473/974    2016-12-12
# login success!
# logout success!
# 500
# 474/974    2016-12-13
# login success!
# logout success!
# 500
# 475/974    2016-12-14
# login success!
# logout success!
# 500
# 476/974    2016-12-15
# login success!
# logout success!
# 500
# 477/974    2016-12-16
# login success!
# logout success!
# 500
# 478/974    2016-12-19
# login success!
# logout success!
# 500
# 479/974    2016-12-20
# login success!
# logout success!
# 500
# 480/974    2016-12-21
# login success!
# logout success!
# 500
# 481/974    2016-12-22
# login success!
# logout success!
# 500
# 482/974    2016-12-23
# login success!
# logout success!
# 500
# 483/974    2016-12-26
# login success!
# logout success!
# 500
# 484/974    2016-12-27
# login success!
# logout success!
# 500
# 485/974    2016-12-28
# login success!
# logout success!
# 500
# 486/974    2016-12-29
# login success!
# logout success!
# 500
# 487/974    2016-12-30
# login success!
# logout success!
# 500
# 488/974    2017-01-03
# login success!
# logout success!
# 500
# 489/974    2017-01-04
# login success!
# logout success!
# 500
# 490/974    2017-01-05
# login success!
# logout success!
# 500
# 491/974    2017-01-06
# login success!
# logout success!
# 500
# 492/974    2017-01-09
# login success!
# logout success!
# 500
# 493/974    2017-01-10
# login success!
# logout success!
# 500
# 494/974    2017-01-11
# login success!
# logout success!
# 500
# 495/974    2017-01-12
# login success!
# logout success!
# 500
# 496/974    2017-01-13
# login success!
# logout success!
# 500
# 497/974    2017-01-16
# login success!
# logout success!
# 500
# 498/974    2017-01-17
# login success!
# logout success!
# 500
# 499/974    2017-01-18
# login success!
# logout success!
# 500
# 500/974    2017-01-19
# login success!
# logout success!
# 499
# 501/974    2017-01-20
# login success!
# logout success!
# 499
# 502/974    2017-01-23
# login success!
# logout success!
# 499
# 503/974    2017-01-24
# login success!
# logout success!
# 500
# 504/974    2017-01-25
# login success!
# logout success!
# 500
# 505/974    2017-01-26
# login success!
# logout success!
# 500
# 506/974    2017-02-03
# login success!
# logout success!
# 500
# 507/974    2017-02-06
# login success!
# logout success!
# 500
# 508/974    2017-02-07
# login success!
# logout success!
# 500
# 509/974    2017-02-08
# login success!
# logout success!
# 500
# 510/974    2017-02-09
# login success!
# logout success!
# 500
# 511/974    2017-02-10
# login success!
# logout success!
# 500
# 512/974    2017-02-13
# login success!
# logout success!
# 500
# 513/974    2017-02-14
# login success!
# logout success!
# 500
# 514/974    2017-02-15
# login success!
# logout success!
# 500
# 515/974    2017-02-16
# login success!
# logout success!
# 500
# 516/974    2017-02-17
# login success!
# logout success!
# 500
# 517/974    2017-02-20
# login success!
# logout success!
# 500
# 518/974    2017-02-21
# login success!
# logout success!
# 500
# 519/974    2017-02-22
# login success!
# logout success!
# 500
# 520/974    2017-02-23
# login success!
# logout success!
# 500
# 521/974    2017-02-24
# login success!
# logout success!
# 500
# 522/974    2017-02-27
# login success!
# logout success!
# 500
# 523/974    2017-02-28
# login success!
# logout success!
# 500
# 524/974    2017-03-01
# login success!
# logout success!
# 500
# 525/974    2017-03-02
# login success!
# logout success!
# 500
# 526/974    2017-03-03
# login success!
# logout success!
# 500
# 527/974    2017-03-06
# login success!
# logout success!
# 500
# 528/974    2017-03-07
# login success!
# logout success!
# 500
# 529/974    2017-03-08
# login success!
# logout success!
# 500
# 530/974    2017-03-09
# login success!
# logout success!
# 500
# 531/974    2017-03-10
# login success!
# logout success!
# 500
# 532/974    2017-03-13
# login success!
# logout success!
# 500
# 533/974    2017-03-14
# login success!
# logout success!
# 500
# 534/974    2017-03-15
# login success!
# logout success!
# 500
# 535/974    2017-03-16
# login success!
# logout success!
# 500
# 536/974    2017-03-17
# login success!
# logout success!
# 500
# 537/974    2017-03-20
# login success!
# logout success!
# 500
# 538/974    2017-03-21
# login success!
# logout success!
# 500
# 539/974    2017-03-22
# login success!
# logout success!
# 500
# 540/974    2017-03-23
# login success!
# logout success!
# 500
# 541/974    2017-03-24
# login success!
# logout success!
# 500
# 542/974    2017-03-27
# login success!
# logout success!
# 500
# 543/974    2017-03-28
# login success!
# logout success!
# 500
# 544/974    2017-03-29
# login success!
# logout success!
# 500
# 545/974    2017-03-30
# login success!
# logout success!
# 500
# 546/974    2017-03-31
# login success!
# logout success!
# 500
# 547/974    2017-04-05
# login success!
# logout success!
# 500
# 548/974    2017-04-06
# login success!
# logout success!
# 500
# 549/974    2017-04-07
# login success!
# logout success!
# 500
# 550/974    2017-04-10
# login success!
# logout success!
# 500
# 551/974    2017-04-11
# login success!
# logout success!
# 500
# 552/974    2017-04-12
# login success!
# logout success!
# 500
# 553/974    2017-04-13
# login success!
# logout success!
# 500
# 554/974    2017-04-14
# login success!
# logout success!
# 500
# 555/974    2017-04-17
# login success!
# logout success!
# 500
# 556/974    2017-04-18
# login success!
# logout success!
# 500
# 557/974    2017-04-19
# login success!
# logout success!
# 500
# 558/974    2017-04-20
# login success!
# logout success!
# 500
# 559/974    2017-04-21
# login success!
# logout success!
# 500
# 560/974    2017-04-24
# login success!
# logout success!
# 500
# 561/974    2017-04-25
# login success!
# logout success!
# 500
# 562/974    2017-04-26
# login success!
# logout success!
# 500
# 563/974    2017-04-27
# login success!
# logout success!
# 500
# 564/974    2017-04-28
# login success!
# logout success!
# 500
# 565/974    2017-05-02
# login success!
# logout success!
# 500
# 566/974    2017-05-03
# login success!
# logout success!
# 500
# 567/974    2017-05-04
# login success!
# logout success!
# 500
# 568/974    2017-05-05
# login success!
# logout success!
# 500
# 569/974    2017-05-08
# login success!
# logout success!
# 500
# 570/974    2017-05-09
# login success!
# logout success!
# 500
# 571/974    2017-05-10
# login success!
# logout success!
# 500
# 572/974    2017-05-11
# login success!
# logout success!
# 500
# 573/974    2017-05-12
# login success!
# logout success!
# 500
# 574/974    2017-05-15
# login success!
# logout success!
# 500
# 575/974    2017-05-16
# login success!
# logout success!
# 500
# 576/974    2017-05-17
# login success!
# logout success!
# 500
# 577/974    2017-05-18
# login success!
# logout success!
# 500
# 578/974    2017-05-19
# login success!
# logout success!
# 500
# 579/974    2017-05-22
# login success!
# logout success!
# 500
# 580/974    2017-05-23
# login success!
# logout success!
# 500
# 581/974    2017-05-24
# login success!
# logout success!
# 500
# 582/974    2017-05-25
# login success!
# logout success!
# 500
# 583/974    2017-05-26
# login success!
# logout success!
# 500
# 584/974    2017-05-31
# login success!
# logout success!
# 500
# 585/974    2017-06-01
# login success!
# logout success!
# 500
# 586/974    2017-06-02
# login success!
# logout success!
# 500
# 587/974    2017-06-05
# login success!
# logout success!
# 500
# 588/974    2017-06-06
# login success!
# logout success!
# 500
# 589/974    2017-06-07
# login success!
# logout success!
# 500
# 590/974    2017-06-08
# login success!
# logout success!
# 500
# 591/974    2017-06-09
# login success!
# logout success!
# 500
# 592/974    2017-06-12
# login success!
# logout success!
# 500
# 593/974    2017-06-13
# login success!
# logout success!
# 500
# 594/974    2017-06-14
# login success!
# logout success!
# 500
# 595/974    2017-06-15
# login success!
# logout success!
# 500
# 596/974    2017-06-16
# login success!
# logout success!
# 500
# 597/974    2017-06-19
# login success!
# logout success!
# 500
# 598/974    2017-06-20
# login success!
# logout success!
# 500
# 599/974    2017-06-21
# login success!
# logout success!
# 500
# 600/974    2017-06-22
# login success!
# logout success!
# 500
# 601/974    2017-06-23
# login success!
# logout success!
# 500
# 602/974    2017-06-26
# login success!
# logout success!
# 500
# 603/974    2017-06-27
# login success!
# logout success!
# 500
# 604/974    2017-06-28
# login success!
# logout success!
# 500
# 605/974    2017-06-29
# login success!
# logout success!
# 500
# 606/974    2017-06-30
# login success!
# logout success!
# 500
# 607/974    2017-07-03
# login success!
# logout success!
# 500
# 608/974    2017-07-04
# login success!
# logout success!
# 500
# 609/974    2017-07-05
# login success!
# logout success!
# 500
# 610/974    2017-07-06
# login success!
# logout success!
# 500
# 611/974    2017-07-07
# login success!
# logout success!
# 500
# 612/974    2017-07-10
# login success!
# logout success!
# 500
# 613/974    2017-07-11
# login success!
# logout success!
# 500
# 614/974    2017-07-12
# login success!
# logout success!
# 500
# 615/974    2017-07-13
# login success!
# logout success!
# 500
# 616/974    2017-07-14
# login success!
# logout success!
# 500
# 617/974    2017-07-17
# login success!
# logout success!
# 500
# 618/974    2017-07-18
# login success!
# logout success!
# 500
# 619/974    2017-07-19
# login success!
# logout success!
# 500
# 620/974    2017-07-20
# login success!
# logout success!
# 500
# 621/974    2017-07-21
# login success!
# logout success!
# 500
# 622/974    2017-07-24
# login success!
# logout success!
# 500
# 623/974    2017-07-25
# login success!
# logout success!
# 500
# 624/974    2017-07-26
# login success!
# logout success!
# 500
# 625/974    2017-07-27
# login success!
# logout success!
# 500
# 626/974    2017-07-28
# login success!
# logout success!
# 500
# 627/974    2017-07-31
# login success!
# logout success!
# 500
# 628/974    2017-08-01
# login success!
# logout success!
# 500
# 629/974    2017-08-02
# login success!
# logout success!
# 500
# 630/974    2017-08-03
# login success!
# logout success!
# 500
# 631/974    2017-08-04
# login success!
# logout success!
# 500
# 632/974    2017-08-07
# login success!
# logout success!
# 500
# 633/974    2017-08-08
# login success!
# logout success!
# 500
# 634/974    2017-08-09
# login success!
# logout success!
# 500
# 635/974    2017-08-10
# login success!
# logout success!
# 500
# 636/974    2017-08-11
# login success!
# logout success!
# 500
# 637/974    2017-08-14
# login success!
# logout success!
# 500
# 638/974    2017-08-15
# login success!
# logout success!
# 500
# 639/974    2017-08-16
# login success!
# logout success!
# 500
# 640/974    2017-08-17
# login success!
# logout success!
# 500
# 641/974    2017-08-18
# login success!
# logout success!
# 500
# 642/974    2017-08-21
# login success!
# logout success!
# 500
# 643/974    2017-08-22
# login success!
# logout success!
# 500
# 644/974    2017-08-23
# login success!
# logout success!
# 500
# 645/974    2017-08-24
# login success!
# logout success!
# 500
# 646/974    2017-08-25
# login success!
# logout success!
# 500
# 647/974    2017-08-28
# login success!
# logout success!
# 500
# 648/974    2017-08-29
# login success!
# logout success!
# 500
# 649/974    2017-08-30
# login success!
# logout success!
# 500
# 650/974    2017-08-31
# login success!
# logout success!
# 500
# 651/974    2017-09-01
# login success!
# logout success!
# 500
# 652/974    2017-09-04
# login success!
# logout success!
# 500
# 653/974    2017-09-05
# login success!
# logout success!
# 500
# 654/974    2017-09-06
# login success!
# logout success!
# 500
# 655/974    2017-09-07
# login success!
# logout success!
# 500
# 656/974    2017-09-08
# login success!
# logout success!
# 500
# 657/974    2017-09-11
# login success!
# logout success!
# 500
# 658/974    2017-09-12
# login success!
# logout success!
# 500
# 659/974    2017-09-13
# login success!
# logout success!
# 500
# 660/974    2017-09-14
# login success!
# logout success!
# 500
# 661/974    2017-09-15
# login success!
# logout success!
# 500
# 662/974    2017-09-18
# login success!
# logout success!
# 500
# 663/974    2017-09-19
# login success!
# logout success!
# 500
# 664/974    2017-09-20
# login success!
# logout success!
# 500
# 665/974    2017-09-21
# login success!
# logout success!
# 500
# 666/974    2017-09-22
# login success!
# logout success!
# 500
# 667/974    2017-09-25
# login success!
# logout success!
# 500
# 668/974    2017-09-26
# login success!
# logout success!
# 500
# 669/974    2017-09-27
# login success!
# logout success!
# 500
# 670/974    2017-09-28
# login success!
# logout success!
# 500
# 671/974    2017-09-29
# login success!
# logout success!
# 500
# 672/974    2017-10-09
# login success!
# logout success!
# 500
# 673/974    2017-10-10
# login success!
# logout success!
# 500
# 674/974    2017-10-11
# login success!
# logout success!
# 500
# 675/974    2017-10-12
# login success!
# logout success!
# 500
# 676/974    2017-10-13
# login success!
# logout success!
# 500
# 677/974    2017-10-16
# login success!
# logout success!
# 500
# 678/974    2017-10-17
# login success!
# logout success!
# 500
# 679/974    2017-10-18
# login success!
# logout success!
# 500
# 680/974    2017-10-19
# login success!
# logout success!
# 500
# 681/974    2017-10-20
# login success!
# logout success!
# 500
# 682/974    2017-10-23
# login success!
# logout success!
# 500
# 683/974    2017-10-24
# login success!
# logout success!
# 500
# 684/974    2017-10-25
# login success!
# logout success!
# 500
# 685/974    2017-10-26
# login success!
# logout success!
# 500
# 686/974    2017-10-27
# login success!
# logout success!
# 500
# 687/974    2017-10-30
# login success!
# logout success!
# 500
# 688/974    2017-10-31
# login success!
# logout success!
# 500
# 689/974    2017-11-01
# login success!
# logout success!
# 500
# 690/974    2017-11-02
# login success!
# logout success!
# 500
# 691/974    2017-11-03
# login success!
# logout success!
# 500
# 692/974    2017-11-06
# login success!
# logout success!
# 500
# 693/974    2017-11-07
# login success!
# logout success!
# 500
# 694/974    2017-11-08
# login success!
# logout success!
# 500
# 695/974    2017-11-09
# login success!
# logout success!
# 500
# 696/974    2017-11-10
# login success!
# logout success!
# 500
# 697/974    2017-11-13
# login success!
# logout success!
# 500
# 698/974    2017-11-14
# login success!
# logout success!
# 500
# 699/974    2017-11-15
# login success!
# logout success!
# 500
# 700/974    2017-11-16
# login success!
# logout success!
# 500
# 701/974    2017-11-17
# login success!
# logout success!
# 500
# 702/974    2017-11-20
# login success!
# logout success!
# 500
# 703/974    2017-11-21
# login success!
# logout success!
# 500
# 704/974    2017-11-22
# login success!
# logout success!
# 500
# 705/974    2017-11-23
# login success!
# logout success!
# 500
# 706/974    2017-11-24
# login success!
# logout success!
# 500
# 707/974    2017-11-27
# login success!
# logout success!
# 500
# 708/974    2017-11-28
# login success!
# logout success!
# 500
# 709/974    2017-11-29
# login success!
# logout success!
# 500
# 710/974    2017-11-30
# login success!
# logout success!
# 500
# 711/974    2017-12-01
# login success!
# logout success!
# 500
# 712/974    2017-12-04
# login success!
# logout success!
# 500
# 713/974    2017-12-05
# login success!
# logout success!
# 500
# 714/974    2017-12-06
# login success!
# logout success!
# 500
# 715/974    2017-12-07
# login success!
# logout success!
# 500
# 716/974    2017-12-08
# login success!
# logout success!
# 500
# 717/974    2017-12-11
# login success!
# logout success!
# 500
# 718/974    2017-12-12
# login success!
# logout success!
# 500
# 719/974    2017-12-13
# login success!
# logout success!
# 500
# 720/974    2017-12-14
# login success!
# logout success!
# 500
# 721/974    2017-12-15
# login success!
# logout success!
# 500
# 722/974    2017-12-18
# login success!
# logout success!
# 500
# 723/974    2017-12-19
# login success!
# logout success!
# 500
# 724/974    2017-12-20
# login success!
# logout success!
# 500
# 725/974    2017-12-21
# login success!
# logout success!
# 500
# 726/974    2017-12-22
# login success!
# logout success!
# 500
# 727/974    2017-12-25
# login success!
# logout success!
# 500
# 728/974    2017-12-26
# login success!
# logout success!
# 500
# 729/974    2017-12-27
# login success!
# logout success!
# 500
# 730/974    2017-12-28
# login success!
# logout success!
# 500
# 731/974    2017-12-29
# login success!
# logout success!
# 500
# 732/974    2018-01-02
# login success!
# logout success!
# 500
# 733/974    2018-01-03
# login success!
# logout success!
# 500
# 734/974    2018-01-04
# login success!
# logout success!
# 500
# 735/974    2018-01-05
# login success!
# logout success!
# 500
# 736/974    2018-01-08
# login success!
# logout success!
# 500
# 737/974    2018-01-09
# login success!
# logout success!
# 500
# 738/974    2018-01-10
# login success!
# logout success!
# 500
# 739/974    2018-01-11
# login success!
# logout success!
# 500
# 740/974    2018-01-12
# login success!
# logout success!
# 500
# 741/974    2018-01-15
# login success!
# logout success!
# 500
# 742/974    2018-01-16
# login success!
# logout success!
# 500
# 743/974    2018-01-17
# login success!
# logout success!
# 500
# 744/974    2018-01-18
# login success!
# logout success!
# 500
# 745/974    2018-01-19
# login success!
# logout success!
# 500
# 746/974    2018-01-22
# login success!
# logout success!
# 500
# 747/974    2018-01-23
# login success!
# logout success!
# 500
# 748/974    2018-01-24
# login success!
# logout success!
# 500
# 749/974    2018-01-25
# login success!
# logout success!
# 500
# 750/974    2018-01-26
# login success!
# logout success!
# 500
# 751/974    2018-01-29
# login success!
# logout success!
# 500
# 752/974    2018-01-30
# login success!
# logout success!
# 500
# 753/974    2018-01-31
# login success!
# logout success!
# 500
# 754/974    2018-02-01
# login success!
# logout success!
# 500
# 755/974    2018-02-02
# login success!
# logout success!
# 500
# 756/974    2018-02-05
# login success!
# logout success!
# 500
# 757/974    2018-02-06
# login success!
# logout success!
# 500
# 758/974    2018-02-07
# login success!
# logout success!
# 500
# 759/974    2018-02-08
# login success!
# logout success!
# 500
# 760/974    2018-02-09
# login success!
# logout success!
# 500
# 761/974    2018-02-12
# login success!
# logout success!
# 500
# 762/974    2018-02-13
# login success!
# logout success!
# 500
# 763/974    2018-02-14
# login success!
# logout success!
# 500
# 764/974    2018-02-22
# login success!
# logout success!
# 500
# 765/974    2018-02-23
# login success!
# logout success!
# 500
# 766/974    2018-02-26
# login success!
# logout success!
# 500
# 767/974    2018-02-27
# login success!
# logout success!
# 500
# 768/974    2018-02-28
# login success!
# logout success!
# 500
# 769/974    2018-03-01
# login success!
# logout success!
# 500
# 770/974    2018-03-02
# login success!
# logout success!
# 500
# 771/974    2018-03-05
# login success!
# logout success!
# 500
# 772/974    2018-03-06
# login success!
# logout success!
# 500
# 773/974    2018-03-07
# login success!
# logout success!
# 500
# 774/974    2018-03-08
# login success!
# logout success!
# 500
# 775/974    2018-03-09
# login success!
# logout success!
# 500
# 776/974    2018-03-12
# login success!
# logout success!
# 500
# 777/974    2018-03-13
# login success!
# logout success!
# 500
# 778/974    2018-03-14
# login success!
# logout success!
# 500
# 779/974    2018-03-15
# login success!
# logout success!
# 500
# 780/974    2018-03-16
# login success!
# logout success!
# 500
# 781/974    2018-03-19
# login success!
# logout success!
# 500
# 782/974    2018-03-20
# login success!
# logout success!
# 500
# 783/974    2018-03-21
# login success!
# logout success!
# 500
# 784/974    2018-03-22
# login success!
# logout success!
# 500
# 785/974    2018-03-23
# login success!
# logout success!
# 500
# 786/974    2018-03-26
# login success!
# logout success!
# 500
# 787/974    2018-03-27
# login success!
# logout success!
# 500
# 788/974    2018-03-28
# login success!
# logout success!
# 500
# 789/974    2018-03-29
# login success!
# logout success!
# 500
# 790/974    2018-03-30
# login success!
# logout success!
# 500
# 791/974    2018-04-02
# login success!
# logout success!
# 500
# 792/974    2018-04-03
# login success!
# logout success!
# 500
# 793/974    2018-04-04
# login success!
# logout success!
# 500
# 794/974    2018-04-09
# login success!
# logout success!
# 500
# 795/974    2018-04-10
# login success!
# logout success!
# 500
# 796/974    2018-04-11
# login success!
# logout success!
# 500
# 797/974    2018-04-12
# login success!
# logout success!
# 500
# 798/974    2018-04-13
# login success!
# logout success!
# 500
# 799/974    2018-04-16
# login success!
# logout success!
# 500
# 800/974    2018-04-17
# login success!
# logout success!
# 500
# 801/974    2018-04-18
# login success!
# logout success!
# 500
# 802/974    2018-04-19
# login success!
# logout success!
# 500
# 803/974    2018-04-20
# login success!
# logout success!
# 500
# 804/974    2018-04-23
# login success!
# logout success!
# 500
# 805/974    2018-04-24
# login success!
# logout success!
# 500
# 806/974    2018-04-25
# login success!
# logout success!
# 500
# 807/974    2018-04-26
# login success!
# logout success!
# 500
# 808/974    2018-04-27
# login success!
# logout success!
# 500
# 809/974    2018-05-02
# login success!
# logout success!
# 500
# 810/974    2018-05-03
# login success!
# logout success!
# 500
# 811/974    2018-05-04
# login success!
# logout success!
# 500
# 812/974    2018-05-07
# login success!
# logout success!
# 500
# 813/974    2018-05-08
# login success!
# logout success!
# 500
# 814/974    2018-05-09
# login success!
# logout success!
# 500
# 815/974    2018-05-10
# login success!
# logout success!
# 500
# 816/974    2018-05-11
# login success!
# logout success!
# 500
# 817/974    2018-05-14
# login success!
# logout success!
# 500
# 818/974    2018-05-15
# login success!
# logout success!
# 500
# 819/974    2018-05-16
# login success!
# logout success!
# 500
# 820/974    2018-05-17
# login success!
# logout success!
# 500
# 821/974    2018-05-18
# login success!
# logout success!
# 500
# 822/974    2018-05-21
# login success!
# logout success!
# 500
# 823/974    2018-05-22
# login success!
# logout success!
# 500
# 824/974    2018-05-23
# login success!
# logout success!
# 500
# 825/974    2018-05-24
# login success!
# logout success!
# 500
# 826/974    2018-05-25
# login success!
# logout success!
# 500
# 827/974    2018-05-28
# login success!
# logout success!
# 500
# 828/974    2018-05-29
# login success!
# logout success!
# 500
# 829/974    2018-05-30
# login success!
# logout success!
# 500
# 830/974    2018-05-31
# login success!
# logout success!
# 500
# 831/974    2018-06-01
# login success!
# logout success!
# 500
# 832/974    2018-06-04
# login success!
# logout success!
# 500
# 833/974    2018-06-05
# login success!
# logout success!
# 500
# 834/974    2018-06-06
# login success!
# logout success!
# 500
# 835/974    2018-06-07
# login success!
# logout success!
# 500
# 836/974    2018-06-08
# login success!
# logout success!
# 500
# 837/974    2018-06-11
# login success!
# logout success!
# 500
# 838/974    2018-06-12
# login success!
# logout success!
# 500
# 839/974    2018-06-13
# login success!
# logout success!
# 500
# 840/974    2018-06-14
# login success!
# logout success!
# 500
# 841/974    2018-06-15
# login success!
# logout success!
# 500
# 842/974    2018-06-19
# login success!
# logout success!
# 500
# 843/974    2018-06-20
# login success!
# logout success!
# 500
# 844/974    2018-06-21
# login success!
# logout success!
# 500
# 845/974    2018-06-22
# login success!
# logout success!
# 500
# 846/974    2018-06-25
# login success!
# logout success!
# 500
# 847/974    2018-06-26
# login success!
# logout success!
# 500
# 848/974    2018-06-27
# login success!
# logout success!
# 500
# 849/974    2018-06-28
# login success!
# logout success!
# 500
# 850/974    2018-06-29
# login success!
# logout success!
# 500
# 851/974    2018-07-02
# login success!
# logout success!
# 500
# 852/974    2018-07-03
# login success!
# logout success!
# 500
# 853/974    2018-07-04
# login success!
# logout success!
# 500
# 854/974    2018-07-05
# login success!
# logout success!
# 500
# 855/974    2018-07-06
# login success!
# logout success!
# 500
# 856/974    2018-07-09
# login success!
# logout success!
# 500
# 857/974    2018-07-10
# login success!
# logout success!
# 500
# 858/974    2018-07-11
# login success!
# logout success!
# 500
# 859/974    2018-07-12
# login success!
# logout success!
# 500
# 860/974    2018-07-13
# login success!
# logout success!
# 500
# 861/974    2018-07-16
# login success!
# logout success!
# 500
# 862/974    2018-07-17
# login success!
# logout success!
# 500
# 863/974    2018-07-18
# login success!
# logout success!
# 500
# 864/974    2018-07-19
# login success!
# logout success!
# 500
# 865/974    2018-07-20
# login success!
# logout success!
# 500
# 866/974    2018-07-23
# login success!
# logout success!
# 500
# 867/974    2018-07-24
# login success!
# logout success!
# 500
# 868/974    2018-07-25
# login success!
# logout success!
# 500
# 869/974    2018-07-26
# login success!
# logout success!
# 500
# 870/974    2018-07-27
# login success!
# logout success!
# 500
# 871/974    2018-07-30
# login success!
# logout success!
# 500
# 872/974    2018-07-31
# login success!
# logout success!
# 500
# 873/974    2018-08-01
# login success!
# logout success!
# 500
# 874/974    2018-08-02
# login success!
# logout success!
# 500
# 875/974    2018-08-03
# login success!
# logout success!
# 500
# 876/974    2018-08-06
# login success!
# logout success!
# 500
# 877/974    2018-08-07
# login success!
# logout success!
# 500
# 878/974    2018-08-08
# login success!
# logout success!
# 500
# 879/974    2018-08-09
# login success!
# logout success!
# 500
# 880/974    2018-08-10
# login success!
# logout success!
# 500
# 881/974    2018-08-13
# login success!
# logout success!
# 500
# 882/974    2018-08-14
# login success!
# logout success!
# 500
# 883/974    2018-08-15
# login success!
# logout success!
# 500
# 884/974    2018-08-16
# login success!
# logout success!
# 500
# 885/974    2018-08-17
# login success!
# logout success!
# 500
# 886/974    2018-08-20
# login success!
# logout success!
# 500
# 887/974    2018-08-21
# login success!
# logout success!
# 500
# 888/974    2018-08-22
# login success!
# logout success!
# 500
# 889/974    2018-08-23
# login success!
# logout success!
# 500
# 890/974    2018-08-24
# login success!
# logout success!
# 500
# 891/974    2018-08-27
# login success!
# logout success!
# 500
# 892/974    2018-08-28
# login success!
# logout success!
# 500
# 893/974    2018-08-29
# login success!
# logout success!
# 500
# 894/974    2018-08-30
# login success!
# logout success!
# 500
# 895/974    2018-08-31
# login success!
# logout success!
# 500
# 896/974    2018-09-03
# login success!
# logout success!
# 500
# 897/974    2018-09-04
# login success!
# logout success!
# 500
# 898/974    2018-09-05
# login success!
# logout success!
# 500
# 899/974    2018-09-06
# login success!
# logout success!
# 500
# 900/974    2018-09-07
# login success!
# logout success!
# 500
# 901/974    2018-09-10
# login success!
# logout success!
# 500
# 902/974    2018-09-11
# login success!
# logout success!
# 500
# 903/974    2018-09-12
# login success!
# logout success!
# 500
# 904/974    2018-09-13
# login success!
# logout success!
# 500
# 905/974    2018-09-14
# login success!
# logout success!
# 500
# 906/974    2018-09-17
# login success!
# logout success!
# 500
# 907/974    2018-09-18
# login success!
# logout success!
# 500
# 908/974    2018-09-19
# login success!
# logout success!
# 500
# 909/974    2018-09-20
# login success!
# logout success!
# 500
# 910/974    2018-09-21
# login success!
# logout success!
# 500
# 911/974    2018-09-25
# login success!
# logout success!
# 500
# 912/974    2018-09-26
# login success!
# logout success!
# 500
# 913/974    2018-09-27
# login success!
# logout success!
# 500
# 914/974    2018-09-28
# login success!
# logout success!
# 500
# 915/974    2018-10-08
# login success!
# logout success!
# 500
# 916/974    2018-10-09
# login success!
# logout success!
# 500
# 917/974    2018-10-10
# login success!
# logout success!
# 500
# 918/974    2018-10-11
# login success!
# logout success!
# 500
# 919/974    2018-10-12
# login success!
# logout success!
# 500
# 920/974    2018-10-15
# login success!
# logout success!
# 500
# 921/974    2018-10-16
# login success!
# logout success!
# 500
# 922/974    2018-10-17
# login success!
# logout success!
# 500
# 923/974    2018-10-18
# login success!
# logout success!
# 500
# 924/974    2018-10-19
# login success!
# logout success!
# 500
# 925/974    2018-10-22
# login success!
# logout success!
# 500
# 926/974    2018-10-23
# login success!
# logout success!
# 500
# 927/974    2018-10-24
# login success!
# logout success!
# 500
# 928/974    2018-10-25
# login success!
# logout success!
# 500
# 929/974    2018-10-26
# login success!
# logout success!
# 500
# 930/974    2018-10-29
# login success!
# logout success!
# 500
# 931/974    2018-10-30
# login success!
# logout success!
# 500
# 932/974    2018-10-31
# login success!
# logout success!
# 500
# 933/974    2018-11-01
# login success!
# logout success!
# 500
# 934/974    2018-11-02
# login success!
# logout success!
# 500
# 935/974    2018-11-05
# login success!
# logout success!
# 500
# 936/974    2018-11-06
# login success!
# logout success!
# 500
# 937/974    2018-11-07
# login success!
# logout success!
# 500
# 938/974    2018-11-08
# login success!
# logout success!
# 500
# 939/974    2018-11-09
# login success!
# logout success!
# 500
# 940/974    2018-11-12
# login success!
# logout success!
# 500
# 941/974    2018-11-13
# login success!
# logout success!
# 500
# 942/974    2018-11-14
# login success!
# logout success!
# 500
# 943/974    2018-11-15
# login success!
# logout success!
# 500
# 944/974    2018-11-16
# login success!
# logout success!
# 500
# 945/974    2018-11-19
# login success!
# logout success!
# 500
# 946/974    2018-11-20
# login success!
# logout success!
# 500
# 947/974    2018-11-21
# login success!
# logout success!
# 500
# 948/974    2018-11-22
# login success!
# logout success!
# 500
# 949/974    2018-11-23
# login success!
# logout success!
# 500
# 950/974    2018-11-26
# login success!
# logout success!
# 500
# 951/974    2018-11-27
# login success!
# logout success!
# 500
# 952/974    2018-11-28
# login success!
# logout success!
# 500
# 953/974    2018-11-29
# login success!
# logout success!
# 500
# 954/974    2018-11-30
# login success!
# logout success!
# 500
# 955/974    2018-12-03
# login success!
# logout success!
# 500
# 956/974    2018-12-04
# login success!
# logout success!
# 500
# 957/974    2018-12-05
# login success!
# logout success!
# 500
# 958/974    2018-12-06
# login success!
# logout success!
# 500
# 959/974    2018-12-07
# login success!
# logout success!
# 500
# 960/974    2018-12-10
# login success!
# logout success!
# 500
# 961/974    2018-12-11
# login success!
# logout success!
# 500
# 962/974    2018-12-12
# login success!
# logout success!
# 500
# 963/974    2018-12-13
# login success!
# logout success!
# 500
# 964/974    2018-12-14
# login success!
# logout success!
# 500
# 965/974    2018-12-17
# login success!
# logout success!
# 500
# 966/974    2018-12-18
# login success!
# logout success!
# 500
# 967/974    2018-12-19
# login success!
# logout success!
# 500
# 968/974    2018-12-20
# login success!
# logout success!
# 500
# 969/974    2018-12-21
# login success!
# logout success!
# 500
# 970/974    2018-12-24
# login success!
# logout success!
# 500
# 971/974    2018-12-25
# login success!
# logout success!
# 500
# 972/974    2018-12-26
# login success!
# logout success!
# 500
# 973/974    2018-12-27
# login success!
# logout success!
# 500
# 974/974    2018-12-28
# login success!
# logout success!
# 500
# Index(['index', 'InnerCode', 'TradingDay', 'PrevClosePrice', 'OpenPrice',
#        'HighPrice', 'LowPrice', 'ClosePrice', 'TurnoverVolume',
#        'TurnoverValue', 'TurnoverDeals', 'XGRQ', 'JSID', 'SecuCode',
#        'ChiNameAbbr', 'RatioAdjustingFactor', 'AdjPrevClosePrice',
#        'AdjOpenPrice', 'AdjHighPrice', 'AdjLowPrice', 'AdjClosePrice',
#        'AdjTurnoverValue', 'NextReturn'],
#       dtype='object')

# %%
all_data.reset_index(drop=True, inplace=True)

# %%
file_list = os.listdir("data_backup/alpha")
factors = []
for alpha in file_list:
    factors.append(pd.read_csv('data_backup/alpha/'+alpha)[1:])
factor_index = 0
for factor in factors:
    factor_name = 'factor'+str(factor_index)
    p = "reading " + factor_name + '/' + str(len(factors)-1)
    print(p)
    factor_index += 1
    new_column = {}
    for i in list(factor.columns):
        if 'a' not in i:
            new_column[i] = (6-len(i))*'0'+i
    factor = factor.rename(index=str, columns=new_column)
    factor = factor.sort_index(1)
    all_factors = []
    for i in range(factor.shape[0]):
        p = str(i) + "/" + str(factor.shape[0])
        print(p,end='\r')
        if factor.iloc[i,-5][:4] != '2017' and factor.iloc[i,-5][:4] != '2018' and  factor.iloc[i,-5][:4] != '2016' and factor.iloc[i,-5][:4] != '2015':
            continue
        new_factor = factor.iloc[i,:-7].T.to_frame()
        new_factor['TradingDay'] = pd.to_datetime(factor.iloc[i,-5])
        new_factor = new_factor.rename(index=str, columns={list(new_factor.columns)[0]: factor_name})
        new_factor['SecuCode'] = new_factor.index
        all_factors.append(new_factor)
    print("concatenating.....")
    all_factors = pd.concat(all_factors)
    all_data = pd.merge(all_data, all_factors,left_on=  ['SecuCode', 'TradingDay'],
               right_on= ['SecuCode','TradingDay'],
               how = 'left')
# Out:
# reading factor0/16
# concatenating.....
# reading factor1/16
# concatenating.....
# reading factor2/16
# concatenating.....
# reading factor3/16
# concatenating.....
# reading factor4/16
# concatenating.....
# reading factor5/16
# concatenating.....
# reading factor6/16
# concatenating.....
# reading factor7/16
# concatenating.....
# reading factor8/16
# concatenating.....
# reading factor9/16
# concatenating.....
# reading factor10/16
# concatenating.....
# reading factor11/16
# concatenating.....
# reading factor12/16
# concatenating.....
# reading factor13/16
# concatenating.....
# reading factor14/16
# concatenating.....
# reading factor15/16
# concatenating.....
# reading factor16/16
# concatenating.....

# %%
all_data['NextReturn'] = np.nan_to_num(all_data['NextReturn'].values)
a = all_data['NextReturn'].values
low_thred = np.percentile(a,33.3333)
high_thred = np.percentile(a,66.6666)
all_data['NextReturnCate'] = np.where(all_data['NextReturn']<low_thred, -1, np.where(all_data['NextReturn']<high_thred,0,1))

# %%
all_data.to_csv("new_all.csv")

# %%
all_data[all_data["TradingDay"] == "2015-01-05"]
# Out:
#     index InnerCode TradingDay PrevClosePrice OpenPrice HighPrice LowPrice  \
# 0       4        20 2015-01-05         7.0500    7.1000    7.3900   7.0200
# 1      10        38 2015-01-05         8.8900    8.9000    9.2000   8.8500
# 2      17        57 2015-01-05         7.1800    7.3000    7.5000   7.2100
# 3      24        68 2015-01-05        47.7300   47.9500   49.2900  47.0100
# 4      26        72 2015-01-05         8.4500    8.4600    8.7200   8.4200
# 5      27        74 2015-01-05         8.4600    8.9000    9.3100   8.7200
# 6      42        93 2015-01-05        30.1200   30.1100   31.1000  29.7000
# 7      43        94 2015-01-05        19.1600   19.7000   20.1500  19.2000
# 8      50       104 2015-01-05        15.1700   15.1700   15.6900  15.0700
# 9      53       107 2015-01-05         5.7300    5.7900    6.1900   5.7900
# 10     57       112 2015-01-05         9.7700    9.7700    9.8800   9.5500
# 11     58       113 2015-01-05         9.8800   10.0000   10.1800   9.6300
# 12     60       115 2015-01-05        13.8000   13.9500   14.7000  13.9400
# 13     62       117 2015-01-05        13.7500   13.7000   14.1500  13.6200
# 14     84       162 2015-01-05        13.6700   13.6700   13.7700  13.0100
# 15     86       164 2015-01-05         8.2900    8.2100    9.0500   8.1100
# 16     87       165 2015-01-05        13.0800   13.1100   14.2600  13.1000
# 17     91       170 2015-01-05         7.4900    7.5200    7.9600   7.4300
# 18     94       173 2015-01-05        11.9500    0.0000    0.0000   0.0000
# 19     98       178 2015-01-05         6.1700    6.1900    6.3500   6.0000
# 20    100       181 2015-01-05        15.8200    0.0000    0.0000   0.0000
# 21    105       188 2015-01-05         6.9700    0.0000    0.0000   0.0000
# 22    108       192 2015-01-05         5.4800    5.5000    5.6800   5.5000
# 23    109       193 2015-01-05         8.2100    8.4400    8.9000   8.4300
# 24    110       194 2015-01-05        49.4400   49.4300   49.7000  48.0000
# 25    115       201 2015-01-05        13.3200   13.3200   14.1600  13.1000
# 26    120       208 2015-01-05        15.8700   15.7700   16.5800  15.7300
# 27    122       211 2015-01-05        12.5800   12.6400   13.1800  11.9600
# 28    133       225 2015-01-05        11.7800   12.0500   12.5900  11.9000
# 29    134       226 2015-01-05        10.2100   10.2100   10.4600  10.1900
# ..    ...       ...        ...            ...       ...       ...      ...
# 470  1619      7388 2015-01-05        17.3000   17.2500   17.5600  17.0000
# 471  2208     13046 2015-01-05         8.5500    8.5100    8.7500   8.4400
# 472  2207     13045 2015-01-05        10.6000   10.6700   11.1300  10.3600
# 473  2234     13297 2015-01-05        13.0800   13.0700   13.9000  13.0100
# 474  1849     10418 2015-01-05         8.7000    8.6900    9.2100   8.6000
# 475  2387     16007 2015-01-05         9.3000    9.2900    9.8400   9.2800
# 476  2388     16008 2015-01-05        11.1800   11.2000   11.3300  11.0700
# 477  2132     12293 2015-01-05         5.9800    0.0000    0.0000   0.0000
# 478  2201     12950 2015-01-05        12.9000   12.8900   13.3300  12.8600
# 479  2486     16914 2015-01-05         7.0300    7.0700    7.2400   6.9600
# 480  1358      4800 2015-01-05         6.0300    6.0300    6.6300   6.0000
# 481  1730      9638 2015-01-05        10.3900   10.4000   10.8300  10.3100
# 482  1923     10832 2015-01-05         7.6300    7.6700    7.9500   7.6100
# 483  1931     10869 2015-01-05         6.3500    6.3000    6.8800   6.2600
# 484  2052     11840 2015-01-05         8.8600    8.8700    9.0800   8.7400
# 485  1679      9344 2015-01-05        16.6200   16.6500   17.0000  16.1700
# 486  1366      4837 2015-01-05         6.2900    6.3000    6.6000   6.2600
# 487  2053     11882 2015-01-05         4.6100    4.6100    4.7400   4.5700
# 488  2291     14107 2015-01-05         8.3000    8.3100    8.6600   8.3100
# 489  2290     14106 2015-01-05        11.2500   11.2900   11.4200  10.8700
# 490  2405     16118 2015-01-05        12.2400   12.2800   12.5900  12.1500
# 491  1507      6410 2015-01-05        10.4900   10.5000   10.6700  10.3000
# 492  2330     14799 2015-01-05        17.8600   17.8600   18.1800  17.5700
# 493  2538     18457 2015-01-05        42.1000   41.9800   41.9900  39.9000
# 494  2427     16325 2015-01-05         9.7000    9.6600   10.1200   9.6300
# 495  2184     12812 2015-01-05        23.2900   23.3200   23.7900  23.3000
# 496  2432     16377 2015-01-05        16.2300   16.1900   16.3800  15.9300
# 497  2561     34602 2015-01-05        27.8700   27.8600   28.6500  27.5200
# 498  2491     16970 2015-01-05        16.7600   16.7200   17.1400  16.5100
# 499  2463     16655 2015-01-05        13.4400   13.4000   13.9300  13.2800
#
#     ClosePrice TurnoverVolume    TurnoverValue      ...        factor8  \
# 0       7.0800      107864712   775346443.8200      ...        94.8675
# 1       9.1300       77484386   703147665.3100      ...        106.916
# 2       7.4300       24220257   178564350.8600      ...         32.477
# 3      48.3200        2618894   126230178.3100      ...        84.4709
# 4       8.4500       14874851   126989523.1600      ...        83.6455
# 5       9.3100      142248249  1305712644.0600      ...         109.78
# 6      30.7800        4726339   143523611.8000      ...        12.1066
# 7      19.5000       27378808   536589479.8200      ...        51.3354
# 8      15.5800        7650032   118016675.1400      ...        26.7033
# 9       6.0500       21890029   131756523.0300      ...         54.856
# 10      9.8500       19757659   191779057.6100      ...        51.2621
# 11     10.0700       44274384   438287054.2200      ...        32.3159
# 12     14.1800       19844066   284548451.1200      ...        102.573
# 13     14.0100       30485877   427221671.8800      ...        88.7157
# 14     13.2500       26466654   352222910.9800      ...        32.3307
# 15      8.8100       38453307   329428145.0000      ...        94.2566
# 16     14.0300       19077281   263483028.0600      ...        79.6571
# 17      7.8400       51173396   395806516.5200      ...        86.6874
# 18     11.9500              0           0.0000      ...        46.2357
# 19      6.3000       40992863   254823920.3700      ...        29.2668
# 20     15.8200              0           0.0000      ...        93.6083
# 21      6.9700              0           0.0000      ...        25.7669
# 22      5.6300       25371391   142482281.8000      ...        2.51718
# 23      8.7700       66122038   575551032.5700      ...         42.586
# 24     48.5000        2559122   124615571.1200      ...        40.6401
# 25     13.9700        8332016   114045826.3600      ...        61.4726
# 26     16.3000        9363873   152211406.4400      ...        86.9292
# 27     12.8000       78812429   995462388.5800      ...        84.4793
# 28     11.9900       93584743  1141126097.1300      ...        78.9364
# 29     10.4200       12361488   128223391.6300      ...        69.7032
# ..         ...            ...              ...      ...            ...
# 470    17.3800        5485899    95088674.0000      ...        15.9278
# 471     8.6800        8141194    70234124.0000      ...          60.22
# 472    11.0100       19559160   210219725.0000      ...        72.4498
# 473    13.7900        9799234   132381014.0000      ...        66.7121
# 474     9.1800       30468438   274673421.0000      ...        56.9069
# 475     9.7700        9432998    90792207.0000      ...        38.4882
# 476    11.2900        7256379    81134399.0000      ...        53.7483
# 477     5.9800              0           0.0000      ...        45.2716
# 478    13.2900        6217000    81581682.0000      ...        74.4595
# 479     7.1900       51162203   363602687.0000      ...         14.169
# 480     6.6300      129272218   831261827.0000      ...        90.7514
# 481    10.7200       25684253   272754585.0000      ...        74.0782
# 482     7.9300       35244491   275576242.0000      ...        52.4584
# 483     6.5200      148052468   973802531.0000      ...        49.9527
# 484     9.0300       13241724   118085115.0000      ...         55.237
# 485    16.8300        6632050   110060314.0000      ...        22.4085
# 486     6.5900      114626115   740882720.0000      ...        31.0841
# 487     4.7300       49232860   229668967.0000      ...        22.2506
# 488     8.6400       16194490   138456632.0000      ...        34.4836
# 489    11.3100        6992580    77743281.0000      ...        75.8479
# 490    12.4900        6558509    81363668.0000      ...        4.56567
# 491    10.6300        7600529    80014748.0000      ...        15.1187
# 492    17.9500        2880752    51610154.0000      ...         28.536
# 493    40.1300        1999551    80362788.0000      ...        39.8788
# 494    10.0900        8714472    87155379.0000      ...        38.6705
# 495    23.6600        2636370    62051879.0000      ...        66.3819
# 496    16.3700        4663967    75576666.0000      ...        103.445
# 497    28.6100        4203279   118923076.0000      ...        108.102
# 498    16.7000        4621315    77765683.0000      ...        19.4168
# 499    13.8000       11635115   159523060.0000      ...        32.5702
#
#      factor9 factor10  factor11 factor12     factor13 factor14 factor15  \
# 0    57.9422   2.3118  0.378723  397.326      4.99105  18.8138  66.1581
# 1    19.9196   2.3082  0.464435  177.222      3.01431   21.688   75.025
# 2    14.2153   2.2056  0.553191  105.605    -0.361918  62.8718  45.9379
# 3    3.83311   3.6776  0.642475   181.83    -0.100233  26.8543  59.7992
# 4    2.12751   2.5496  0.235521  17.7624     0.260867  17.5198  75.3715
# 5    13.8116   2.8214  0.368056  115.851      7.01518  28.2124  73.0431
# 6    5.06253   8.5167  0.885331  155.042     -8.30517   26.935  11.6664
# 7    8.14191   2.7087  0.726479   156.63     -8.21533  36.0217  32.5844
# 8    4.72898   4.4898  0.796537  73.7728     -1.94696  21.7589  20.1875
# 9    11.2392   3.1405  0.600575  66.7736     -1.86582 -612.465  51.5134
# 10   8.04902   5.0123  0.763636   79.111    -0.925734  302.939  37.4284
# 11   7.22766   3.8146  0.632887  72.4086      1.79049  44.4511  29.2041
# 12   2.88675   2.1252       0.4  39.1491       1.3511  18.5891   82.755
# 13   3.73484   3.1523  0.561189   51.667    -0.653217  41.9677   64.737
# 14   10.9973   2.4017      0.68  149.829      3.73557  25.7442  38.3677
# 15   16.5273   2.1116   0.33244  136.567      6.08392  18.7717  80.2772
# 16   2.67801    2.004  0.561905  36.0108     0.575955  12.7096  55.1697
# 17   13.5279    1.149  0.356589  103.245      3.76042  226.881  73.0119
# 18   8.43115   2.5913       NaN  100.753     0.872131  44.2909  45.6287
# 19   5.07248   0.8766  0.461806  31.4884      1.12254  24.1474  34.3629
# 20   5.10508   2.2567  0.482353  80.6762      1.87518  12.1642  79.8527
# 21   3.00332   4.5867       NaN  20.9331    0.0561425 -29.8995  25.7669
# 22   11.2865   4.6692  0.909931  64.2997     -5.89336 -23.2878  8.48055
# 23   17.1717   7.2442  0.681499  146.599     -1.12893 -37.3229  31.0149
# 24    2.6961     3.88  0.499072  131.342      -1.7109  27.7967  33.3861
# 25   5.74366    2.589  0.723744  78.4149     -2.69872  25.9899  33.8133
# 26   7.01657   2.1787  0.544204  112.246    -0.463578  19.3595  66.6147
# 27   8.20216   1.5833  0.230024  101.487      8.72384  72.5524  80.0469
# 28   19.8897   2.8204  0.308146  229.728      15.2959  12.8397  71.4375
# 29   17.8924   3.3491       0.6  184.046     -2.41544  38.3152  48.2497
# ..       ...      ...       ...      ...          ...      ...      ...
# 470  1.06174   2.0548  0.851471  18.5188     -0.38017  20.7362  17.7041
# 471  2.17364   2.4153  0.693103  18.5716    -0.529943  32.3039  43.9691
# 472  2.08721   1.5532  0.215613  22.5237      1.69129  94.8536  79.5778
# 473  2.09699   2.9204  0.617564  28.1153    -0.458663  17.4976  44.6369
# 474  1.73208   2.4604  0.447619  15.4257     0.562482  28.7262  52.2415
# 475  1.33268   2.3705  0.668831  12.8318    -0.154268   173.06  28.4608
# 476   2.1877   4.0367  0.688976   24.584    -0.302568  17.0414  37.6173
# 477  2.90832   3.9701       NaN  17.3918 -9.24149e-05  56.8027  45.2716
# 478  1.14251   1.7222       0.7   14.895   -0.0536792  21.7874  46.9207
# 479   1.0367   2.5089  0.446154   7.3924     0.402239  53.3027  28.5812
# 480  2.51885   1.3621  0.338645  15.6009     0.622426  78.8174  69.5381
# 481  1.58484   1.6009  0.376923  16.7179     0.513827  19.5626  69.9029
# 482  2.21534   1.3629  0.604096  17.1511     0.229217  62.6507  39.7542
# 483  1.04247   2.1077   0.33711  6.53449     0.314181  21.4344  42.5655
# 484   1.1359   1.6944  0.707246  10.1895    -0.238858  23.7347  37.2579
# 485  1.05519   2.9728  0.652389  18.0605    0.0269788  22.0607  30.9658
# 486  1.15881   3.0833  0.295848  7.41401     0.656794  155.349  45.7115
# 487  1.07909   1.5275  0.677966  5.05795    0.0101301  40.1997  23.3817
# 488  2.07051   1.9029   0.56383  17.6409     0.215896  36.0093  36.4767
# 489   2.0464   2.5818  0.615202   23.188    -0.483409  84.5718  59.6776
# 490  1.02693   2.2678  0.716632  12.8509    -0.220962  19.3598    12.02
# 491   1.0209   3.2412  0.851927  11.0344    -0.428763  78.0734  15.6773
# 492  1.04642   1.8504  0.505825  18.7962     0.260238    27.87  35.4241
# 493  1.00396    5.786  0.693431    40.97     -1.78413  46.3415  35.2258
# 494  2.06991   2.1468  0.784153  20.4952    -0.757976  15.1868  24.6676
# 495  1.00231   2.9149   0.75443  23.4878    -0.943031  32.0528  44.4595
# 496  1.10785   1.8586  0.610315  17.8746    -0.274225  30.5156  68.6102
# 497        1   4.0505  0.534407  28.1019   -0.0762821  22.2366  79.7982
# 498  1.03722   4.5863   0.44711  17.5307     0.732358  32.8393  37.1917
# 499  1.04036   2.7126  0.799469  14.2618    -0.801149  18.1988  24.8483
#
#     factor16 NextReturnCate
# 0    394.355             -1
# 1    176.328              0
# 2    106.274              1
# 3    180.984              1
# 4    17.7945              1
# 5    113.283              1
# 6    153.638              1
# 7    155.543              1
# 8    73.7532              1
# 9    67.0081              0
# 10   78.9931              1
# 11   72.5946              1
# 12   38.9769              0
# 13   51.6902              1
# 14   151.653              0
# 15   135.359              1
# 16   35.7247              0
# 17   103.461              1
# 18   100.752              0
# 19   31.3682              1
# 20   80.7624              0
# 21   20.9331              0
# 22   63.1818              0
# 23    145.65              1
# 24   131.079              1
# 25   77.8151              1
# 26   112.335              1
# 27   103.085             -1
# 28   229.686             -1
# 29   183.862              1
# ..       ...            ...
# 470  18.4976              1
# 471  18.4455              1
# 472  22.8424             -1
# 473  27.9948              0
# 474  15.4051              0
# 475  12.8204              0
# 476   24.511              1
# 477  17.3918              0
# 478  14.8343              1
# 479   7.4124              0
# 480  15.4557             -1
# 481  16.8342              1
# 482   17.067             -1
# 483  6.45914             -1
# 484  10.2117              1
# 485  18.2527              1
# 486  7.42565              1
# 487  5.06093              1
# 488  17.6656              1
# 489  23.3412              0
# 490  12.8058              1
# 491  11.0523              1
# 492  18.8272             -1
# 493  40.7949              1
# 494  20.3389              1
# 495  23.3598              1
# 496  17.7655              1
# 497   28.044             -1
# 498  17.6659              0
# 499  14.1739              1
#
# [500 rows x 41 columns]

# %%
all_data.to_csv("all_data.csv")

# %%
all_data = pd.read_csv("all_data.csv")
